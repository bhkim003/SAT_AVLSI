# %%
# Simulation for SAT solving hardware
# reference: Chaeyun Shim, Jooyoung Bae, and Bongjin Kim. "30.3 VIP-Sat: A Boolean Satisfiability Solver Featuring 5× 12 Variable In-Memory Processing Elements with 98% Solvability for 50-Variables 218-Clauses 3-SAT Problems." 2024 IEEE International Solid-State Circuits Conference (ISSCC). Vol. 67. IEEE, 2024.

# %%
# 데이터셋 위치  
# /data2/sat/uf50-218  
# /data2/sat/uf20-91 
# 출처: https://www.cs.ubc.ca/~hoos/SATLIB/benchm.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy 
import os
import re
import json
import datetime
from collections import defaultdict
import re

# %%
def count_files_in_directory(directory):
    try:
        # 폴더 내의 모든 파일 목록 가져오기
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        return files
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
        return None

# %%
def read_cnf_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    clauses = []

    clause_save_start = False
    clause_count = 0
    for line in lines:
        if clause_save_start == True:
            clause = list(map(int, line.strip().split()))
            assert clause[-1] == 0
            clause = clause[:-1]  # Remove the trailing 0
            clauses.append(clause)
            clause_count += 1
            if clause_count == num_clauses:
                break

        if line.startswith(('p')) and clause_save_start == False:
            clause_save_start = True
            _, _, num_vars, num_clauses = line.split()
            num_vars = int(num_vars)
            num_clauses = int(num_clauses)
    assert clause_save_start == True

    clauses = np.array(clauses)
    return clauses, num_vars, num_clauses

# %%
class VPE:
    def __init__(self, MY_VAR):
        """
        VPE 초기화 메서드
        :param MY_VAR: 이 VPE가 담당할 변수 (예: v1, v2 등)
        """
        self._MY_VAR = MY_VAR  # 이 VPE가 처리할 변수
        self.MY_STATE = 1       # 변수의 상태 

        self.clauses = []         # 변수가 속한 절들의 리스트
        self.neighbors = set()    # 상관관계 있는 이웃 변수들

    @property # MY_VAR 속성은 읽기 전용
    def MY_VAR(self):
        return self._MY_VAR
    
    def add_clause(self, all_clauses):
        """
        변수가 속한 절을 추가하는 메서드
        :param all_clauses: 전체 절들의 리스트
        """
        clauses_clone = copy.deepcopy(all_clauses)
        for clause in clauses_clone:
            clause_abs = [abs(x) for x in clause]

            if self.MY_VAR in clause_abs:
                self_index = clause_abs.index(self.MY_VAR)
                temp = clause[self_index]

                #주인공이 앞에 오게 저장
                clause = np.concatenate((clause[:self_index], clause[self_index + 1:]))  # self_index에서 요소 제거
                clause_abs = clause_abs[:self_index] + clause_abs[self_index+1:]
                temp2 = np.insert(clause, 0, temp) 
                self.clauses.append(temp2) 

                # 절 내에서 다른 변수들을 이웃으로 추가
                for var_abs in clause_abs:
                    self.neighbors.add(var_abs)
            
    def get_neighbors(self):
        """
        상관관계 있는 이웃 변수들을 반환하는 메서드
        """
        return list(self.neighbors)

    def process(self, var_state_array):
        """
        변수를 처리하는 메서드 (예: 값 업데이트 등)
        이 부분은 문제 해결 알고리즘에 따라 달라질 수 있음.
        """

        # Adder Tree
        tree_sum = 0

        non_trivial_clauses_count = 0.0 # VI가 중요한 절 개수
        up_count = 0.0
        down_count = 0.0

        # Clause Column
        for clause in self.clauses:
            SI = 0 if clause[0] < 0 else 1 # 음수면 0, 양수면 1 
            SL = 0 if clause[1] < 0 else 1
            SR = 0 if clause[2] < 0 else 1

            VI = var_state_array[abs(clause[0])-1] # 현재 V값 가져오기
            VL = var_state_array[abs(clause[1])-1]
            VR = var_state_array[abs(clause[2])-1]

            assert VI == self.MY_STATE, f'{VI}, {self.MY_STATE}'

            # S와 V의 XOR값(같으면 0 다르면 1)이 3개가 나옴. (SIVI, SLVL, SRVR) 한개라도 XOR값이 0이어야 Clause satisfied.
            
            # Clause Logic
            if ((SL == 1 and VL == 0) or (SL == 0 and VL == 1)) and ((SR == 0 and VR == 1) or (SR == 1 and VR == 0)) == 1: 
                C0 = 1 # MY_VAR가 중요해졌다는 flag.
                C1 = 1 if SI == 0 else 0 # SI 토글
            else:
                C0 = 0
                C1 = 0

            # Adder Tree
            addi = 0
            if C0 == 1:
                non_trivial_clauses_count += 1.0
                if C1 == 1:
                    addi = -1
                    down_count += 1.0
                else: # C1 == 0
                    addi = 1
                    up_count += 1.0
            else: # C0 == 0
                addi = 0
            tree_sum = tree_sum + addi

        # update
        if tree_sum < 0:
            self.MY_STATE = 0
        elif tree_sum == 0:
            self.MY_STATE = 1 if self.MY_STATE == 0 else 0
        elif tree_sum > 0:
            self.MY_STATE = 1
        else: 
            assert False

        return self.MY_STATE

# %%
class VPE_ARRAY:
    def __init__(self, my_seed=42,  num_rows=5, num_cols=12, clauses=[[1,2,-3],[2,-1,57]], num_vars=50, num_clauses=218, what_file='uf50-03'):
        """
        VPE_ARRAY 초기화 메서드
        :param num_rows: VPE 배열의 행 개수 (기본값: 5)
        :param num_cols: VPE 배열의 열 개수 (기본값: 12)
        :param clauses: 3-SAT 문제의 절(clause) 리스트
        :param num_vars: 변수의 총 개수
        :param num_clauses: 절의 총 개수
        """
        self.my_seed = my_seed
        self.num_rows = num_rows  # 행 개수
        self.clauses = clauses
        self.num_cols = num_cols  # 열 개수
        self.num_vars = num_vars  # 변수의 총 개수
        self.var_init_seed = my_seed
        self.what_file = what_file

        # 랜덤 시드 초기화
        random.seed(self.my_seed)

        # 상관 관계 행렬 
        self.correlation_matrix = self.create_correlation_matrix()

        # VPE 배열 생성
        self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_variables_to_vpe()

        # 딱 variable 개수만큼 배치 잘했는지 확인
        assert len(self.assigned_abs_vars) == self.num_vars, f'len(self.assigned_abs_vars): {len(self.assigned_abs_vars)}, self.num_vars: {self.num_vars}'
        assert sum(1 for i in range(self.num_rows) for j in range(self.num_cols) if self.VPES[i][j] is not None) == self.num_vars

        # 배치한 거 한번 보자
        # self.print_vpe_index()

        # uncorrelated columns check
        assert self.check_uncorrelated_columns(self.VPE_index, self.correlation_matrix)

        # VPE 배열에 모든 절 삽입
        self.add_clause_to_vpe()
        
        # variable state initialize
        self.var_state_array = self.variable_state_initialize()

        # deployment된 VPE들의 state값을 출력
        # self.print_var_state_array()
        
        # run
        # 외부에서 실행해야 된다  


    def create_correlation_matrix(self):
        """
        상관 관계 행렬을 생성하는 메서드

        Args:
            clauses (list): 변수의 절(clause) 리스트
        """
        # 각 절(clause)에서 변수를 두 개씩 비교하며 상관 관계를 행렬에 기록
        correlation_matrix = np.zeros((self.num_vars, self.num_vars), dtype=int)
        for clause in self.clauses:
            for i, var1 in enumerate(clause):
                for var2 in clause[i + 1:]:
                    abs_var1, abs_var2 = abs(var1) - 1, abs(var2) - 1  # 변수 인덱스는 0부터 시작하므로 -1 처리
                    correlation_matrix[abs_var1, abs_var2] = 1  # 상관된 변수 간에는 1을 표시
                    correlation_matrix[abs_var2, abs_var1] = 1  # 상관 행렬은 대칭이므로 반대 방향도 동일하게 처리
        
        return correlation_matrix
    
    def assign_variables_to_vpe(self):
        correlation_matrix_save = copy.deepcopy(self.correlation_matrix)
        assigned_abs_vars = set()
        deploy_search_iter = 0
        while True:
            deploy_search_iter += 1
            self.correlation_matrix = copy.deepcopy(correlation_matrix_save)

            # 사용한 변수를 추적하기 위한 리스트
            assigned_abs_vars = set()

            # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
            VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
            VPES_index_past = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])

            # 변수 할당을 위한 작업
            current_row_at_column = [0 for _ in range(self.num_cols)]
            for whole_col_iter in range(1000): # 모든 컬럼 반복 # 근데 어차피 이전 iter와 변화가 없으면 걍 break된다.
                shuffled_abs_vars_range = np.concatenate([np.sort(group)[::-1] for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 if np.random.seed((self.my_seed+1)*(whole_col_iter+1)*(deploy_search_iter+1)) is None else None

                for col in range(self.num_cols):
                    if current_row_at_column[col] >= self.num_rows:  # 이 column에 모두 할당했으면 다음 column으로
                        continue

                    # 상관 관계가 없는 변수들을 찾아서 같은 컬럼에 넣어!
                    col_chance = self.num_rows # 원하는 만큼 다 해 (한 컬럼에 한번에 몇개까지 넣을지)

                    for abs_var in shuffled_abs_vars_range:
                        if abs_var in assigned_abs_vars:
                            continue # next var  # 이미 할당된 변수는 건너뜀

                        # 상관되지 않은 변수인지 확인
                        can_assign = True
                        for prev_row in range(current_row_at_column[col]):
                            prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                            if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                                can_assign = False
                                break # next var

                        if can_assign == True:
                            assert VPES[current_row_at_column[col]][col] == None
                            VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                            assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                            current_row_at_column[col] += 1
                            col_chance -= 1 

                        # stage1_cut_row = self.num_vars//self.num_cols - 1
                        if current_row_at_column[col] == self.num_rows or col_chance == 0:  # 이 column에 어느 정도 할당했으면 다음 column으로
                            break # next col;
                
                VPES_index_temp = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                if np.array_equal(VPES_index_past, VPES_index_temp) or len(assigned_abs_vars) == self.num_vars:
                    break
                else:
                    pass
                VPES_index_past = VPES_index_temp
            
            assert len(assigned_abs_vars) <= self.num_vars, f'ASSERT FALSE!! len(assigned_abs_vars): {len(assigned_abs_vars)}, self.num_vars: {self.num_vars}'
            if len(assigned_abs_vars) == self.num_vars:
                VPES_index = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                break
        return VPES, VPES_index, assigned_abs_vars

    def print_vpe_index(self):
        """
        VPE 배열을 2D 행렬로 출력하는 메서드
        """
        print('VPE Array:')
        for row_index, row in enumerate(self.VPE_index):
            formatted_row = '| '.join(f'v{str(elem-1) if elem is not None else "No":<2}' 
                                        for col_index, elem in enumerate(row))
            print(formatted_row)
        print('num of assigned_abs_vars:', len(self.assigned_abs_vars),'\n')
        

    def check_uncorrelated_columns(self, VPE_index, correlation_matrix):
        # VPE_index: VPE 배열의 인덱스를 나타냄. 각 값은 변수 번호를 의미함.
        # correlation_matrix: 변수들 간의 상관관계를 나타내는 행렬. (num_vars x num_vars 크기의 행렬)

        num_rows = len(VPE_index)
        # VPE_index의 행(row) 수를 얻음. 즉, VPE 배열에서 몇 개의 행이 있는지 확인.

        num_cols = len(VPE_index[0])
        # VPE_index의 열(column) 수를 얻음. 즉, 각 열에 몇 개의 변수가 배치되었는지 확인.

        for col in range(num_cols):
            # 각 열(column)을 순회함. 이때 col은 현재 처리 중인 열의 인덱스를 나타냄.

            col_values = [VPE_index[row][col] for row in range(num_rows) if VPE_index[row][col] is not None]
            # 현재 열에서 변수가 할당된 값을 모두 수집. None이 아닌 값만 선택하여 리스트로 만듦.
            # 즉, 해당 열에 배치된 변수 번호들을 수집하는 과정.

            for i in range(len(col_values)):
                # 수집한 변수 번호 리스트에서 첫 번째 변수부터 시작하여 다른 변수들과 비교하기 위해 반복문 시작.
                # i는 현재 비교하고자 하는 첫 번째 변수의 인덱스를 나타냄.

                for j in range(i + 1, len(col_values)):
                    # i 이후에 있는 변수들과 비교하기 위한 반복문.
                    # j는 두 번째로 비교할 변수의 인덱스를 나타냄.

                    var1 = col_values[i]
                    # 첫 번째 변수의 값(var1)을 col_values 리스트에서 가져옴.

                    var2 = col_values[j]
                    # 두 번째 변수의 값(var2)을 col_values 리스트에서 가져옴.

                    # 상관된 경우를 찾음
                    if correlation_matrix[var1 - 1][var2 - 1] == 1:
                        # correlation_matrix에서 var1과 var2가 상관된 경우를 확인.
                        # 변수 번호는 1부터 시작하므로, 0-based 인덱스에 맞추기 위해 -1 처리.
                        # 상관된 경우, correlation_matrix에서 해당 값이 1임을 이용하여 상관된 변수를 확인함.

                        # print(f"Error: Column {col+1} contains correlated variables {var1} and {var2}.")
                        # 상관된 변수를 발견한 경우, 그 변수가 어느 column에 있는지와 함께 에러 메시지를 출력.

                        return False
                        # 상관된 변수가 발견되면 더 이상 검사를 진행하지 않고 False를 반환하여 함수 종료.

        # 모든 열에 대해 상관된 변수가 없을 경우, 오류가 없음을 나타냄.
        # print("All columns are internally uncorrelated.\n")
        return True
        # 모든 열에서 상관된 변수가 없는 경우, True를 반환함.

    def add_clause_to_vpe(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].add_clause(self.clauses)

    
    def variable_state_initialize(self):
        self.var_init_seed *= self.my_seed
        random.seed(self.var_init_seed)
        var_state_array = [random.choice([0, 1]) for _ in range(self.num_vars)]

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].MY_STATE = var_state_array[self.VPES[row][col].MY_VAR - 1]
        return var_state_array
    


    def satisfy_check(self, var_state_array, clauses):
        """
        절을 만족하는지 확인하는 메서드
        :param var_state_array: 변수들의 상태를 나타내는 배열 (0 또는 1로 구성된 리스트)
        :param clauses: 각 절을 표현하는 리스트의 리스트 (변수는 양수 또는 음수로 표현됨)
        :return: num_unsat_clause, unsat_clauses_list (만족되지 않은 절의 개수와 그 절들의 리스트)
        """
        unsat_clauses_list = []
        # 각 절에 대해 만족 여부를 확인
        for clause in clauses:
            satisfied = False  # 해당 절이 만족되는지 여부를 나타내는 변수

            for var in clause:
                abs_var = abs(var) - 1  # 변수의 절대값으로 인덱스를 맞춤 (0부터 시작)
                var_state = var_state_array[abs_var]  # 해당 변수의 상태

                if (var > 0 and var_state == 1) or (var < 0 and var_state == 0):
                    satisfied = True  
                    break # 하나라도 만족하는 변수가 있으면 절이 만족됨

            if satisfied == False:
                unsat_clauses_list.append(clause)  # 만족되지 않은 절을 리스트에 추가

        num_unsat_clause = len(unsat_clauses_list)  # 만족되지 않은 절의 개수

        return num_unsat_clause, unsat_clauses_list
    
    def print_var_state_array(self):
        for col in range(self.num_cols):
            print(f'col{col:>2}', end='|||')
        print()

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPE_index[row][col] != None:
                    print(f'v{self.VPE_index[row][col]-1:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
                else: 
                    print(f'None ', end=' | ')
            print()

    def run(self, max_iter, iter_verbose):
        """
        VPE 배열을 실행하는 메서드
        :param max_iter: 최대 반복 횟수 (기본값: 100)
        """

        num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)

        if iter_verbose == True or True:
            print('INITIAL VAR STATE ARRAY')
            print(f'iteration {0:>4} | num_unsat_clause: {num_unsat_clause}')
            self.print_var_state_array()
        for i in range(max_iter):
            # row-wise parellel processing
            for col in range(self.num_cols):
                state_temp_at_now_col = [None for _ in range(self.num_rows)]
                for row in range(self.num_rows):
                    if self.VPES[row][col] != None:
                        state_temp_at_now_col[row] = self.VPES[row][col].process(self.var_state_array)

                # updated state update!!
                toggle_count = 0
                for row in range(self.num_rows):
                    if state_temp_at_now_col[row] != None:  
                        if self.var_state_array[self.VPES[row][col].MY_VAR - 1] != state_temp_at_now_col[row]:
                            toggle_count += 1
                        self.var_state_array[self.VPES[row][col].MY_VAR - 1] = state_temp_at_now_col[row]

                        
                if iter_verbose == True:
                    num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
                    print(f'\n\niter {i+1}- col {col} done, toggle_count: {toggle_count}' )
                    print(f'iteration {i+1:>4} | num_unsat_clause: {num_unsat_clause}')
                    self.print_var_state_array()

            num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)

            if num_unsat_clause == 0:
                return i+1
            
            # iteration 마다 실패하면 다시 리셋하기 (근데 이러면 solvability 0)
            # self.var_state_array = self.variable_state_initialize()

        else:
            if iter_verbose == True:
                print(f"NOT SATISFIED! num_unsat_clause: {num_unsat_clause}, unsat_clauses_list: {unsat_clauses_list}, iteration: {i+1}")
            return -num_unsat_clause # 음수를 출력하여 실패한 것을 알림

# %%
def HYPER_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, file_path='/data2/sat/uf50-218/uf50-03.cnf', max_iter=100, iter_verbose=False):
    clauses, num_vars, num_clauses = read_cnf_file(file_path)

    SUCCESS_OR_NOT = 0
    for hyper_iter in range(HYPER_MAX_ITER):
        my_seed = hyper_seed * (hyper_iter+1)
        what_file = os.path.splitext(os.path.basename(file_path))[0]
        vpe_array = VPE_ARRAY(my_seed=my_seed, num_rows=num_rows, num_cols=num_cols, clauses=clauses, num_vars=num_vars, num_clauses=num_clauses, what_file=what_file)  # 5x12 VPE 배열 생성
        success_iter = vpe_array.run(max_iter, iter_verbose)  # VPE processing 실행
        assert success_iter != 0, 'run메서드에서는 0이 나올 수는 없게 해놨다.'
        
        if success_iter > 0:
            print(f'SATISFIED!!!! hyper_iter: {hyper_iter+1}, success_iter: {success_iter}')
            SUCCESS_OR_NOT = success_iter # 양수면 성공임
            break
    else:
        print(f'NOT SATISFIED! HYPER_MAX_ITER: {HYPER_MAX_ITER},  last num_unsat_clause: {-success_iter}')

    return SUCCESS_OR_NOT, hyper_iter

# %%
def FULL_FILE_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, BASE_PATH='/data2/sat/uf50-218/', max_iter=10, iter_verbose=False, max_problem = 1000, current_time="20241026_025657"):
    files = count_files_in_directory(BASE_PATH)
    assert files != None, 'no directory'
    
    # 파일 이름에서 숫자만 추출하여 정렬
    def extract_number(file_name):
        numbers = re.findall(r'\d+', file_name) # 파일 이름에서 숫자를 추출
        return int(numbers[-1]) if numbers else float('inf')  # 숫자가 없는 파일을 뒤로 정렬
    
    files.sort(key=extract_number)  # 파일 이름을 숫자 순으로 정렬
    
    total_file = len(files)
    num_success = 0
    current_file = 0

    for file in files:
        current_file += 1
        file_path = os.path.join(BASE_PATH, file)
        print(f'\nfile: {file}, {current_file}/{max_problem}   (real total: {total_file})')

        SUCCESS_OR_NOT, hyper_iter= HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose)
        if SUCCESS_OR_NOT > 0:
            num_success += 1
            iter = SUCCESS_OR_NOT
        print(f'Current Solvability: {100*num_success/current_file:.2f}%')
        
        if max_problem == current_file:
            break
    print(f'\n\nFinal Solvability: {100*num_success/current_file:.2f}%')

# %%
HYPER_MAX_ITER = 1 # fix 1
# BASE_PATH = 'set your directory' # SATLIB dataset path
BASE_PATH = '/data2/sat/uf50-218/' 
# BASE_PATH = '/data2/sat/uf20-91/'
hyper_seed = 2
num_rows = 5
num_cols = 12
max_iter = 11
iter_verbose = False # True # False
max_problem = 100 # max 100 # don't set over 100
current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
print(f'current_time: {current_time}')

FULL_FILE_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, 
                hyper_seed=hyper_seed, 
                num_rows=num_rows, 
                num_cols=num_cols, 
                BASE_PATH=BASE_PATH, 
                max_iter=max_iter, 
                iter_verbose=iter_verbose,
                max_problem=max_problem,
                current_time=current_time)
# Out:
# current_time: 20241210_123002
#
# file: uf50-01.cnf, 1/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v48=1 | v21=1 | v30=0 | v36=1 | v42=1 | v11=0 | v32=0 | v20=1 | v3 =1 | v43=1 | v15=0 | None  |
# v34=1 | v45=1 | v47=0 | v5 =0 | v37=0 | v2 =0 | v28=1 | v33=1 | v35=0 | v46=0 | v9 =1 | None  |
# v13=1 | v40=0 | v17=1 | v10=1 | v49=1 | v25=1 | v6 =0 | v14=1 | v19=0 | v27=0 | None  | None  |
# v38=1 | v39=1 | v44=1 | v24=1 | v22=0 | v26=1 | v31=0 | v8 =0 | v0 =0 | None  | None  | None  |
# v7 =0 | v12=0 | v4 =1 | v29=1 | v41=1 | v16=0 | v18=0 | v23=0 | v1 =1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 0.00%
#
# file: uf50-02.cnf, 2/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v30=0 | v37=0 | v7 =0 | v27=0 | v20=1 | v13=1 | v12=0 | v40=0 | v2 =0 | v4 =1 | v48=1 | None  |
# v8 =0 | v21=1 | v0 =0 | v3 =1 | v34=1 | v14=1 | v16=0 | v11=0 | v32=0 | v36=1 | v1 =1 | None  |
# v29=1 | v31=0 | v43=1 | v35=0 | v25=1 | v45=1 | v38=1 | v41=1 | v46=0 | v10=1 | v23=0 | None  |
# v24=1 | v26=1 | v18=0 | v28=1 | v47=0 | v44=1 | v33=1 | v17=1 | v6 =0 | None  | None  | None  |
# None  | v22=0 | v5 =0 | v49=1 | v9 =1 | v15=0 | v39=1 | v42=1 | v19=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 0.00%
#
# file: uf50-03.cnf, 3/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 34
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =0 | v23=0 | v26=1 | v27=0 | v16=0 | v47=0 | v4 =1 | v20=1 | v41=1 | v15=0 | v5 =0 | None  |
# v36=1 | v38=1 | v35=0 | v24=1 | v1 =1 | v30=0 | v7 =0 | v0 =0 | v19=0 | v2 =0 | v14=1 | None  |
# v25=1 | v13=1 | v11=0 | v45=1 | v44=1 | v17=1 | v22=0 | v42=1 | v49=1 | v29=1 | v37=0 | None  |
# v6 =0 | v31=0 | v9 =1 | v39=1 | v3 =1 | v10=1 | v18=0 | v32=0 | v43=1 | v48=1 | None  | None  |
# v28=1 | v33=1 | v34=1 | v40=0 | v46=0 | v12=0 | None  | v21=1 | None  | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 3
# Current Solvability: 33.33%
#
# file: uf50-04.cnf, 4/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v21=1 | v33=1 | v9 =1 | v0 =0 | v15=0 | v34=1 | v6 =0 | v13=1 | v40=0 | v26=1 | v11=0 | None  |
# v20=1 | v46=0 | v48=1 | v37=0 | v30=0 | v10=1 | v31=0 | v7 =0 | v41=1 | v25=1 | v8 =0 | None  |
# v1 =1 | v17=1 | v4 =1 | v39=1 | v36=1 | v35=0 | v49=1 | v24=1 | v29=1 | v14=1 | None  | None  |
# v45=1 | v32=0 | v42=1 | v12=0 | v19=0 | v3 =1 | v18=0 | v43=1 | v23=0 | v2 =0 | None  | None  |
# v16=0 | v47=0 | v22=0 | v38=1 | v5 =0 | v28=1 | v27=0 | v44=1 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 25.00%
#
# file: uf50-05.cnf, 5/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 28
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v34=1 | v44=1 | v37=0 | v9 =1 | v17=1 | v8 =0 | v48=1 | v32=0 | v12=0 | v7 =0 | None  |
# v49=1 | v41=1 | v27=0 | v33=1 | v10=1 | v20=1 | v42=1 | v23=0 | v15=0 | v16=0 | v24=1 | None  |
# v2 =0 | v6 =0 | v19=0 | v22=0 | v21=1 | v4 =1 | v38=1 | v18=0 | v31=0 | v14=1 | v13=1 | None  |
# v5 =0 | v29=1 | v39=1 | v47=0 | v43=1 | v0 =0 | v3 =1 | v40=0 | v28=1 | v35=0 | None  | None  |
# v46=0 | None  | v26=1 | v1 =1 | v36=1 | v11=0 | v30=0 | None  | v25=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 40.00%
#
# file: uf50-06.cnf, 6/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v19=0 | v48=1 | v35=0 | v1 =1 | v0 =0 | v22=0 | v37=0 | v44=1 | v27=0 | v33=1 | None  |
# v41=1 | v4 =1 | v25=1 | v5 =0 | v23=0 | v40=0 | v43=1 | v36=1 | v32=0 | v30=0 | None  | None  |
# v14=1 | v34=1 | v13=1 | v31=0 | v24=1 | v20=1 | v10=1 | v39=1 | v28=1 | v6 =0 | None  | None  |
# v8 =0 | v26=1 | v17=1 | v47=0 | v42=1 | v29=1 | v38=1 | v46=0 | v7 =0 | v12=0 | None  | None  |
# v49=1 | v15=0 | v18=0 | v21=1 | v11=0 | v2 =0 | v3 =1 | v9 =1 | v16=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-07.cnf, 7/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 31
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v32=0 | v33=1 | v41=1 | v34=1 | v24=1 | v21=1 | v20=1 | v44=1 | v4 =1 | v22=0 | None  |
# v6 =0 | v5 =0 | v17=1 | v29=1 | v11=0 | v0 =0 | v48=1 | v42=1 | v7 =0 | v47=0 | v15=0 | None  |
# v14=1 | v16=0 | v43=1 | v28=1 | v40=0 | v27=0 | v2 =0 | v39=1 | v31=0 | v35=0 | v10=1 | None  |
# v8 =0 | v1 =1 | v19=0 | v25=1 | v30=0 | v46=0 | v49=1 | v26=1 | v36=1 | None  | None  | None  |
# None  | v23=0 | v18=0 | v13=1 | v9 =1 | v38=1 | v12=0 | v37=0 | v3 =1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 3
# Current Solvability: 42.86%
#
# file: uf50-08.cnf, 8/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v46=0 | v12=0 | v47=0 | v25=1 | v19=0 | v6 =0 | v31=0 | v38=1 | v8 =0 | v2 =0 | v9 =1 | None  |
# v26=1 | v16=0 | v27=0 | v48=1 | v49=1 | v39=1 | v0 =0 | v10=1 | v36=1 | v3 =1 | v5 =0 | None  |
# v43=1 | v1 =1 | v32=0 | v24=1 | v11=0 | v18=0 | v28=1 | v40=0 | v45=1 | v30=0 | None  | None  |
# v20=1 | v34=1 | v13=1 | v23=0 | v42=1 | v14=1 | v44=1 | v33=1 | v37=0 | v21=1 | None  | None  |
# v7 =0 | v15=0 | None  | v22=0 | v17=1 | v35=0 | v29=1 | v4 =1 | v41=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 3
# Current Solvability: 37.50%
#
# file: uf50-09.cnf, 9/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v33=1 | v0 =0 | v12=0 | v28=1 | v20=1 | v39=1 | v34=1 | v31=0 | v16=0 | v22=0 | v13=1 | None  |
# v10=1 | v26=1 | v5 =0 | v18=0 | v9 =1 | v45=1 | v4 =1 | v24=1 | v23=0 | v41=1 | v29=1 | None  |
# v47=0 | v21=1 | v2 =0 | v19=0 | v1 =1 | v42=1 | v49=1 | v27=0 | v46=0 | v3 =1 | None  | None  |
# v37=0 | v35=0 | v8 =0 | v48=1 | v17=1 | v36=1 | v11=0 | v38=1 | v43=1 | v25=1 | None  | None  |
# v14=1 | v15=0 | v40=0 | v7 =0 | v6 =0 | v32=0 | v44=1 | v30=0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 33.33%
#
# file: uf50-010.cnf, 10/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v47=0 | v22=0 | v31=0 | v4 =1 | v24=1 | v48=1 | v40=0 | v12=0 | v35=0 | v11=0 | v13=1 | None  |
# v32=0 | v1 =1 | v41=1 | v10=1 | v34=1 | v49=1 | v37=0 | v7 =0 | v2 =0 | v28=1 | None  | None  |
# v43=1 | v21=1 | v6 =0 | v30=0 | v19=0 | v16=0 | v27=0 | v23=0 | v5 =0 | v42=1 | None  | None  |
# v29=1 | v14=1 | v25=1 | v44=1 | v3 =1 | v38=1 | v36=1 | v39=1 | v20=1 | v18=0 | None  | None  |
# v0 =0 | v8 =0 | v45=1 | v26=1 | v17=1 | v9 =1 | None  | v33=1 | v46=0 | v15=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.00%
#
# file: uf50-011.cnf, 11/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 30
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v34=1 | v35=0 | v42=1 | v27=0 | v18=0 | v32=0 | v19=0 | v1 =1 | v24=1 | v15=0 | v26=1 | v16=0 |
# v9 =1 | v47=0 | v13=1 | v8 =0 | v10=1 | v22=0 | v14=1 | v43=1 | v3 =1 | v40=0 | None  | None  |
# v36=1 | v6 =0 | v28=1 | v29=1 | v7 =0 | v41=1 | v21=1 | v31=0 | v23=0 | v33=1 | None  | None  |
# v45=1 | v37=0 | v46=0 | v2 =0 | v39=1 | v44=1 | v0 =0 | v49=1 | v5 =0 | v4 =1 | None  | None  |
# None  | None  | v48=1 | v25=1 | v11=0 | v30=0 | v17=1 | v12=0 | v38=1 | v20=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 36.36%
#
# file: uf50-012.cnf, 12/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 36
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v11=0 | v48=1 | v4 =1 | v38=1 | v28=1 | v1 =1 | v44=1 | v39=1 | v23=0 | v16=0 | v30=0 | None  |
# v45=1 | v29=1 | v49=1 | v26=1 | v43=1 | v9 =1 | v12=0 | v2 =0 | v32=0 | v0 =0 | v22=0 | None  |
# v17=1 | v37=0 | v18=0 | v15=0 | v13=1 | v24=1 | v31=0 | v42=1 | v7 =0 | v46=0 | None  | None  |
# v6 =0 | v20=1 | v8 =0 | v40=0 | v25=1 | v21=1 | v3 =1 | v34=1 | v5 =0 | v35=0 | None  | None  |
# v33=1 | v14=1 | v27=0 | v36=1 | v41=1 | v19=0 | v10=1 | v47=0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-013.cnf, 13/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 22
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v28=1 | v20=1 | v46=0 | v37=0 | v22=0 | v45=1 | v43=1 | v31=0 | v29=1 | v14=1 | v39=1 | None  |
# v15=0 | v38=1 | v33=1 | v10=1 | v17=1 | v49=1 | v0 =0 | v9 =1 | v44=1 | v23=0 | v16=0 | None  |
# v13=1 | v19=0 | v7 =0 | v24=1 | v12=0 | v3 =1 | v4 =1 | v11=0 | v27=0 | v41=1 | None  | None  |
# v35=0 | v32=0 | v47=0 | v26=1 | v36=1 | v25=1 | v34=1 | v8 =0 | v30=0 | v6 =0 | None  | None  |
# v40=0 | None  | v42=1 | v48=1 | v2 =0 | v1 =1 | v18=0 | v5 =0 | v21=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 38.46%
#
# file: uf50-014.cnf, 14/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v30=0 | v46=0 | v0 =0 | v33=1 | v24=1 | v35=0 | v22=0 | v32=0 | v34=1 | v23=0 | v1 =1 | None  |
# v37=0 | v26=1 | v5 =0 | v7 =0 | v20=1 | v4 =1 | v21=1 | v8 =0 | v3 =1 | v36=1 | None  | None  |
# v44=1 | v2 =0 | v31=0 | v18=0 | v16=0 | v43=1 | v42=1 | v38=1 | v41=1 | v45=1 | None  | None  |
# v9 =1 | v47=0 | v11=0 | v13=1 | v40=0 | v39=1 | v12=0 | v48=1 | v25=1 | v28=1 | None  | None  |
# v29=1 | v15=0 | v27=0 | v49=1 | v14=1 | v19=0 | v10=1 | v17=1 | v6 =0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 3
# Current Solvability: 35.71%
#
# file: uf50-015.cnf, 15/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v19=0 | v18=0 | v11=0 | v38=1 | v3 =1 | v0 =0 | v47=0 | v12=0 | v44=1 | v23=0 | None  |
# v29=1 | v22=0 | v31=0 | v49=1 | v26=1 | v34=1 | v32=0 | v30=0 | v10=1 | v35=0 | v13=1 | None  |
# v42=1 | v9 =1 | v21=1 | v16=0 | v27=0 | v43=1 | v28=1 | v33=1 | v45=1 | v36=1 | None  | None  |
# v46=0 | v20=1 | v17=1 | v39=1 | v4 =1 | v8 =0 | v6 =0 | v5 =0 | v2 =0 | None  | None  | None  |
# v15=0 | v1 =1 | v41=1 | v48=1 | v14=1 | v25=1 | v37=0 | v40=0 | v24=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 40.00%
#
# file: uf50-016.cnf, 16/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v34=1 | v18=0 | v26=1 | v40=0 | v49=1 | v10=1 | v38=1 | v16=0 | v45=1 | v35=0 | v24=1 | v48=1 |
# v41=1 | v42=1 | v27=0 | v4 =1 | v13=1 | v47=0 | v2 =0 | v44=1 | v46=0 | v15=0 | None  | None  |
# v9 =1 | v36=1 | v20=1 | v11=0 | v25=1 | v14=1 | v30=0 | v32=0 | v19=0 | v29=1 | None  | None  |
# v5 =0 | v37=0 | v1 =1 | v28=1 | v43=1 | v7 =0 | v17=1 | v3 =1 | v6 =0 | v31=0 | None  | None  |
# v8 =0 | None  | v39=1 | v33=1 | v23=0 | v0 =0 | v12=0 | v22=0 | v21=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 37.50%
#
# file: uf50-017.cnf, 17/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v31=0 | v35=0 | v4 =1 | v0 =0 | v44=1 | v38=1 | v32=0 | v43=1 | v47=0 | v3 =1 | v8 =0 | None  |
# v26=1 | v42=1 | v45=1 | v6 =0 | v5 =0 | v22=0 | v21=1 | v10=1 | v25=1 | v27=0 | v7 =0 | None  |
# v1 =1 | v41=1 | v28=1 | v48=1 | v29=1 | v37=0 | v36=1 | v17=1 | v40=0 | v14=1 | v12=0 | None  |
# v20=1 | v18=0 | v13=1 | v2 =0 | v15=0 | v23=0 | v11=0 | v30=0 | v16=0 | None  | None  | None  |
# None  | v33=1 | v19=0 | v24=1 | v46=0 | v39=1 | v49=1 | v34=1 | v9 =1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 35.29%
#
# file: uf50-018.cnf, 18/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v11=0 | v20=1 | v38=1 | v9 =1 | v1 =1 | v2 =0 | v22=0 | v21=1 | v0 =0 | v3 =1 | v45=1 | None  |
# v48=1 | v46=0 | v24=1 | v49=1 | v47=0 | v32=0 | v36=1 | v16=0 | v44=1 | v29=1 | v5 =0 | None  |
# v37=0 | v39=1 | v41=1 | v40=0 | v8 =0 | v4 =1 | v35=0 | v6 =0 | v43=1 | v26=1 | None  | None  |
# v18=0 | v12=0 | v31=0 | v28=1 | v33=1 | v27=0 | v10=1 | v7 =0 | v34=1 | v13=1 | None  | None  |
# v30=0 | None  | v42=1 | v25=1 | v19=0 | v23=0 | v17=1 | v14=1 | None  | v15=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-019.cnf, 19/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 22
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v48=1 | v26=1 | v17=1 | v23=0 | v12=0 | v10=1 | v7 =0 | v15=0 | v29=1 | v13=1 | None  | None  |
# v38=1 | v35=0 | v4 =1 | v11=0 | v47=0 | v36=1 | v25=1 | v28=1 | v27=0 | v44=1 | None  | None  |
# v37=0 | v18=0 | v0 =0 | v49=1 | v19=0 | v8 =0 | v22=0 | v24=1 | v46=0 | v33=1 | None  | None  |
# v21=1 | v40=0 | v14=1 | v41=1 | v30=0 | v5 =0 | v42=1 | v6 =0 | v45=1 | v20=1 | None  | None  |
# v31=0 | v43=1 | v1 =1 | v9 =1 | v16=0 | v34=1 | v2 =0 | v39=1 | v32=0 | v3 =1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 31.58%
#
# file: uf50-020.cnf, 20/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 27
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v41=1 | v21=1 | v19=0 | v6 =0 | v2 =0 | v37=0 | v46=0 | v25=1 | v3 =1 | v33=1 | v10=1 | None  |
# v40=0 | v28=1 | v36=1 | v30=0 | v47=0 | v18=0 | v14=1 | v35=0 | v34=1 | v32=0 | v9 =1 | None  |
# v27=0 | v42=1 | v20=1 | v49=1 | v8 =0 | v7 =0 | v11=0 | v4 =1 | v43=1 | v22=0 | v45=1 | None  |
# v15=0 | v48=1 | v29=1 | v39=1 | v44=1 | v23=0 | v17=1 | v1 =1 | v24=1 | v12=0 | None  | None  |
# v26=1 | None  | v0 =0 | v38=1 | v5 =0 | None  | v31=0 | v16=0 | None  | v13=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 10
# Current Solvability: 35.00%
#
# file: uf50-021.cnf, 21/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v35=0 | v40=0 | v49=1 | v48=1 | v4 =1 | v11=0 | v45=1 | v21=1 | v6 =0 | v36=1 | None  | None  |
# v31=0 | v29=1 | v22=0 | v20=1 | v33=1 | v38=1 | v1 =1 | v43=1 | v10=1 | v30=0 | None  | None  |
# v32=0 | v9 =1 | v39=1 | v17=1 | v47=0 | v13=1 | v2 =0 | v25=1 | v41=1 | v19=0 | None  | None  |
# v27=0 | v23=0 | v34=1 | v26=1 | v0 =0 | v37=0 | v18=0 | v3 =1 | v8 =0 | v15=0 | None  | None  |
# v14=1 | v28=1 | v42=1 | v16=0 | v46=0 | v12=0 | v7 =0 | v44=1 | v5 =0 | v24=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-022.cnf, 22/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v37=0 | v41=1 | v22=0 | v13=1 | v0 =0 | v40=0 | v23=0 | v36=1 | v12=0 | v16=0 | v39=1 | None  |
# v14=1 | v31=0 | v24=1 | v2 =0 | v28=1 | v8 =0 | v19=0 | v5 =0 | v3 =1 | v25=1 | None  | None  |
# v26=1 | v4 =1 | v34=1 | v32=0 | v45=1 | v20=1 | v49=1 | v47=0 | v21=1 | v6 =0 | None  | None  |
# v44=1 | v43=1 | v46=0 | v35=0 | v27=0 | v38=1 | v15=0 | v48=1 | v9 =1 | v7 =0 | None  | None  |
# v30=0 | v33=1 | v29=1 | v1 =1 | v11=0 | v10=1 | v42=1 | v17=1 | v18=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 31.82%
#
# file: uf50-023.cnf, 23/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v35=0 | v27=0 | v43=1 | v49=1 | v37=0 | v13=1 | v30=0 | v17=1 | v34=1 | v32=0 | v14=1 | None  |
# v42=1 | v38=1 | v26=1 | v28=1 | v15=0 | v47=0 | v6 =0 | v8 =0 | v45=1 | v40=0 | v21=1 | None  |
# v22=0 | v41=1 | v4 =1 | v0 =0 | v39=1 | v36=1 | v5 =0 | v7 =0 | v25=1 | v3 =1 | None  | None  |
# v48=1 | v44=1 | v16=0 | v46=0 | v31=0 | v20=1 | v29=1 | v33=1 | v19=0 | v24=1 | None  | None  |
# None  | v23=0 | v9 =1 | None  | v11=0 | v18=0 | v2 =0 | v10=1 | v1 =1 | v12=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 34.78%
#
# file: uf50-024.cnf, 24/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v12=0 | v38=1 | v9 =1 | v8 =0 | v27=0 | v37=0 | v33=1 | v25=1 | v36=1 | v6 =0 | None  |
# v48=1 | v43=1 | v20=1 | v46=0 | v21=1 | v31=0 | v15=0 | v39=1 | v17=1 | v11=0 | v13=1 | None  |
# v41=1 | v1 =1 | v5 =0 | v34=1 | v49=1 | v40=0 | v16=0 | v0 =0 | v3 =1 | v10=1 | None  | None  |
# v22=0 | v32=0 | v29=1 | v35=0 | v42=1 | v26=1 | v2 =0 | v44=1 | v14=1 | v28=1 | None  | None  |
# v24=1 | v47=0 | v18=0 | v4 =1 | v19=0 | v30=0 | v23=0 | v7 =0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-025.cnf, 25/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v47=0 | v11=0 | v46=0 | v39=1 | v28=1 | v0 =0 | v16=0 | v49=1 | v14=1 | v34=1 | v36=1 |
# v2 =0 | v21=1 | v5 =0 | v23=0 | v18=0 | v32=0 | v3 =1 | v37=0 | v43=1 | v38=1 | v17=1 | None  |
# v45=1 | v40=0 | v7 =0 | v35=0 | v31=0 | v6 =0 | v33=1 | v15=0 | v29=1 | v9 =1 | None  | None  |
# v10=1 | v44=1 | v22=0 | v1 =1 | v48=1 | v4 =1 | v19=0 | v8 =0 | v27=0 | v41=1 | None  | None  |
# v13=1 | v25=1 | v26=1 | None  | v30=0 | v42=1 | None  | v24=1 | v20=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 32.00%
#
# file: uf50-026.cnf, 26/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 31
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v35=0 | v12=0 | v2 =0 | v31=0 | v48=1 | v46=0 | v15=0 | v14=1 | v17=1 | v10=1 | v11=0 | None  |
# v38=1 | v7 =0 | v4 =1 | v42=1 | v20=1 | v36=1 | v49=1 | v40=0 | v37=0 | v16=0 | None  | None  |
# v22=0 | v47=0 | v1 =1 | v39=1 | v9 =1 | v43=1 | v27=0 | v34=1 | v13=1 | v0 =0 | None  | None  |
# v18=0 | v19=0 | v33=1 | v8 =0 | v29=1 | v24=1 | v21=1 | v32=0 | v30=0 | v23=0 | None  | None  |
# v6 =0 | v41=1 | v26=1 | v5 =0 | v44=1 | v28=1 | v3 =1 | v45=1 | v25=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.77%
#
# file: uf50-027.cnf, 27/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v42=1 | v32=0 | v18=0 | v19=0 | v12=0 | v2 =0 | v23=0 | v36=1 | v33=1 | v47=0 | v31=0 | None  |
# v38=1 | v17=1 | v15=0 | v11=0 | v39=1 | v46=0 | v3 =1 | v10=1 | v5 =0 | v27=0 | v22=0 | None  |
# v49=1 | v26=1 | v8 =0 | v0 =0 | v40=0 | v7 =0 | v43=1 | v45=1 | v44=1 | v25=1 | None  | None  |
# v41=1 | v6 =0 | v28=1 | v20=1 | v9 =1 | v21=1 | v16=0 | v24=1 | v48=1 | v35=0 | None  | None  |
# None  | v1 =1 | v37=0 | v13=1 | v4 =1 | v14=1 | v29=1 | v30=0 | v34=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 33.33%
#
# file: uf50-028.cnf, 28/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v0 =0 | v4 =1 | v18=0 | v5 =0 | v43=1 | v11=0 | v47=0 | v3 =1 | v28=1 | v12=0 | v17=1 | None  |
# v33=1 | v42=1 | v7 =0 | v16=0 | v30=0 | v45=1 | v9 =1 | v46=0 | v38=1 | v2 =0 | v22=0 | None  |
# v48=1 | v29=1 | v36=1 | v44=1 | v25=1 | v34=1 | v31=0 | v20=1 | v19=0 | v1 =1 | None  | None  |
# v41=1 | v26=1 | v37=0 | v13=1 | v32=0 | v21=1 | v14=1 | v6 =0 | v24=1 | v39=1 | None  | None  |
# None  | v23=0 | None  | v40=0 | v10=1 | v15=0 | v49=1 | v8 =0 | v35=0 | v27=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 32.14%
#
# file: uf50-029.cnf, 29/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 35
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v41=1 | v22=0 | v17=1 | v48=1 | v25=1 | v38=1 | v35=0 | v16=0 | v20=1 | v29=1 | v43=1 | v46=0 |
# v24=1 | v3 =1 | v0 =0 | v36=1 | v12=0 | v8 =0 | v9 =1 | v44=1 | v39=1 | v27=0 | v15=0 | None  |
# v49=1 | v28=1 | v32=0 | v18=0 | v23=0 | v1 =1 | v45=1 | v10=1 | v7 =0 | v13=1 | None  | None  |
# v31=0 | v14=1 | v26=1 | v33=1 | v6 =0 | v37=0 | v42=1 | v4 =1 | v5 =0 | None  | None  | None  |
# v34=1 | v11=0 | v47=0 | v40=0 | v21=1 | v2 =0 | v19=0 | None  | v30=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 34.48%
#
# file: uf50-030.cnf, 30/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v24=1 | v46=0 | v9 =1 | v40=0 | v27=0 | v17=1 | v19=0 | v22=0 | v45=1 | v4 =1 | v8 =0 | v10=1 |
# v42=1 | v36=1 | v7 =0 | v38=1 | v29=1 | v11=0 | v20=1 | v25=1 | v31=0 | v0 =0 | v6 =0 | v21=1 |
# v26=1 | v30=0 | v49=1 | v28=1 | v23=0 | v43=1 | v35=0 | v18=0 | v14=1 | v15=0 | None  | None  |
# v3 =1 | v48=1 | v33=1 | v5 =0 | v39=1 | v32=0 | v16=0 | v2 =0 | None  | None  | None  | None  |
# v47=0 | v13=1 | v37=0 | v1 =1 | v34=1 | v41=1 | v12=0 | v44=1 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-031.cnf, 31/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 20
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v42=1 | v20=1 | v30=0 | v45=1 | v39=1 | v47=0 | v5 =0 | v41=1 | v34=1 | v18=0 | v9 =1 | None  |
# v15=0 | v0 =0 | v40=0 | v33=1 | v14=1 | v36=1 | v44=1 | v31=0 | v8 =0 | v48=1 | None  | None  |
# v21=1 | v26=1 | v3 =1 | v46=0 | v4 =1 | v28=1 | v27=0 | v29=1 | v35=0 | v22=0 | None  | None  |
# v25=1 | v17=1 | v12=0 | v7 =0 | v38=1 | v49=1 | v6 =0 | v16=0 | v23=0 | v37=0 | None  | None  |
# v43=1 | v1 =1 | v13=1 | v2 =0 | v32=0 | v10=1 | v24=1 | v19=0 | v11=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 32.26%
#
# file: uf50-032.cnf, 32/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =1 | v34=1 | v48=1 | v25=1 | v11=0 | v23=0 | v0 =0 | v39=1 | v30=0 | v38=1 | v49=1 | None  |
# v43=1 | v44=1 | v24=1 | v45=1 | v33=1 | v8 =0 | v1 =1 | v20=1 | v41=1 | v42=1 | v47=0 | None  |
# v32=0 | v35=0 | v26=1 | v21=1 | v4 =1 | v22=0 | v13=1 | v19=0 | v40=0 | None  | v28=1 | None  |
# v17=1 | v14=1 | v12=0 | v27=0 | v31=0 | v5 =0 | v18=0 | v36=1 | v29=1 | None  | None  | None  |
# v7 =0 | v15=0 | v46=0 | v6 =0 | v37=0 | v3 =1 | v10=1 | v2 =0 | v16=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 31.25%
#
# file: uf50-033.cnf, 33/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v49=1 | v34=1 | v11=0 | v44=1 | v1 =1 | v42=1 | v22=0 | v48=1 | v27=0 | v26=1 | v9 =1 | None  |
# v46=0 | v33=1 | v19=0 | v3 =1 | v45=1 | v21=1 | v0 =0 | v29=1 | v16=0 | v2 =0 | v39=1 | None  |
# v40=0 | v14=1 | v25=1 | v37=0 | v13=1 | v20=1 | v8 =0 | v30=0 | v28=1 | v43=1 | None  | None  |
# v5 =0 | v24=1 | v15=0 | v36=1 | v41=1 | v23=0 | v7 =0 | v31=0 | v10=1 | v12=0 | None  | None  |
# None  | v18=0 | v17=1 | v32=0 | v38=1 | v47=0 | v6 =0 | v35=0 | v4 =1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.30%
#
# file: uf50-034.cnf, 34/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v36=1 | v40=0 | v39=1 | v41=1 | v16=0 | v45=1 | v10=1 | v24=1 | v46=0 | v2 =0 | v5 =0 | v18=0 |
# v4 =1 | v12=0 | v14=1 | v42=1 | v35=0 | v38=1 | v37=0 | v9 =1 | v0 =0 | v17=1 | v1 =1 | None  |
# v30=0 | v34=1 | v49=1 | v26=1 | v33=1 | v22=0 | v8 =0 | v48=1 | v31=0 | v23=0 | None  | None  |
# v13=1 | v47=0 | v43=1 | v28=1 | v44=1 | v29=1 | v3 =1 | v27=0 | v25=1 | v7 =0 | None  | None  |
# v21=1 | None  | None  | v20=1 | v32=0 | None  | v19=0 | v6 =0 | v11=0 | v15=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.41%
#
# file: uf50-035.cnf, 35/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v11=0 | v14=1 | v21=1 | v6 =0 | v28=1 | v4 =1 | v10=1 | v2 =0 | v23=0 | v31=0 | v38=1 | v24=1 |
# v18=0 | v3 =1 | v27=0 | v13=1 | v19=0 | v43=1 | v9 =1 | v8 =0 | v17=1 | v7 =0 | v37=0 | None  |
# v12=0 | v30=0 | v16=0 | v46=0 | v47=0 | v35=0 | v20=1 | v48=1 | v1 =1 | v42=1 | None  | None  |
# v22=0 | v5 =0 | v32=0 | v29=1 | v41=1 | v33=1 | v26=1 | v15=0 | v49=1 | None  | None  | None  |
# None  | v0 =0 | v39=1 | v25=1 | v40=0 | v45=1 | v44=1 | v36=1 | v34=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 28.57%
#
# file: uf50-036.cnf, 36/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 18
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v46=0 | v29=1 | v9 =1 | v24=1 | v39=1 | v21=1 | v41=1 | v2 =0 | v1 =1 | v42=1 | v3 =1 | None  |
# v47=0 | v31=0 | v7 =0 | v5 =0 | v49=1 | v15=0 | v38=1 | v44=1 | v33=1 | v40=0 | None  | None  |
# v10=1 | v48=1 | v19=0 | v27=0 | v32=0 | v11=0 | v16=0 | v18=0 | v36=1 | v8 =0 | None  | None  |
# v26=1 | v37=0 | v14=1 | v23=0 | v20=1 | v13=1 | v43=1 | v22=0 | v34=1 | v30=0 | None  | None  |
# v45=1 | v28=1 | v12=0 | v35=0 | v17=1 | v25=1 | v0 =0 | v6 =0 | None  | v4 =1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 4
# Current Solvability: 30.56%
#
# file: uf50-037.cnf, 37/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v43=1 | v33=1 | v14=1 | v28=1 | v12=0 | v13=1 | v32=0 | v40=0 | v15=0 | v19=0 | v41=1 | None  |
# v11=0 | v44=1 | v34=1 | v9 =1 | v45=1 | v1 =1 | v47=0 | v46=0 | v10=1 | v5 =0 | v31=0 | None  |
# v26=1 | v35=0 | v24=1 | v16=0 | v42=1 | v36=1 | v18=0 | v8 =0 | v23=0 | v21=1 | None  | None  |
# v4 =1 | v22=0 | v39=1 | v38=1 | v30=0 | v25=1 | v37=0 | v29=1 | v20=1 | None  | None  | None  |
# v2 =0 | v17=1 | v3 =1 | v27=0 | v7 =0 | v49=1 | v6 =0 | v48=1 | v0 =0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.73%
#
# file: uf50-038.cnf, 38/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v41=1 | v12=0 | v39=1 | v48=1 | v16=0 | v31=0 | v25=1 | v30=0 | v11=0 | v2 =0 | v45=1 | None  |
# v19=0 | v35=0 | v24=1 | v20=1 | v23=0 | v21=1 | v36=1 | v26=1 | v42=1 | v33=1 | None  | None  |
# v32=0 | v47=0 | v22=0 | v1 =1 | v17=1 | v27=0 | v37=0 | v4 =1 | v15=0 | v18=0 | None  | None  |
# v14=1 | v43=1 | v40=0 | v8 =0 | v5 =0 | v28=1 | v34=1 | v44=1 | v38=1 | v13=1 | None  | None  |
# v29=1 | v9 =1 | v10=1 | v49=1 | v3 =1 | v7 =0 | v46=0 | v0 =0 | v6 =0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 28.95%
#
# file: uf50-039.cnf, 39/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v31=0 | v23=0 | v14=1 | v3 =1 | v46=0 | v36=1 | v11=0 | v26=1 | v18=0 | v37=0 | v41=1 | None  |
# v29=1 | v43=1 | v10=1 | v1 =1 | v48=1 | v24=1 | v5 =0 | v9 =1 | v34=1 | v19=0 | None  | None  |
# v44=1 | v42=1 | v2 =0 | v40=0 | v35=0 | v8 =0 | v4 =1 | v39=1 | v47=0 | v38=1 | None  | None  |
# v15=0 | v0 =0 | v32=0 | v16=0 | v25=1 | v7 =0 | v45=1 | v21=1 | v30=0 | v27=0 | None  | None  |
# v20=1 | None  | v28=1 | v12=0 | v49=1 | v33=1 | v13=1 | v6 =0 | v22=0 | v17=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 30.77%
#
# file: uf50-040.cnf, 40/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v10=1 | v35=0 | v2 =0 | v36=1 | v7 =0 | v9 =1 | v22=0 | v11=0 | v0 =0 | v46=0 | v16=0 | None  |
# v31=0 | v24=1 | v45=1 | v43=1 | v21=1 | v48=1 | v4 =1 | v44=1 | v20=1 | v26=1 | None  | None  |
# v41=1 | v30=0 | v23=0 | v13=1 | v40=0 | v3 =1 | v29=1 | v1 =1 | v39=1 | v6 =0 | None  | None  |
# v28=1 | v42=1 | v12=0 | v15=0 | v14=1 | v19=0 | v27=0 | v8 =0 | v25=1 | v38=1 | None  | None  |
# v5 =0 | v34=1 | v33=1 | v49=1 | v47=0 | v32=0 | v17=1 | v37=0 | v18=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 32.50%
#
# file: uf50-041.cnf, 41/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 27
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v37=0 | v19=0 | v39=1 | v23=0 | v11=0 | v9 =1 | v3 =1 | v45=1 | v1 =1 | v18=0 | v5 =0 | None  |
# v21=1 | v4 =1 | v32=0 | v2 =0 | v48=1 | v49=1 | v20=1 | v27=0 | v35=0 | v25=1 | None  | None  |
# v38=1 | v28=1 | v41=1 | v43=1 | v33=1 | v10=1 | v17=1 | v14=1 | v24=1 | v46=0 | None  | None  |
# v47=0 | v6 =0 | v15=0 | v29=1 | v16=0 | v42=1 | v13=1 | v12=0 | v36=1 | v30=0 | None  | None  |
# v40=0 | v44=1 | v34=1 | v0 =0 | v31=0 | v26=1 | v22=0 | v8 =0 | None  | v7 =0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 31.71%
#
# file: uf50-042.cnf, 42/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 28
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v24=1 | v4 =1 | v2 =0 | v38=1 | v44=1 | v22=0 | v18=0 | v16=0 | v17=1 | v12=0 | v3 =1 | None  |
# v33=1 | v45=1 | v14=1 | v27=0 | v25=1 | v15=0 | v43=1 | v46=0 | v35=0 | v42=1 | v21=1 | None  |
# v5 =0 | v23=0 | v13=1 | v30=0 | v1 =1 | v28=1 | v9 =1 | v49=1 | v31=0 | v37=0 | v19=0 | None  |
# v41=1 | v32=0 | v47=0 | v48=1 | v34=1 | v8 =0 | v10=1 | v6 =0 | v36=1 | v0 =0 | None  | None  |
# None  | v20=1 | None  | None  | v40=0 | v7 =0 | v39=1 | v11=0 | v29=1 | v26=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 33.33%
#
# file: uf50-043.cnf, 43/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 36
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v24=1 | v32=0 | v25=1 | v30=0 | v12=0 | v13=1 | v9 =1 | v21=1 | v46=0 | v48=1 | v18=0 | None  |
# v16=0 | v11=0 | v45=1 | v4 =1 | v7 =0 | v26=1 | v47=0 | v2 =0 | v40=0 | v37=0 | v33=1 | None  |
# v5 =0 | v43=1 | v34=1 | v28=1 | v35=0 | v31=0 | v44=1 | v19=0 | v22=0 | v41=1 | None  | None  |
# v14=1 | v20=1 | v38=1 | v10=1 | v42=1 | v1 =1 | v15=0 | v39=1 | v23=0 | v49=1 | None  | None  |
# v36=1 | v0 =0 | v6 =0 | v17=1 | v27=0 | v8 =0 | None  | None  | v3 =1 | v29=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 34.88%
#
# file: uf50-044.cnf, 44/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v1 =1 | v7 =0 | v10=1 | v34=1 | v28=1 | v8 =0 | v2 =0 | v27=0 | v45=1 | v13=1 | None  |
# v31=0 | v23=0 | v19=0 | v39=1 | v33=1 | v26=1 | v3 =1 | v42=1 | v15=0 | v43=1 | v5 =0 | None  |
# v12=0 | v29=1 | v16=0 | v41=1 | v49=1 | v25=1 | v47=0 | v40=0 | v4 =1 | v36=1 | v48=1 | None  |
# v46=0 | v17=1 | v11=0 | None  | v44=1 | v37=0 | v14=1 | v38=1 | v32=0 | v24=1 | v35=0 | None  |
# v22=0 | None  | v21=1 | None  | None  | v30=0 | v9 =1 | v0 =0 | v20=1 | v6 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 36.36%
#
# file: uf50-045.cnf, 45/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v21=1 | v46=0 | v47=0 | v25=1 | v2 =0 | v34=1 | v20=1 | v29=1 | v1 =1 | v7 =0 | v36=1 | v0 =0 |
# v17=1 | v18=0 | v41=1 | v13=1 | v49=1 | v42=1 | v32=0 | v8 =0 | v3 =1 | v48=1 | v39=1 | None  |
# v6 =0 | v22=0 | v11=0 | v9 =1 | v28=1 | v24=1 | v23=0 | v14=1 | v43=1 | v30=0 | None  | None  |
# v26=1 | v15=0 | v45=1 | v4 =1 | v31=0 | v38=1 | v12=0 | v19=0 | v40=0 | v5 =0 | None  | None  |
# v35=0 | None  | v33=1 | None  | v37=0 | v44=1 | v16=0 | v27=0 | None  | v10=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 35.56%
#
# file: uf50-046.cnf, 46/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 17
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v49=1 | v25=1 | v14=1 | v27=0 | v12=0 | v41=1 | v35=0 | v21=1 | v26=1 | v10=1 | v1 =1 | None  |
# v6 =0 | v15=0 | v5 =0 | v24=1 | v32=0 | v37=0 | v19=0 | v7 =0 | v23=0 | v17=1 | v46=0 | None  |
# v20=1 | v28=1 | v47=0 | v0 =0 | v13=1 | v3 =1 | v36=1 | v22=0 | v9 =1 | v4 =1 | None  | None  |
# v38=1 | v40=0 | v43=1 | v2 =0 | v31=0 | v39=1 | v42=1 | v11=0 | v16=0 | v34=1 | None  | None  |
# None  | v45=1 | v18=0 | v48=1 | None  | v30=0 | v33=1 | v8 =0 | v44=1 | v29=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 34.78%
#
# file: uf50-047.cnf, 47/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v40=0 | v41=1 | v31=0 | v19=0 | v49=1 | v27=0 | v13=1 | v5 =0 | v6 =0 | v21=1 | v33=1 | None  |
# v9 =1 | v22=0 | v34=1 | v16=0 | v46=0 | v25=1 | v44=1 | v39=1 | v42=1 | v36=1 | None  | None  |
# v18=0 | v35=0 | v12=0 | v24=1 | v37=0 | v17=1 | v26=1 | v11=0 | v47=0 | v4 =1 | None  | None  |
# v15=0 | v14=1 | v10=1 | v8 =0 | v20=1 | v45=1 | v43=1 | v48=1 | v23=0 | v32=0 | None  | None  |
# v29=1 | v0 =0 | v28=1 | v7 =0 | v30=0 | v2 =0 | v38=1 | None  | v3 =1 | v1 =1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 34.04%
#
# file: uf50-048.cnf, 48/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 28
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =0 | v10=1 | v19=0 | v9 =1 | v41=1 | v36=1 | v40=0 | v25=1 | v16=0 | v27=0 | v30=0 | None  |
# v35=0 | v47=0 | v1 =1 | v38=1 | v29=1 | v11=0 | v23=0 | v39=1 | v45=1 | v42=1 | v7 =0 | None  |
# v18=0 | v20=1 | v33=1 | v48=1 | v0 =0 | v31=0 | v21=1 | v28=1 | v37=0 | v24=1 | None  | None  |
# v17=1 | v26=1 | v5 =0 | v44=1 | v46=0 | v22=0 | v15=0 | v34=1 | v32=0 | v13=1 | None  | None  |
# v3 =1 | v2 =0 | v49=1 | v14=1 | v43=1 | None  | v4 =1 | v6 =0 | v12=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 33.33%
#
# file: uf50-049.cnf, 49/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v29=1 | v20=1 | v49=1 | v42=1 | v21=1 | v7 =0 | v22=0 | v6 =0 | v14=1 | v37=0 | v33=1 | None  |
# v39=1 | v17=1 | v25=1 | v44=1 | v8 =0 | v47=0 | v48=1 | v15=0 | v40=0 | v27=0 | v26=1 | None  |
# v41=1 | v32=0 | v23=0 | v34=1 | v18=0 | v4 =1 | v19=0 | v31=0 | v38=1 | v28=1 | None  | None  |
# v2 =0 | v30=0 | v43=1 | v16=0 | v13=1 | v0 =0 | v3 =1 | v11=0 | v10=1 | None  | None  | None  |
# v5 =0 | v36=1 | v9 =1 | v1 =1 | v45=1 | v46=0 | v35=0 | v24=1 | v12=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 5
# Current Solvability: 34.69%
#
# file: uf50-050.cnf, 50/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v42=1 | v37=0 | v39=1 | v27=0 | v45=1 | v44=1 | v35=0 | v22=0 | v10=1 | v29=1 | v30=0 | None  |
# v7 =0 | v16=0 | v9 =1 | v38=1 | v0 =0 | v33=1 | v34=1 | v48=1 | v26=1 | v23=0 | v6 =0 | None  |
# v11=0 | v47=0 | v40=0 | v2 =0 | v43=1 | v1 =1 | v17=1 | v21=1 | v25=1 | v18=0 | None  | None  |
# v19=0 | v49=1 | v13=1 | v32=0 | v12=0 | v20=1 | v41=1 | v8 =0 | v3 =1 | v46=0 | None  | None  |
# v28=1 | v5 =0 | v4 =1 | v31=0 | v24=1 | v14=1 | v15=0 | v36=1 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 34.00%
#
# file: uf50-051.cnf, 51/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 27
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v11=0 | v40=0 | v46=0 | v43=1 | v0 =0 | v45=1 | v38=1 | v41=1 | v12=0 | v1 =1 | v20=1 | None  |
# v49=1 | v4 =1 | v31=0 | v47=0 | v14=1 | v2 =0 | v17=1 | v36=1 | v3 =1 | v25=1 | v24=1 | None  |
# v13=1 | v29=1 | v27=0 | v5 =0 | v35=0 | v37=0 | v10=1 | v23=0 | v21=1 | v22=0 | None  | None  |
# v32=0 | v28=1 | v26=1 | v30=0 | v19=0 | v9 =1 | v42=1 | v6 =0 | v16=0 | v18=0 | None  | None  |
# v33=1 | v34=1 | v44=1 | v39=1 | v7 =0 | None  | v8 =0 | v48=1 | v15=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 33.33%
#
# file: uf50-052.cnf, 52/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v38=1 | v12=0 | v13=1 | v36=1 | v23=0 | v15=0 | v47=0 | v37=0 | v21=1 | v6 =0 | None  |
# v19=0 | v16=0 | v34=1 | v41=1 | v20=1 | v14=1 | v7 =0 | v31=0 | v24=1 | v10=1 | None  | None  |
# v28=1 | v26=1 | v25=1 | v22=0 | v42=1 | v32=0 | v11=0 | v33=1 | v35=0 | v17=1 | None  | None  |
# v39=1 | v8 =0 | v49=1 | v9 =1 | v18=0 | v40=0 | v5 =0 | v2 =0 | v48=1 | v44=1 | None  | None  |
# v46=0 | v1 =1 | v27=0 | v0 =0 | v3 =1 | v4 =1 | v30=0 | v29=1 | v43=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 32.69%
#
# file: uf50-053.cnf, 53/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 34
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =1 | v23=0 | v21=1 | v7 =0 | v27=0 | v3 =1 | v11=0 | v6 =0 | v9 =1 | v24=1 | v14=1 | None  |
# v8 =0 | v4 =1 | v47=0 | v17=1 | v48=1 | v43=1 | v45=1 | v41=1 | v36=1 | v15=0 | v30=0 | None  |
# v35=0 | v12=0 | v26=1 | v31=0 | v33=1 | v13=1 | v28=1 | v34=1 | v22=0 | v42=1 | None  | None  |
# v32=0 | v10=1 | v39=1 | v37=0 | v5 =0 | v29=1 | v49=1 | v20=1 | v16=0 | v0 =0 | None  | None  |
# v2 =0 | v44=1 | v40=0 | v25=1 | v38=1 | v46=0 | v18=0 | v19=0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 32.08%
#
# file: uf50-054.cnf, 54/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 30
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v37=0 | v16=0 | v11=0 | v29=1 | v49=1 | v19=0 | v8 =0 | v5 =0 | v35=0 | v31=0 | v47=0 | None  |
# v41=1 | v2 =0 | v1 =1 | v14=1 | v24=1 | v7 =0 | v40=0 | v36=1 | v13=1 | v48=1 | v46=0 | None  |
# v17=1 | v28=1 | v32=0 | v45=1 | v4 =1 | v33=1 | v9 =1 | v27=0 | v26=1 | v38=1 | None  | None  |
# v0 =0 | v15=0 | v39=1 | v20=1 | v6 =0 | v30=0 | v25=1 | v23=0 | v3 =1 | v22=0 | None  | None  |
# None  | v18=0 | v42=1 | v21=1 | v44=1 | v10=1 | v12=0 | v43=1 | None  | v34=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 31.48%
#
# file: uf50-055.cnf, 55/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v7 =0 | v26=1 | v24=1 | v37=0 | v17=1 | v42=1 | v31=0 | v32=0 | v44=1 | v49=1 | None  |
# v18=0 | v16=0 | v14=1 | v15=0 | v9 =1 | v1 =1 | v21=1 | v29=1 | v2 =0 | v27=0 | v28=1 | None  |
# v0 =0 | v20=1 | v39=1 | v8 =0 | v34=1 | v38=1 | v25=1 | v10=1 | v11=0 | v40=0 | None  | None  |
# v33=1 | v13=1 | v47=0 | v22=0 | v23=0 | v35=0 | v12=0 | v41=1 | v3 =1 | None  | None  | None  |
# v46=0 | v43=1 | v5 =0 | v6 =0 | v4 =1 | v48=1 | v30=0 | v36=1 | v45=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.91%
#
# file: uf50-056.cnf, 56/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 34
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v42=1 | v41=1 | v28=1 | v35=0 | v8 =0 | v33=1 | v31=0 | v14=1 | v36=1 | v9 =1 | v3 =1 | None  |
# v38=1 | v32=0 | v19=0 | v43=1 | v37=0 | v24=1 | v0 =0 | v5 =0 | v2 =0 | v12=0 | None  | None  |
# v20=1 | v1 =1 | v22=0 | v13=1 | v44=1 | v18=0 | v10=1 | v39=1 | v34=1 | v11=0 | None  | None  |
# v45=1 | v47=0 | v26=1 | v48=1 | v46=0 | v7 =0 | v6 =0 | v16=0 | v25=1 | v21=1 | None  | None  |
# v29=1 | v40=0 | v23=0 | v30=0 | v49=1 | v4 =1 | v27=0 | v17=1 | None  | v15=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.36%
#
# file: uf50-057.cnf, 57/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 24
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v20=1 | v19=0 | v31=0 | v18=0 | v16=0 | v6 =0 | v27=0 | v8 =0 | v48=1 | v32=0 | v17=1 | None  |
# v15=0 | v25=1 | v29=1 | v42=1 | v39=1 | v47=0 | v10=1 | v44=1 | v3 =1 | v26=1 | None  | None  |
# v2 =0 | v33=1 | v34=1 | v49=1 | v1 =1 | v4 =1 | v28=1 | v46=0 | v22=0 | v0 =0 | None  | None  |
# v41=1 | v24=1 | v23=0 | v43=1 | v40=0 | v7 =0 | v45=1 | v21=1 | v30=0 | v9 =1 | None  | None  |
# v35=0 | v14=1 | v5 =0 | v38=1 | v13=1 | None  | v36=1 | v12=0 | v11=0 | v37=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.82%
#
# file: uf50-058.cnf, 58/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v32=0 | v30=0 | v17=1 | v44=1 | v26=1 | v6 =0 | v8 =0 | v43=1 | v19=0 | v10=1 | None  |
# v49=1 | v45=1 | v28=1 | v47=0 | v20=1 | v12=0 | v0 =0 | v35=0 | v11=0 | v41=1 | v38=1 | None  |
# v27=0 | v21=1 | v1 =1 | v39=1 | v40=0 | v37=0 | v22=0 | v14=1 | v33=1 | v25=1 | None  | None  |
# v23=0 | v34=1 | v16=0 | v46=0 | v42=1 | v5 =0 | v18=0 | v2 =0 | v24=1 | v9 =1 | None  | None  |
# v48=1 | v4 =1 | v31=0 | v36=1 | v29=1 | v3 =1 | v13=1 | None  | None  | v7 =0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.31%
#
# file: uf50-059.cnf, 59/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =1 | v27=0 | v32=0 | v43=1 | v15=0 | v14=1 | v37=0 | v5 =0 | v22=0 | v34=1 | v10=1 | None  |
# v33=1 | v41=1 | v30=0 | v39=1 | v25=1 | v44=1 | v9 =1 | v35=0 | v29=1 | v13=1 | None  | None  |
# v26=1 | v21=1 | v36=1 | v48=1 | v45=1 | v17=1 | v47=0 | v20=1 | v12=0 | v6 =0 | None  | None  |
# v2 =0 | v42=1 | v40=0 | v49=1 | v31=0 | v38=1 | v19=0 | v11=0 | v16=0 | v3 =1 | None  | None  |
# None  | v46=0 | v7 =0 | v0 =0 | v18=0 | v28=1 | v4 =1 | v23=0 | v24=1 | v8 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 3
# Current Solvability: 30.51%
#
# file: uf50-060.cnf, 60/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 25
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v49=1 | v46=0 | v9 =1 | v21=1 | v0 =0 | v6 =0 | v34=1 | v48=1 | v1 =1 | v7 =0 | v3 =1 | None  |
# v39=1 | v33=1 | v8 =0 | v42=1 | v35=0 | v2 =0 | v41=1 | v47=0 | v15=0 | v20=1 | v24=1 | None  |
# v38=1 | v14=1 | v5 =0 | v18=0 | v45=1 | v43=1 | v19=0 | v17=1 | v26=1 | v25=1 | None  | None  |
# v13=1 | v37=0 | v27=0 | v29=1 | v32=0 | v44=1 | v11=0 | v16=0 | v23=0 | None  | None  | None  |
# v36=1 | v31=0 | v30=0 | v4 =1 | v12=0 | v28=1 | v22=0 | v40=0 | v10=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.00%
#
# file: uf50-061.cnf, 61/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 28
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v0 =0 | v36=1 | v45=1 | v43=1 | v21=1 | v39=1 | v29=1 | v6 =0 | v32=0 | v10=1 | v8 =0 | None  |
# v42=1 | v15=0 | v22=0 | v38=1 | v16=0 | v25=1 | v12=0 | v11=0 | v34=1 | v37=0 | v13=1 | None  |
# v49=1 | v27=0 | v14=1 | v44=1 | v35=0 | v31=0 | v26=1 | v40=0 | v28=1 | v20=1 | None  | None  |
# v30=0 | v17=1 | v33=1 | v48=1 | v4 =1 | v9 =1 | v3 =1 | v19=0 | v24=1 | None  | None  | None  |
# v46=0 | v41=1 | v5 =0 | v23=0 | v1 =1 | v7 =0 | v2 =0 | v47=0 | v18=0 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 3
# Current Solvability: 29.51%
#
# file: uf50-062.cnf, 62/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 22
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v32=0 | v6 =0 | v29=1 | v21=1 | v0 =0 | v3 =1 | v30=0 | v45=1 | v5 =0 | v9 =1 | v8 =0 | None  |
# v49=1 | v11=0 | v46=0 | v28=1 | v48=1 | v43=1 | v37=0 | v22=0 | v24=1 | v7 =0 | None  | None  |
# v34=1 | v44=1 | v23=0 | v18=0 | v10=1 | v20=1 | v39=1 | v4 =1 | v36=1 | v38=1 | None  | None  |
# v41=1 | v26=1 | v31=0 | v17=1 | v14=1 | v15=0 | v1 =1 | v47=0 | v27=0 | v12=0 | None  | None  |
# ...
# v27=0 | v49=1 | v12=0 | v43=1 | v36=1 | v18=0 | v45=1 | v0 =0 | v32=0 | v25=1 | None  | None  |
# v47=0 | v2 =0 | v6 =0 | v39=1 | v35=0 | v1 =1 | v31=0 | v7 =0 | v16=0 | v19=0 | None  | None  |
# v38=1 | v48=1 | None  | v24=1 | None  | v11=0 | v41=1 | v4 =1 | v46=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 30.00%
#
# file: uf50-081.cnf, 81/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v26=1 | v16=0 | v23=0 | v29=1 | v33=1 | v18=0 | v13=1 | v15=0 | v9 =1 | v41=1 | v38=1 | None  |
# v34=1 | v3 =1 | v32=0 | v10=1 | v24=1 | v35=0 | v17=1 | v14=1 | v19=0 | v40=0 | None  | None  |
# v0 =0 | v44=1 | v12=0 | v45=1 | v8 =0 | v5 =0 | v22=0 | v2 =0 | v20=1 | v28=1 | None  | None  |
# v42=1 | v49=1 | v48=1 | v43=1 | v36=1 | v4 =1 | v11=0 | v6 =0 | v31=0 | v1 =1 | None  | None  |
# v30=0 | None  | v7 =0 | v25=1 | v21=1 | v46=0 | v39=1 | v27=0 | v47=0 | v37=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 30.86%
#
# file: uf50-082.cnf, 82/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 22
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v10=1 | v40=0 | v20=1 | v42=1 | v24=1 | v16=0 | v15=0 | v46=0 | v4 =1 | v35=0 | v25=1 | v11=0 |
# v21=1 | v9 =1 | v23=0 | v37=0 | v34=1 | v39=1 | v31=0 | v45=1 | v6 =0 | v12=0 | v19=0 | v29=1 |
# v8 =0 | v14=1 | v17=1 | v13=1 | v36=1 | v5 =0 | v27=0 | v49=1 | v1 =1 | v30=0 | None  | None  |
# v26=1 | v28=1 | v38=1 | v22=0 | v7 =0 | v41=1 | v0 =0 | v47=0 | v18=0 | None  | None  | None  |
# v43=1 | v48=1 | v3 =1 | v2 =0 | v32=0 | None  | None  | v44=1 | v33=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.49%
#
# file: uf50-083.cnf, 83/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v44=1 | v37=0 | v36=1 | v27=0 | v6 =0 | v38=1 | v30=0 | v13=1 | v26=1 | v33=1 | v3 =1 | None  |
# v16=0 | v21=1 | v23=0 | v7 =0 | v31=0 | v5 =0 | v48=1 | v1 =1 | v11=0 | v14=1 | v49=1 | None  |
# v10=1 | v47=0 | v19=0 | v0 =0 | v45=1 | v17=1 | v25=1 | v12=0 | v2 =0 | v32=0 | None  | None  |
# v20=1 | v8 =0 | v46=0 | v35=0 | v15=0 | v34=1 | v18=0 | v39=1 | v29=1 | None  | None  | None  |
# v28=1 | v24=1 | v40=0 | v22=0 | v43=1 | v4 =1 | v42=1 | v9 =1 | v41=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 5
# Current Solvability: 31.33%
#
# file: uf50-084.cnf, 84/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v2 =0 | v20=1 | v40=0 | v49=1 | v21=1 | v10=1 | v9 =1 | v8 =0 | v15=0 | v47=0 | None  |
# v7 =0 | v39=1 | v3 =1 | v0 =0 | v17=1 | v13=1 | v48=1 | v41=1 | v22=0 | v44=1 | v23=0 | None  |
# v35=0 | v33=1 | v14=1 | v30=0 | v43=1 | v27=0 | v42=1 | v16=0 | v11=0 | v24=1 | None  | None  |
# v6 =0 | v45=1 | v36=1 | v25=1 | v19=0 | v28=1 | v46=0 | v1 =1 | v18=0 | v29=1 | None  | None  |
# None  | v4 =1 | v38=1 | v31=0 | v34=1 | v5 =0 | None  | v37=0 | v26=1 | v32=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.95%
#
# file: uf50-085.cnf, 85/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 23
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v46=0 | v19=0 | v41=1 | v39=1 | v20=1 | v32=0 | v31=0 | v10=1 | v11=0 | v26=1 | v3 =1 | v17=1 |
# v27=0 | v49=1 | v25=1 | v24=1 | v12=0 | v42=1 | v29=1 | v6 =0 | v8 =0 | v18=0 | v4 =1 | None  |
# v43=1 | v44=1 | v35=0 | v34=1 | v30=0 | v48=1 | v0 =0 | v9 =1 | v22=0 | v5 =0 | None  | None  |
# v1 =1 | v33=1 | v7 =0 | v14=1 | v23=0 | v40=0 | v21=1 | v2 =0 | v36=1 | v38=1 | None  | None  |
# v47=0 | v45=1 | None  | v15=0 | v37=0 | v16=0 | v13=1 | None  | None  | v28=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 31.76%
#
# file: uf50-086.cnf, 86/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 20
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=1 | v8 =0 | v0 =0 | v14=1 | v11=0 | v25=1 | v36=1 | v20=1 | v4 =1 | v31=0 | v15=0 | None  |
# v49=1 | v22=0 | v43=1 | v17=1 | v10=1 | v44=1 | v42=1 | v35=0 | v33=1 | v27=0 | None  | None  |
# v29=1 | v9 =1 | v41=1 | v12=0 | v18=0 | v47=0 | v16=0 | v34=1 | v48=1 | v45=1 | None  | None  |
# v3 =1 | v40=0 | v26=1 | v23=0 | v32=0 | v46=0 | v30=0 | v28=1 | v21=1 | v5 =0 | None  | None  |
# v19=0 | v1 =1 | v24=1 | v7 =0 | v37=0 | v39=1 | v6 =0 | v2 =0 | v38=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 31.40%
#
# file: uf50-087.cnf, 87/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v31=0 | v41=1 | v8 =0 | v47=0 | v33=1 | v30=0 | v12=0 | v19=0 | v40=0 | v49=1 | v27=0 | v23=0 |
# v32=0 | v45=1 | v18=0 | v22=0 | v29=1 | v14=1 | v15=0 | v28=1 | v24=1 | v13=1 | None  | None  |
# v44=1 | v9 =1 | v38=1 | v48=1 | v21=1 | v2 =0 | v26=1 | v17=1 | v10=1 | v6 =0 | None  | None  |
# v46=0 | v42=1 | v3 =1 | v25=1 | v5 =0 | v4 =1 | v0 =0 | v1 =1 | v36=1 | v35=0 | None  | None  |
# v7 =0 | v43=1 | v39=1 | v37=0 | v34=1 | v20=1 | v11=0 | v16=0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 3
# Current Solvability: 31.03%
#
# file: uf50-088.cnf, 88/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 20
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v38=1 | v33=1 | v42=1 | v27=0 | v14=1 | v44=1 | v35=0 | v21=1 | v10=1 | v1 =1 | None  |
# v8 =0 | v0 =0 | v31=0 | v20=1 | v47=0 | v30=0 | v4 =1 | v19=0 | v9 =1 | v12=0 | v23=0 | None  |
# v29=1 | v48=1 | v6 =0 | v40=0 | v28=1 | v18=0 | v43=1 | v16=0 | v2 =0 | v11=0 | v17=1 | None  |
# v24=1 | v3 =1 | v49=1 | v32=0 | v13=1 | v15=0 | v41=1 | v46=0 | v34=1 | v45=1 | None  | None  |
# None  | v39=1 | v22=0 | v25=1 | v26=1 | v36=1 | v37=0 | v5 =0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 30.68%
#
# file: uf50-089.cnf, 89/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 30
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v45=1 | v11=0 | v0 =0 | v35=0 | v15=0 | v21=1 | v13=1 | v1 =1 | v30=0 | v7 =0 | v23=0 | None  |
# v38=1 | v33=1 | v43=1 | v6 =0 | v36=1 | v9 =1 | v34=1 | v32=0 | v26=1 | v39=1 | v25=1 | None  |
# v8 =0 | v49=1 | v41=1 | v28=1 | v12=0 | v20=1 | v42=1 | v27=0 | v46=0 | v24=1 | v44=1 | None  |
# v40=0 | v16=0 | v22=0 | v37=0 | v17=1 | v18=0 | v31=0 | v14=1 | v19=0 | None  | None  | None  |
# None  | v4 =1 | v5 =0 | v10=1 | v47=0 | v48=1 | v29=1 | v3 =1 | v2 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 11
# Current Solvability: 31.46%
#
# file: uf50-090.cnf, 90/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 26
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v29=1 | v13=1 | v47=0 | v48=1 | v16=0 | v22=0 | v37=0 | v14=1 | v32=0 | v0 =0 | v43=1 | None  |
# v33=1 | v7 =0 | v30=0 | v24=1 | v9 =1 | v1 =1 | v31=0 | v41=1 | v11=0 | v6 =0 | None  | None  |
# v27=0 | v49=1 | v34=1 | v17=1 | v4 =1 | v28=1 | v42=1 | v2 =0 | v39=1 | v45=1 | None  | None  |
# v36=1 | v26=1 | v5 =0 | v8 =0 | v3 =1 | v40=0 | v23=0 | v46=0 | v21=1 | v44=1 | None  | None  |
# v20=1 | v15=0 | v10=1 | v25=1 | v38=1 | v19=0 | v18=0 | None  | v12=0 | v35=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 31.11%
#
# file: uf50-091.cnf, 91/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 28
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v46=0 | v33=1 | v4 =1 | v37=0 | v16=0 | v32=0 | v29=1 | v13=1 | v40=0 | v7 =0 | v34=1 | None  |
# v31=0 | v20=1 | v5 =0 | v49=1 | v1 =1 | v19=0 | v18=0 | v44=1 | v15=0 | v47=0 | v0 =0 | None  |
# v48=1 | v11=0 | v22=0 | v23=0 | v17=1 | v28=1 | v30=0 | v35=0 | v9 =1 | v10=1 | None  | None  |
# v2 =0 | v26=1 | v27=0 | v8 =0 | v6 =0 | v41=1 | v38=1 | v12=0 | v43=1 | v45=1 | None  | None  |
# None  | v39=1 | None  | v3 =1 | v21=1 | v36=1 | v42=1 | v25=1 | v24=1 | v14=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.77%
#
# file: uf50-092.cnf, 92/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 30
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v45=1 | v25=1 | v18=0 | v13=1 | v15=0 | v7 =0 | v2 =0 | v1 =1 | v24=1 | v0 =0 | None  |
# v16=0 | v44=1 | v22=0 | v17=1 | v43=1 | v47=0 | v33=1 | v27=0 | v20=1 | v26=1 | None  | None  |
# v42=1 | v34=1 | v8 =0 | v40=0 | v29=1 | v37=0 | v36=1 | v23=0 | v49=1 | v4 =1 | None  | None  |
# v9 =1 | v28=1 | v41=1 | v48=1 | v11=0 | v46=0 | v21=1 | v10=1 | v14=1 | v3 =1 | None  | None  |
# None  | v39=1 | v30=0 | v19=0 | v38=1 | v32=0 | v35=0 | v5 =0 | v6 =0 | v31=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.43%
#
# file: uf50-093.cnf, 93/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 29
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =1 | v5 =0 | v23=0 | v36=1 | v31=0 | v15=0 | v13=1 | v1 =1 | v38=1 | v22=0 | v25=1 | None  |
# v41=1 | v34=1 | v45=1 | v43=1 | v29=1 | v14=1 | v32=0 | v11=0 | v6 =0 | v47=0 | None  | None  |
# v27=0 | v20=1 | v44=1 | v24=1 | v35=0 | v18=0 | v10=1 | v2 =0 | v30=0 | v46=0 | None  | None  |
# v26=1 | v39=1 | v12=0 | v21=1 | v28=1 | v33=1 | v37=0 | v0 =0 | v3 =1 | v16=0 | None  | None  |
# v49=1 | v7 =0 | v48=1 | v40=0 | v17=1 | v4 =1 | v19=0 | v42=1 | None  | v8 =0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 30.11%
#
# file: uf50-094.cnf, 94/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 27
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v29=1 | v23=0 | v7 =0 | v9 =1 | v31=0 | v19=0 | v32=0 | v5 =0 | v11=0 | v12=0 | None  |
# v48=1 | v47=0 | v1 =1 | v4 =1 | v42=1 | v10=1 | v8 =0 | v25=1 | v24=1 | v28=1 | None  | None  |
# v46=0 | v36=1 | v43=1 | v21=1 | v22=0 | v3 =1 | v18=0 | v0 =0 | v38=1 | v40=0 | None  | None  |
# v30=0 | v33=1 | v26=1 | v45=1 | v41=1 | v34=1 | v14=1 | v20=1 | v6 =0 | v35=0 | None  | None  |
# v44=1 | v49=1 | None  | v27=0 | v16=0 | v37=0 | v13=1 | v2 =0 | v39=1 | v17=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.79%
#
# file: uf50-095.cnf, 95/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v28=1 | v24=1 | v16=0 | v42=1 | v38=1 | v8 =0 | v39=1 | v21=1 | v2 =0 | v22=0 | v33=1 | v9 =1 |
# v12=0 | v3 =1 | v23=0 | v47=0 | v35=0 | v4 =1 | v31=0 | v29=1 | v30=0 | v19=0 | None  | None  |
# v36=1 | v48=1 | v15=0 | v34=1 | v6 =0 | v46=0 | v10=1 | v43=1 | v0 =0 | v41=1 | None  | None  |
# v26=1 | v5 =0 | v49=1 | v32=0 | v17=1 | v20=1 | v25=1 | v40=0 | v18=0 | v1 =1 | None  | None  |
# v7 =0 | v37=0 | v44=1 | v14=1 | v13=1 | v45=1 | v11=0 | v27=0 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 29.47%
#
# file: uf50-096.cnf, 96/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 27
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v44=1 | v43=1 | v36=1 | v20=1 | v1 =1 | v33=1 | v21=1 | v7 =0 | v49=1 | v16=0 | None  |
# v2 =0 | v11=0 | v42=1 | v13=1 | v47=0 | v37=0 | v48=1 | v32=0 | v38=1 | v26=1 | v4 =1 | None  |
# v18=0 | v35=0 | v10=1 | v8 =0 | v22=0 | v31=0 | v30=0 | v46=0 | v3 =1 | v41=1 | v28=1 | None  |
# v14=1 | v27=0 | v9 =1 | v45=1 | v5 =0 | None  | v23=0 | v40=0 | v39=1 | v24=1 | None  | None  |
# v17=1 | v6 =0 | v34=1 | v12=0 | v25=1 | None  | v15=0 | v0 =0 | v29=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 30.21%
#
# file: uf50-097.cnf, 97/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 20
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v20=1 | v44=1 | v28=1 | v43=1 | v39=1 | v24=1 | v11=0 | v8 =0 | v13=1 | v31=0 | v0 =0 | None  |
# v14=1 | v29=1 | v12=0 | v17=1 | v26=1 | v48=1 | v30=0 | v45=1 | v40=0 | v19=0 | v21=1 | None  |
# v16=0 | v27=0 | v49=1 | v3 =1 | v15=0 | v9 =1 | v33=1 | v34=1 | v6 =0 | v36=1 | v5 =0 | None  |
# v23=0 | v32=0 | v22=0 | v10=1 | v35=0 | v2 =0 | v1 =1 | v41=1 | None  | v18=0 | None  | None  |
# None  | v46=0 | v7 =0 | v47=0 | v25=1 | v42=1 | v4 =1 | v38=1 | None  | v37=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 2
# Current Solvability: 29.90%
#
# file: uf50-098.cnf, 98/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 37
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v22=0 | v35=0 | v42=1 | v10=1 | v9 =1 | v3 =1 | v25=1 | v48=1 | v36=1 | v47=0 | v17=1 | None  |
# v8 =0 | v26=1 | v15=0 | v39=1 | v46=0 | v30=0 | v11=0 | v38=1 | v23=0 | v18=0 | v31=0 | None  |
# v12=0 | v45=1 | v5 =0 | v21=1 | v27=0 | v7 =0 | v49=1 | v4 =1 | v40=0 | v16=0 | v14=1 | None  |
# v2 =0 | v34=1 | v6 =0 | v20=1 | v41=1 | v1 =1 | v19=0 | v33=1 | v13=1 | v28=1 | None  | None  |
# v37=0 | None  | v43=1 | v32=0 | v24=1 | v29=1 | v0 =0 | v44=1 | None  | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.59%
#
# file: uf50-099.cnf, 99/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 20
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v11=0 | v4 =1 | v48=1 | v24=1 | v32=0 | v18=0 | v15=0 | v10=1 | v23=0 | v40=0 | v31=0 | None  |
# v37=0 | v34=1 | v9 =1 | v45=1 | v7 =0 | v17=1 | v43=1 | v19=0 | v36=1 | v33=1 | v3 =1 | None  |
# v28=1 | v26=1 | v47=0 | v16=0 | v38=1 | v46=0 | v14=1 | v2 =0 | v41=1 | v1 =1 | None  | None  |
# v49=1 | v5 =0 | v39=1 | v27=0 | v21=1 | v30=0 | v29=1 | v20=1 | v13=1 | v12=0 | None  | None  |
# v44=1 | v22=0 | None  | v0 =0 | v25=1 | v6 =0 | v8 =0 | v35=0 | v42=1 | None  | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.29%
#
# file: uf50-0100.cnf, 100/100   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 32
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v26=1 | v11=0 | v8 =0 | v38=1 | v29=1 | v47=0 | v31=0 | v23=0 | v1 =1 | v30=0 | v6 =0 | None  |
# v42=1 | v18=0 | v17=1 | v34=1 | v40=0 | v37=0 | v45=1 | v0 =0 | v7 =0 | v12=0 | None  | None  |
# v9 =1 | v36=1 | v43=1 | v35=0 | v49=1 | v39=1 | v27=0 | v14=1 | v24=1 | v4 =1 | None  | None  |
# v16=0 | v13=1 | v44=1 | v2 =0 | v46=0 | v41=1 | v28=1 | v48=1 | v3 =1 | v20=1 | None  | None  |
# v22=0 | None  | v32=0 | v19=0 | v10=1 | v33=1 | v15=0 | v21=1 | v5 =0 | v25=1 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 1
# Current Solvability: 29.00%
#
#
# Final Solvability: 29.00%
