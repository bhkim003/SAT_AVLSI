# %%
# Simulation for SAT solving shardware
# reference: Shim, Chaeyun, Jooyoung Bae, and Bongjin Kim. "30.3 VIP-Sat: A Boolean Satisfiability Solver Featuring 5× 12 Variable In-Memory Processing Elements with 98% Solvability for 50-Variables 218-Clauses 3-SAT Problems." 2024 IEEE International Solid-State Circuits Conference (ISSCC). Vol. 67. IEEE, 2024.

# %%
# 데이터셋 위치  
# /data2/sat/uf50-218  
# /data2/sat/uf20-91 
# 출처: https://www.cs.ubc.ca/~hoos/SATLIB/benchm.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy 
import os
import re
import json
import datetime
from collections import defaultdict
import re

# %%
class LFSR:
    def __init__(self, init_value, n_bits):
        assert init_value < (1 << n_bits) and init_value > 0, "init_value must fit in n_bits and be greater than 0"
        self.n_bits = n_bits
        self.registers = self._init_registers(init_value)
        self.taps_dict = { #https://www.programmersought.com/article/18123888566/
                2: [2 ,1],
                3: [3, 2],
                4: [4, 3],
                5: [5, 3],
                6: [6, 5], 
                7: [7, 6], 
                8: [8, 6, 5, 4], 
                9: [9, 5], 
                10: [10, 7], 
                11: [11, 9],
                12: [12, 11, 10, 4],
                13: [13, 12, 11, 8],
                14: [14, 13, 12, 2],
                15: [15, 14],
                16: [16,15,13,4],
                17: [17,14],
                18: [18,11],
                19: [19,18,17,14],
                20: [20,17],
                21: [21,19],
                22: [22,21],
                23: [23,18],
                24: [24,23,22,17],
            }
        self.taps = self.taps_dict[n_bits]  # 피드백 위치 (가장 오른쪽 비트부터 0부터 시작)
    
    def _init_registers(self, init_value):
        binary_value = bin(init_value)[2:].zfill(self.n_bits) # 이진수로 변환 후, n_bits에 맞춰 0 채움
        return [int(bit) for bit in binary_value[::-1]] # 각 비트를 리스트에 저장 (big endian)

    def shift(self):
        feedback = self.registers[self.taps[0] - 1]
        for tap in self.taps[1:]:
            feedback ^= self.registers[tap - 1]  # XOR 연산
        self.registers = [feedback] + self.registers[:-1]
        return int(''.join(map(str, self.registers)), 2)

    def generate(self, num_iterations):
        out_list = []
        for _ in range(num_iterations):
            out_list.append(self.shift())
        return out_list

# 예시 사용
init_value = 1  # 초기 값
n_bits = 2  # 레지스터 비트 수
num_iterations = 33  # 최대 31번 반복

lfsr_instance = LFSR(init_value, n_bits)
output = lfsr_instance.generate(num_iterations)
print(output)
# Out:
# [3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2]

# %%
def count_files_in_directory(directory):
    try:
        # 폴더 내의 모든 파일 목록 가져오기
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        return files
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
        return None

# %%
def read_cnf_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    clauses = []

    clause_save_start = False
    clause_count = 0
    for line in lines:
        if clause_save_start == True:
            clause = list(map(int, line.strip().split()))
            assert clause[-1] == 0
            clause = clause[:-1]  # Remove the trailing 0
            clauses.append(clause)
            clause_count += 1
            if clause_count == num_clauses:
                break

        if line.startswith(('p')) and clause_save_start == False:
            clause_save_start = True
            _, _, num_vars, num_clauses = line.split()
            num_vars = int(num_vars)
            num_clauses = int(num_clauses)
    assert clause_save_start == True

    clauses = np.array(clauses)
    return clauses, num_vars, num_clauses

# %%
class VPE:
    def __init__(self, MY_VAR, lfsr_bit):
        """
        VPE 초기화 메서드
        :param MY_VAR: 이 VPE가 담당할 변수 (예: v1, v2 등)
        """
        self._MY_VAR = MY_VAR  # 이 VPE가 처리할 변수
        self.MY_STATE = 1       # 변수의 상태 

        self.clauses = []         # 변수가 속한 절들의 리스트
        self.neighbors = set()    # 상관관계 있는 이웃 변수들
        self.rotation = 0         # VPE의 회전 상태


        self.lfsr_bit = lfsr_bit 
        # self.lfsr_init_value = 1 # DEPRECATED
        # self.lfsr_logic = LFSR(self.lfsr_init_value, self.lfsr_bit) # DEPRECATED
        

    @property # MY_VAR 속성은 읽기 전용
    def MY_VAR(self):
        return self._MY_VAR
    
    def add_clause(self, all_clauses):
        """
        변수가 속한 절을 추가하는 메서드
        :param all_clauses: 전체 절들의 리스트
        """
        clauses_clone = copy.deepcopy(all_clauses)
        for clause in clauses_clone:
            clause_abs = [abs(x) for x in clause]

            if self.MY_VAR in clause_abs:
                self_index = clause_abs.index(self.MY_VAR)
                temp = clause[self_index]
                #주인공이 앞에 오게 저장
                clause = np.concatenate((clause[:self_index], clause[self_index + 1:]))  # self_index에서 요소 제거
                clause_abs = clause_abs[:self_index] + clause_abs[self_index+1:]
                temp2 = np.insert(clause, 0, temp) 
                self.clauses.append(temp2) 

                # 절 내에서 다른 변수들을 이웃으로 추가
                for var_abs in clause_abs:
                    self.neighbors.add(var_abs)

        # assert len(self.clauses) <= 32, f'{len(self.clauses)}'
        if len(self.clauses) > 32:
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print(f'32개 절 초과됨!!!! : Var{self._MY_VAR}에 {len(self.clauses)}개 추가됨.')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            
            # assert False
            
        # print('self._MY_VAR:', self._MY_VAR-1)
        # print('self.clauses:\n', np.abs(self.clauses)-1)
        # print('self.clauses unique:\n', len(np.unique(np.abs(self.clauses)-1)))
            
    def get_neighbors(self):
        """
        상관관계 있는 이웃 변수들을 반환하는 메서드
        """
        return list(self.neighbors)

    def process(self, var_state_array, stochastic_mode, pseudo_number):
        """
        변수를 처리하는 메서드 (예: 값 업데이트 등)
        이 부분은 문제 해결 알고리즘에 따라 달라질 수 있음.
        """

        # Adder Tree
        tree_sum = 0

        non_trivial_clauses_count = 0.0 # VI가 중요한 절 개수
        up_count = 0.0
        down_count = 0.0

        pseudo_gen = False

        # Clause Column
        # print(len(self.clauses),'개 연관 클로즈','v',self._MY_VAR-1)
        for clause in self.clauses:
            SI = 0 if clause[0] < 0 else 1 # 음수면 0, 양수면 1 
            SL = 0 if clause[1] < 0 else 1
            SR = 0 if clause[2] < 0 else 1

            VI = var_state_array[abs(clause[0])-1] # 현재 V값 가져오기
            VL = var_state_array[abs(clause[1])-1]
            VR = var_state_array[abs(clause[2])-1]

            assert VI == self.MY_STATE, f'{VI}, {self.MY_STATE}'

            # S와 V의 XOR값(같으면 0 다르면 1)이 3개가 나옴. (SIVI, SLVL, SRVR) 한개라도 XOR값이 0이어야 Clause satisfied.
            
            # Clause Logic
            if ((SL == 1 and VL == 0) or (SL == 0 and VL == 1)) and ((SR == 0 and VR == 1) or (SR == 1 and VR == 0)) == 1: 
                C0 = 1 # MY_VAR가 중요해졌다는 flag.
                C1 = 1 if SI == 0 else 0 # SI 토글
            else:
                C0 = 0
                C1 = 0

            # Adder Tree
            addi = 0
            if C0 == 1:
                non_trivial_clauses_count += 1.0
                if C1 == 1:
                    addi = -1
                    down_count += 1.0
                else: # C1 == 0
                    addi = 1
                    up_count += 1.0
            else: # C0 == 0
                addi = 0

            tree_sum = tree_sum + addi
            if self._MY_VAR-1 == 10:
                # print(f'clause[0]: {clause[0]}, clause[1]: {clause[1]}, clause[2]: {clause[2]}, C0: {C0}, C1: {C1}, SI: {SI}, SL: {SL}, VL: {VL}, SR: {SR}, VR: {VR}, VI: {VI}, addi: {addi}')
                pass
        # print('tree_sum',tree_sum,'\n')

        # Variable Update Logic
        if stochastic_mode == False:
            # DETERMINISTIC UPDATE MODE
            if tree_sum < 0:
                self.MY_STATE = 0
            elif tree_sum == 0:
                self.MY_STATE = 1 if self.MY_STATE == 0 else 0
                # pass
            elif tree_sum > 0:
                self.MY_STATE = 1
            else: 
                assert False
        else:
            # # STOCHASTIC UPDATE MODE - scheme1
            # if tree_sum == 0:
            #     # self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
            #     p = 1/2
            # else:
            #     p = down_count/non_trivial_clauses_count
                
            # if random.random() < p:
            #     self.MY_STATE = 0
            # else:
            #     self.MY_STATE = 1

            # # STOCHASTIC UPDATE MODE - scheme2
            # if tree_sum == 0:
            #     self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
            # else:
            #     p = down_count/non_trivial_clauses_count
                
            #     if random.random() < p:
            #         self.MY_STATE = 0
            #     else:
            #         self.MY_STATE = 1
            
            # # # STOCHASTIC UPDATE MODE - scheme3
            # assert abs(tree_sum) <= 15
            # assert self.rotation > 0
            # # tree_sum = tree_sum + random.randint(0, 0)
            # tree_sum = tree_sum + np.random.normal(0, 0.25*non_trivial_clauses_count) #그나마 0.25가 낫다
            # if tree_sum < 0:
            #     self.MY_STATE = 0
            # elif tree_sum == 0:
            #     self.MY_STATE = 1 if self.MY_STATE == 0 else 0
            #     # pass
            # elif tree_sum > 0:
            #     self.MY_STATE = 1
            # else: 
            #     assert False
                    
            # # # STOCHASTIC UPDATE MODE - scheme4
            assert abs(tree_sum) <= 15, "tree_sum이 15 이상이네??!"
            assert self.rotation > 0
            assert down_count < 16 and up_count < 16, f"down_count 또는 up_count가 8 이상이네??!{down_count}, {up_count}"
            if tree_sum == 0:
                self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
            else:
                pseudo_gen = True
                assert pseudo_number < 2**self.lfsr_bit and pseudo_number > 0
                pseudo_random = pseudo_number
                    
                if pseudo_random * non_trivial_clauses_count < down_count * (2**self.lfsr_bit):
                    self.MY_STATE = 0
                elif pseudo_random * non_trivial_clauses_count > down_count * (2**self.lfsr_bit):
                    self.MY_STATE = 1
                elif pseudo_random * non_trivial_clauses_count == down_count * (2**self.lfsr_bit):
                    self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
                else:
                    assert False


        return self.MY_STATE, pseudo_gen

# %%
class VPE_ARRAY:
    def __init__(self, my_seed=42,  num_rows=5, num_cols=12, clauses=[[1,2,-3],[2,-1,57]], num_vars=50, num_clauses=218, what_file='uf50-03', hyper_iter=0, LFSR_BIT=2):
        """
        VPE_ARRAY 초기화 메서드
        :param num_rows: VPE 배열의 행 개수 (기본값: 5)
        :param num_cols: VPE 배열의 열 개수 (기본값: 12)
        :param clauses: 3-SAT 문제의 절(clause) 리스트
        :param num_vars: 변수의 총 개수
        :param num_clauses: 절의 총 개수
        """
        self.my_seed = my_seed
        self.num_rows = num_rows  # 행 개수
        self.clauses = clauses
        self.num_cols = num_cols  # 열 개수
        self.num_vars = num_vars  # 변수의 총 개수
        self.what_file = what_file
        self.hyper_iter = hyper_iter
        self.LFSR_BIT = LFSR_BIT

        self.problem_integer = int(re.search(r'-(\d+)', self.what_file).group(1))

        # from datetime import datetime
        # temp_seed = int( datetime.now().strftime("%f"))  # 현재 시간의 밀리초 값 추출
        temp_seed = 1
        random.seed(self.my_seed*(self.problem_integer+1)*(temp_seed))
        np.random.seed(self.my_seed*(self.problem_integer+1)*(temp_seed))

        # 상관 관계 행렬 
        self.correlation_matrix = self.create_correlation_matrix()

        # VPE 배열 생성
        # self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_variables_to_vpe_shim()
        self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_varaibles_to_vpe_with_file()

        # 딱 variable 개수만큼 배치 잘했는지 확인
        assert len(self.assigned_abs_vars) == self.num_vars, f'len(self.assigned_abs_vars): {len(self.assigned_abs_vars)}, self.num_vars: {self.num_vars}'
        assert sum(1 for i in range(self.num_rows) for j in range(self.num_cols) if self.VPES[i][j] is not None) == self.num_vars

        # 배치한 거 한번 보자
        # self.print_vpe_index()

        # uncorrelated columns check
        assert self.check_uncorrelated_columns(self.VPE_index, self.correlation_matrix)

        # mapping 저장
        # np.save(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}.npy', self.VPE_index)

        # VPE 배열에 모든 절 삽입
        self.add_clause_to_vpe()
        
        # variable state initialize
        # self.var_state_array = self.variable_state_initialize()
        self.var_state_array = self.variable_state_initialize2()

        # deployment된 VPE들의 state값을 출력
        # self.print_var_state_array()
        
        # run
        # 외부에서 실행하세요.    


    def create_correlation_matrix(self):
        """
        상관 관계 행렬을 생성하는 메서드

        Args:
            clauses (list): 변수의 절(clause) 리스트
        """
        # 각 절(clause)에서 변수를 두 개씩 비교하며 상관 관계를 행렬에 기록
        correlation_matrix = np.zeros((self.num_vars, self.num_vars), dtype=int)
        for clause in self.clauses:
            for i, var1 in enumerate(clause):
                for var2 in clause[i + 1:]:
                    abs_var1, abs_var2 = abs(var1) - 1, abs(var2) - 1  # 변수 인덱스는 0부터 시작하므로 -1 처리
                    correlation_matrix[abs_var1, abs_var2] = 1  # 상관된 변수 간에는 1을 표시
                    correlation_matrix[abs_var2, abs_var1] = 1  # 상관 행렬은 대칭이므로 반대 방향도 동일하게 처리
        
        return correlation_matrix
    
    def assign_varaibles_to_vpe_with_file(self):
        # 사용한 변수를 추적하기 위한 리스트
        assigned_abs_vars = set()
        # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
        VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
        if 'uf50' in self.what_file:
            VPES_index = np.load(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}.npy', allow_pickle=True)
        elif 'uf100' in self.what_file: 
            VPES_index = np.load(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}.npy', allow_pickle=True)
        else: 
            VPES_index = np.load(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}_rows{self.num_rows}.npy', allow_pickle=True)

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if VPES_index[row][col] != None:
                    VPES[row][col] = VPE(VPES_index[row][col], self.LFSR_BIT)
                    assigned_abs_vars.add(VPES_index[row][col])
        return VPES, VPES_index, assigned_abs_vars


    
    def assign_variables_to_vpe_shim(self):
        correlation_matrix_save = copy.deepcopy(self.correlation_matrix)
        assigned_abs_vars = set()
        deploy_search_iter = 0
        while True:
            # print('deploy_search_iter', deploy_search_iter)
            deploy_search_iter += 1
            self.correlation_matrix = copy.deepcopy(correlation_matrix_save)

            assigned_abs_vars = set()

            VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
            VPES_index_past = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])

            current_row_at_column = [0 for _ in range(self.num_cols)]
            for whole_col_iter in range(1000): # 모든 컬럼 반복 # 근데 어차피 이전 iter와 변화가 없으면 걍 break된다.
                shuffled_abs_vars_range = np.concatenate([np.sort(group)[::-1] for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 
                if deploy_search_iter > 100:
                    shuffled_abs_vars_range = np.concatenate([np.random.shuffle(group) or group for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 if np.random.seed((self.my_seed+1)*(whole_col_iter+1)*(deploy_search_iter+1)) is None else None

                for col in range(self.num_cols):
                    if current_row_at_column[col] >= self.num_rows:  # 이 column에 모두 할당했으면 다음 column으로
                        continue

                    col_chance = self.num_rows # 원하는 만큼 다 해 (한 컬럼에 한번에 몇개까지 넣을지)

                    for abs_var in shuffled_abs_vars_range:
                        if abs_var in assigned_abs_vars:
                            continue # next var  # 이미 할당된 변수는 건너뜀
                        
                        can_assign = True
                        for prev_row in range(current_row_at_column[col]):
                            if self.what_file=='uf50-0730' and col == 0 and prev_row == 1:
                                continue

                            prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                            if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                                can_assign = False
                                break # next var

                        if can_assign == True:
                            assert VPES[current_row_at_column[col]][col] == None
                            VPES[current_row_at_column[col]][col] = VPE(abs_var, self.LFSR_BIT)  # 변수 할당
                            assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                            current_row_at_column[col] += 1
                            col_chance -= 1
                            if self.what_file=='uf50-0730' and col == 0 and current_row_at_column[col] == 1:
                                current_row_at_column[col] += 1
                                col_chance -= 1


                        # stage1_cut_row = self.num_vars//self.num_cols - 1
                        if current_row_at_column[col] == self.num_rows or col_chance == 0:  # 이 column에 어느 정도 할당했으면 다음 column으로
                            break # next col;
                
                VPES_index_temp = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                if np.array_equal(VPES_index_past, VPES_index_temp) or len(assigned_abs_vars) == self.num_vars:
                    break
                else:
                    pass
                VPES_index_past = VPES_index_temp
            
            assert len(assigned_abs_vars) <= self.num_vars, f'ASSERT FALSE!! len(assigned_abs_vars): {len(assigned_abs_vars)}, self.num_vars: {self.num_vars}'
            if len(assigned_abs_vars) == self.num_vars:
                # print('deploy_search_iter', deploy_search_iter)
                VPES_index = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                break
        return VPES, VPES_index, assigned_abs_vars


    def check_uncorrelated_columns(self, VPE_index, correlation_matrix):
        num_rows = len(VPE_index)
        num_cols = len(VPE_index[0])
        for col in range(num_cols):
            col_values = [VPE_index[row][col] for row in range(num_rows) if VPE_index[row][col] is not None]
            for i in range(len(col_values)):
                for j in range(i + 1, len(col_values)):
                    var1 = col_values[i]
                    var2 = col_values[j]
                    if correlation_matrix[var1 - 1][var2 - 1] == 1:
                        return False
        return True

    def add_clause_to_vpe(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].add_clause(self.clauses)

    
    # def variable_state_initialize(self):
    #     var_state_array = [random.choice([0, 1]) for _ in range(self.num_vars)]

    #     for row in range(self.num_rows):
    #         for col in range(self.num_cols):
    #             if self.VPES[row][col] != None:
    #                 self.VPES[row][col].MY_STATE = var_state_array[self.VPES[row][col].MY_VAR - 1]
    #     return var_state_array
    
    def variable_state_initialize2(self):
        # np.random.seed(1)
        var_state_array = [None for _ in range(self.num_vars)]
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    draw = np.random.choice([0, 1], p=[0.5, 0.5])
                    self.VPES[row][col].MY_STATE = draw
                    var_state_array[self.VPES[row][col].MY_VAR - 1] = draw
        return var_state_array
    


    def satisfy_check(self, var_state_array, clauses):
        """
        절을 만족하는지 확인하는 메서드
        :param var_state_array: 변수들의 상태를 나타내는 배열 (0 또는 1로 구성된 리스트)
        :param clauses: 각 절을 표현하는 리스트의 리스트 (변수는 양수 또는 음수로 표현됨)
        :return: num_unsat_clause, unsat_clauses_list (만족되지 않은 절의 개수와 그 절들의 리스트)
        """
        unsat_clauses_list = []
        # 각 절에 대해 만족 여부를 확인
        for clause in clauses:
            satisfied = False  # 해당 절이 만족되는지 여부를 나타내는 변수

            for var in clause:
                abs_var = abs(var) - 1  # 변수의 절대값으로 인덱스를 맞춤 (0부터 시작)
                var_state = var_state_array[abs_var]  # 해당 변수의 상태

                if (var > 0 and var_state == 1) or (var < 0 and var_state == 0):
                    satisfied = True  
                    break # 하나라도 만족하는 변수가 있으면 절이 만족됨

            if satisfied == False:
                unsat_clauses_list.append(clause)  # 만족되지 않은 절을 리스트에 추가

        num_unsat_clause = len(unsat_clauses_list)  # 만족되지 않은 절의 개수

        return num_unsat_clause, unsat_clauses_list
    
    def print_var_state_array(self):
        for col in range(self.num_cols):
            print(f'col{col:>2}', end='|||')
        print()

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPE_index[row][col] != None:
                    print(f'v{self.VPE_index[row][col]-1:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
                else: 
                    print(f'None ', end=' | ')
            print()

        # ## ======================일반적인 파일 뽑기===============================================        
        # 기존에 있는 파일 직접 지우고 실행해라 
        # f_all = open(f'sat_init_condition/mapping.txt', 'a')  # 파일 열기
        # f_all.write(f'\nmy %map{self.problem_integer}_UF{self.num_vars}_ROW{self.num_rows} = (\n    ')
        # for row in range(5):
        #     for col in range(self.num_cols):
        #         if row >= self.num_rows:
        #             f_all.write(f'\'99\' => \'{row * self.num_cols + col}\', ')
        #         else:
        #             if self.VPE_index[row][col] != None:
        #                 f_all.write(f'\'{self.VPE_index[row][col]}\' => \'{row * self.num_cols + col}\', ')
        #             else:
        #                 f_all.write(f'\'99\' => \'{row * self.num_cols + col}\', ')
        #     f_all.write('\n    ') if row != 5-1 else f_all.write('')
        # f_all.write(f'\n);\n\n')
        # f_all.close()
        
        # # 기존에 있는 파일 직접 지우고 실행해라 그리고 HYPER_RUN에서 break 빼고 돌려라
        # f_all_value = open(f'sat_init_condition/init_value.txt', 'a')  # 파일 열기
        # for row in range(5):
        #     f_all_value.write(f'`define INIT_VAR{row}_PRO{self.problem_integer}_UF{self.num_vars}_ITER{self.hyper_iter+1}_ROW{self.num_rows} \'{{')
        #     for col in range(self.num_cols):
        #         if row >= self.num_rows:
        #             f_all_value.write(f'{0}')
        #         else:
        #             if self.VPE_index[row][col] != None:
        #                 f_all_value.write(f'{self.var_state_array[self.VPE_index[row][col]-1]}')
        #             else:
        #                 f_all_value.write(f'{0}')

        #         f_all_value.write(', ') if col != self.num_cols-1 else f_all_value.write('}')
        #     f_all_value.write('\n')
        # f_all_value.write(f'\n\n')
        # f_all_value.close()
        # ## ======================일반적인 파일 뽑기=============================================== 
        

        # # ===mapping======= uf20짜리 row두개로 위에 두개 밑에 두개 row에 배치=================
        # if self.problem_integer%2== 1:
        #     # 기존에 있는 파일 직접 지우고 실행해라
        #     f_all = open(f'sat_init_condition/mapping.txt', 'a')  # 파일 열기
        #     f_all.write(f'\nmy %map{self.problem_integer}_{self.problem_integer+1}_UF{self.num_vars}_ROW{self.num_rows} = (\n    ')
        #     for row in [0,1]:
        #         for col in range(self.num_cols):
        #             if self.VPE_index[row][col] != None:
        #                 f_all.write(f'\'{self.VPE_index[row][col]}\' => \'{row * self.num_cols + col}\', ')
        #             else:
        #                 f_all.write(f'\'99\' => \'{row * self.num_cols + col}\', ')
        #         f_all.write('\n    ') if row != 5-1 else f_all.write('')
        #     f_all.close()
        # else:
        #     # 기존에 있는 파일 직접 지우고 실행해라
        #     f_all = open(f'sat_init_condition/mapping.txt', 'a')  # 파일 열기
        #     for row in [2,3,4]:
        #         for col in range(self.num_cols):
        #             if row == 2:
        #                 f_all.write(f'\'99\' => \'{row * self.num_cols + col}\', ')
        #             else:
        #                 row_temp = row -3
        #                 if self.VPE_index[row_temp][col] != None:
        #                     f_all.write(f'\'{self.VPE_index[row_temp][col]}\' => \'{row * self.num_cols + col}\', ')
        #                 else:
        #                     f_all.write(f'\'99\' => \'{row_temp * self.num_cols + col}\', ')
        #         f_all.write('\n    ') if row != 5-1 else f_all.write('')
        #     f_all.write(f'\n);\n\n')
        #     f_all.close()
        # # ===mapping======= uf20짜리 row두개로 위에 두개 밑에 두개 row에 배치=================


        
        # # ===init value====== uf20짜리 row두개로 위에 두개 밑에 두개 row에 배치=================
        # 기존에 있는 파일 직접 지우고 실행해라 그리고 HYPER_RUN에서 break 빼고 돌려라
        # f_all_value = open(f'sat_init_condition/init_value.txt', 'a')  # 파일 열기
        # if self.problem_integer%2== 1:
        #     for row in [0,1]:
        #         f_all_value.write(f'`define INIT_VAR{row}_PRO{self.problem_integer}_{self.problem_integer+1}_UF{self.num_vars}_ITER{self.hyper_iter+1}_ROW{self.num_rows} \'{{')
        #         for col in range(self.num_cols):
        #             if self.VPE_index[row][col] != None:
        #                 f_all_value.write(f'{self.var_state_array[self.VPE_index[row][col]-1]}')
        #             else:
        #                 f_all_value.write(f'{0}')
        #             f_all_value.write(', ') if col != self.num_cols-1 else f_all_value.write('}')
        #         f_all_value.write('\n')
        #     f_all_value.write(f'\n\n')
        #     f_all_value.close()
        # else:
        #     for row in [2,3,4]:
        #         f_all_value.write(f'`define INIT_VAR{row}_PRO{self.problem_integer-1}_{self.problem_integer}_UF{self.num_vars}_ITER{self.hyper_iter+1}_ROW{self.num_rows} \'{{')
        #         for col in range(self.num_cols):
        #             if row == 2:
        #                 f_all_value.write(f'{0}')
        #             else:
        #                 row_temp = row -3
        #                 if self.VPE_index[row_temp][col] != None:
        #                     f_all_value.write(f'{self.var_state_array[self.VPE_index[row_temp][col]-1]}')
        #                 else:
        #                     f_all_value.write(f'{0}')

        #             f_all_value.write(', ') if col != self.num_cols-1 else f_all_value.write('}')
        #         f_all_value.write('\n')
        #     f_all_value.write(f'\n\n')
        #     f_all_value.close()
        # # ===init value====== uf20짜리 row두개로 위에 두개 밑에 두개 row에 배치=================

    def rotation_value_up_each_VPE(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].rotation += 1


    def run(self, max_iter, iter_verbose, stochastic_mode_start_iter):
        """
        VPE 배열을 실행하는 메서드
        :param max_iter: 최대 반복 횟수 (기본값: 100)
        """
        num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)

        # if iter_verbose == True or True:
        if iter_verbose == True :
            print('INITIAL VAR STATE ARRAY')
            print(f'iteration {0:>4} | num_unsat_clause: {num_unsat_clause}')
            self.print_var_state_array()
            
        pseudo_number = [[3] * self.num_cols for _ in range(self.num_rows)]
        for i in range(max_iter):
            self.rotation_value_up_each_VPE()
            # row-wise parellel processing
            for col in range(self.num_cols):
                state_temp_at_now_col = [None for _ in range(self.num_rows)]
                for row in range(self.num_rows):
                    if self.VPES[row][col] != None:
                        if stochastic_mode_start_iter<0: # 일정 rotation 이하는 sto, 이후는 determ
                            stochastic_mode = False if i+1 >= -stochastic_mode_start_iter else True
                        elif stochastic_mode_start_iter==0:
                            assert False, 'stochastic_mode_start_iter should be non-zero'
                        elif stochastic_mode_start_iter>0:  # 일정 rotation 이하는 determ, 이후는 sto
                            stochastic_mode = True if i+1 >= stochastic_mode_start_iter else False
                        else:
                            assert False
                        state_temp_at_now_col[row], pseudo_gen = self.VPES[row][col].process(self.var_state_array,stochastic_mode,pseudo_number[0][col])
                if pseudo_gen == True:
                    pseudo_number[0][col] = pseudo_number[0][col] + 1 if pseudo_number[0][col] != 2**self.LFSR_BIT - 1 else 1
        

                # updated state update!!
                toggle_count = 0
                for row in range(self.num_rows):
                    if state_temp_at_now_col[row] != None:  
                        if self.var_state_array[self.VPES[row][col].MY_VAR - 1] != state_temp_at_now_col[row]:
                            toggle_count += 1
                        self.var_state_array[self.VPES[row][col].MY_VAR - 1] = state_temp_at_now_col[row]

                        
                if iter_verbose == True:
                    num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
                    print(f'\n\niter {i+1}- col {col} done, toggle_count: {toggle_count}' )
                    print(f'iteration {i+1:>4} | num_unsat_clause: {num_unsat_clause}')
                    self.print_var_state_array()

            num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)


            # 매번 검사해서 나가는 게 아니다.
            # if num_unsat_clause == 0:
            #     return i+1
            
            # iteration 마다 실패하면 다시 리셋하기 (근데 이러면 solvability 0)
            # self.var_state_array = self.variable_state_initialize()


        else:
            if num_unsat_clause == 0:
                return i+1
            else:
                if iter_verbose == True:
                    print(f"NOT SATISFIED! num_unsat_clause: {num_unsat_clause}, unsat_clauses_list: {unsat_clauses_list}, iteration: {i+1}")
                return -num_unsat_clause

# %%
def HYPER_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=18, file_path='/data2/sat/uf50-218/uf50-03.cnf', max_iter=100, iter_verbose=False, stochastic_mode_start_iter=9999999, STO_ROTATION=200, LFSR_BIT=2):
    clauses, num_vars, num_clauses = read_cnf_file(file_path)

    SUCCESS_OR_NOT = 0
    for hyper_iter in range(HYPER_MAX_ITER):
        if STO_ROTATION == 0:
            pass
        elif STO_ROTATION > 0:
            if hyper_iter+1 == HYPER_MAX_ITER:
                stochastic_mode_start_iter=1
                max_iter = STO_ROTATION
            else:
                stochastic_mode_start_iter=9999999
                max_iter = max_iter
        elif STO_ROTATION < 0:
            if hyper_iter+1 == 1:
                stochastic_mode_start_iter=1
                max_iter = -STO_ROTATION
            else:
                stochastic_mode_start_iter=9999999
                max_iter = max_iter
        else:
            assert False


        # print(f'hyper_iter: {hyper_iter+1}', end = '  ')
        my_seed = hyper_seed * (hyper_iter+1)
        what_file = os.path.splitext(os.path.basename(file_path))[0]
        vpe_array = VPE_ARRAY(my_seed=my_seed, num_rows=num_rows, num_cols=num_cols, clauses=clauses, num_vars=num_vars, num_clauses=num_clauses, what_file=what_file, hyper_iter=hyper_iter, LFSR_BIT=LFSR_BIT)  # 5x12 VPE 배열 생성
        success_iter = vpe_array.run(max_iter, iter_verbose, stochastic_mode_start_iter)  # VPE processing 실행
        assert success_iter != 0, 'run메서드에서는 0이 나올 수는 없게 해놨다.'
        
        if success_iter > 0:
            print(f'SATISFIED!!!! hyper_iter: {hyper_iter+1}, success_iter: {success_iter}')
            SUCCESS_OR_NOT = success_iter # 양수면 성공임
            break
        # print(f'not satisfied. num_unsat_clause: {-success_iter}')
        # print()
    else:
        print(f'NOT SATISFIED! HYPER_MAX_ITER: {HYPER_MAX_ITER},  last num_unsat_clause: {-success_iter}')
    return SUCCESS_OR_NOT, hyper_iter+1

# %%
def FULL_FILE_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, BASE_PATH='/data2/sat/uf50-218/', max_iter=10, iter_verbose=False, max_problem = 1000, stochastic_mode_start_iter = 9999999, current_time="20241026_025657", STO_ROTATION=200, LFSR_BIT=2):
    # 설정 값을 딕셔너리 형태로 저장
    config = {
        "HYPER_MAX_ITER": HYPER_MAX_ITER,
        "hyper_seed": hyper_seed,
        "num_rows": num_rows,
        "num_cols": num_cols,
        "BASE_PATH": BASE_PATH,
        "max_iter": max_iter,
        "iter_verbose": iter_verbose,
        "max_problem": max_problem,
        "stochastic_mode_start_iter": stochastic_mode_start_iter,
        "current_time": current_time,
        "STO_ROTATION": STO_ROTATION,
        "LFSR_BIT": LFSR_BIT,
    }

    success_file_list = []
    fail_file_list = []
    
    # config.json 파일로 저장
    folder_name = os.path.basename(os.path.normpath(BASE_PATH))  # 마지막 폴더 이름을 추출합니다.
    iter_save_path = os.path.join(f'iter_save_box/{folder_name}_iter_analysis_{current_time}_seed{hyper_seed}')



    files = count_files_in_directory(BASE_PATH)
    assert files != None, '파일 못 불러오고 있따.'
    
    # 파일 이름에서 숫자만 추출하여 정렬
    def extract_number(file_name):
        numbers = re.findall(r'\d+', file_name) # 파일 이름에서 숫자를 추출
        # print(numbers)
        return int(numbers[-1]) if numbers else float('inf')  # 숫자가 없는 파일을 뒤로 정렬
    
    files.sort(key=extract_number)  # 파일 이름을 숫자 순으로 정렬
    
    total_file = len(files)
    num_success = 0
    current_file = 0

    success_iter_list = []
    total_rot = 0
    for file in files:
        # if file != 'uf50-03.cnf':
        #     continue
        # if file != 'uf50-025.cnf':
        #     continue
        # if file != 'uf50-0730.cnf':
        #     continue
        current_file += 1
        file_path = os.path.join(BASE_PATH, file)
        print(f'\nfile: {file}, {current_file}/{max_problem}')

        SUCCESS_OR_NOT, hyper_iter= HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose, stochastic_mode_start_iter=stochastic_mode_start_iter, STO_ROTATION=STO_ROTATION, LFSR_BIT=LFSR_BIT)
        # SUCCESS_OR_NOT가 양수면 성공(성공한 iter 수), 음수면 실패(불만족하는 clause 수)
        if SUCCESS_OR_NOT > 0:
            num_success += 1
            iter = SUCCESS_OR_NOT
            success_iter_list.append((min(total_file, max_problem), current_file, iter, hyper_iter))
            success_file_list.append(file)


        else:
            fail_file_list.append(file)
            total_rot += max_iter*(HYPER_MAX_ITER-1) + STO_ROTATION
        print(f'Current Solvability: {100*num_success/current_file:.2f}%')


        if STO_ROTATION == 0:
            total_rot += max_iter*hyper_iter
        elif STO_ROTATION > 0:
            if hyper_iter == HYPER_MAX_ITER:
                total_rot += max_iter*(hyper_iter-1) + abs(STO_ROTATION)
            else:
                total_rot += max_iter*hyper_iter
        elif STO_ROTATION < 0:
            total_rot += max_iter*(hyper_iter-1) + abs(STO_ROTATION)
        else:
            assert False
        
        if max_problem == current_file:
            break
    config['total_rot'] = total_rot
    print(f'\n\nFinal Solvability: {100*num_success/current_file:.2f}%, total_rot: {total_rot}')
    print(f'')
    print(f'success_file_list: {success_file_list}')
    print(f'fail_file_list: {fail_file_list}')
    success_iter_array = np.array(success_iter_list, dtype=int)  # 정수형 배열로 변환
    with open(iter_save_path + '.json', 'w') as config_file:
        json.dump(config, config_file, indent=4)  # JSON 형식으로 저장하며, 들여쓰기를 설정합니다.
    np.save(iter_save_path , success_iter_array)  # NumPy 형식으로 저장

    # final solvability
    return num_success/current_file, total_rot

# %%
# mapping 뽑을 때: seed = 50, HYPER_MAX_ITER = 1, max_iter = 7  # value 뽑을 때: seed = 50, HYPER_MAX_ITER = 17, max_iter = 1
HYPER_MAX_ITER = 11 #iteration
STO_ROTATION = 0 # 0이면 혼합X, 양수면 마지막에한번만 이 수만큼 stochastic, 음수면 처음에한번만 이 수만큼 stochastic
LFSR_BIT = 2

# BASE_PATH = '/data2/sat/uf50-218/'
# BASE_PATH = '/data2/sat/uf20-91/'
BASE_PATH = '/data2/sat/uf100-430/'
hyper_seed = 50
num_rows = 10 
num_cols = 12
max_iter = 28 #rotation
iter_verbose = False # True # False
max_problem = 1000
stochastic_mode_start_iter = 9999999    #1    #9999999    #stochastic할 거면 1로 설정 
current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
print(f'current_time: {current_time}')

solv_list = []
total_rot_list = []
for for_loop_seed in range(hyper_seed,hyper_seed+1):
    print(f'\n\n\n\n\nfor_loop_seed: {for_loop_seed}\n\n\n\n\n')

    solvability, total_rot = FULL_FILE_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, 
                    hyper_seed=for_loop_seed, 
                    num_rows=num_rows, 
                    num_cols=num_cols, 
                    BASE_PATH=BASE_PATH, 
                    max_iter=max_iter, 
                    iter_verbose=iter_verbose,
                    max_problem=max_problem,
                    stochastic_mode_start_iter=stochastic_mode_start_iter,
                    current_time=current_time,
                    STO_ROTATION=STO_ROTATION,
                    LFSR_BIT=LFSR_BIT)
    solv_list.append(solvability)
    total_rot_list.append(total_rot)

np.save(f'solv_list_save_box/solv_list_{current_time}.npy', solv_list) # NumPy로 저장
loaded_solv_list = np.load(f'solv_list_save_box/solv_list_{current_time}.npy') # NumPy로 로드
np.save(f'solv_list_save_box/total_list_{current_time}.npy', total_rot_list) # NumPy로 저장
loaded_total_rot_list = np.load(f'solv_list_save_box/total_list_{current_time}.npy') # NumPy로 로드
print(f"Mean: {np.mean(loaded_solv_list)}, Min: { np.min(loaded_solv_list)}, Max: {np.max(loaded_solv_list)}")
print(f"Mean: {np.mean(loaded_total_rot_list)}, Min: { np.min(loaded_total_rot_list)}, Max: {np.max(loaded_total_rot_list)}")
# Out:
# current_time: 20241217_144633
#
#
#
#
#
# for_loop_seed: 50
#
#
#
#
#
#
# file: uf100-01.cnf, 1/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-02.cnf, 2/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-03.cnf, 3/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-04.cnf, 4/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-05.cnf, 5/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-06.cnf, 6/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-07.cnf, 7/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-08.cnf, 8/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-09.cnf, 9/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 22
# Current Solvability: 0.00%
#
# file: uf100-010.cnf, 10/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 6
# Current Solvability: 0.00%
#
# file: uf100-011.cnf, 11/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-012.cnf, 12/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-013.cnf, 13/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-014.cnf, 14/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 7
# Current Solvability: 0.00%
#
# file: uf100-015.cnf, 15/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-016.cnf, 16/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-017.cnf, 17/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-018.cnf, 18/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-019.cnf, 19/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-020.cnf, 20/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-021.cnf, 21/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-022.cnf, 22/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-023.cnf, 23/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-024.cnf, 24/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-025.cnf, 25/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-026.cnf, 26/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-027.cnf, 27/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-028.cnf, 28/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-029.cnf, 29/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-030.cnf, 30/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-031.cnf, 31/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-032.cnf, 32/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-033.cnf, 33/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-034.cnf, 34/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-035.cnf, 35/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-036.cnf, 36/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-037.cnf, 37/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-038.cnf, 38/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-039.cnf, 39/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 8
# Current Solvability: 0.00%
#
# file: uf100-040.cnf, 40/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-041.cnf, 41/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-042.cnf, 42/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-043.cnf, 43/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-044.cnf, 44/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-045.cnf, 45/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-046.cnf, 46/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-047.cnf, 47/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 22
# Current Solvability: 0.00%
#
# file: uf100-048.cnf, 48/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-049.cnf, 49/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-050.cnf, 50/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-051.cnf, 51/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-052.cnf, 52/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-053.cnf, 53/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-054.cnf, 54/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-055.cnf, 55/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 8
# Current Solvability: 0.00%
#
# file: uf100-056.cnf, 56/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-057.cnf, 57/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-058.cnf, 58/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-059.cnf, 59/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-060.cnf, 60/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-061.cnf, 61/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-062.cnf, 62/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-063.cnf, 63/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-064.cnf, 64/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 8
# Current Solvability: 0.00%
#
# file: uf100-065.cnf, 65/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-066.cnf, 66/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-067.cnf, 67/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-068.cnf, 68/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-069.cnf, 69/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-070.cnf, 70/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-071.cnf, 71/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-072.cnf, 72/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-073.cnf, 73/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-074.cnf, 74/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-075.cnf, 75/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-076.cnf, 76/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-077.cnf, 77/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-078.cnf, 78/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-079.cnf, 79/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-080.cnf, 80/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-081.cnf, 81/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-082.cnf, 82/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-083.cnf, 83/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-084.cnf, 84/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 24
# Current Solvability: 0.00%
#
# file: uf100-085.cnf, 85/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-086.cnf, 86/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-087.cnf, 87/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-088.cnf, 88/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-089.cnf, 89/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-090.cnf, 90/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-091.cnf, 91/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-092.cnf, 92/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-093.cnf, 93/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-094.cnf, 94/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-095.cnf, 95/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-096.cnf, 96/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-097.cnf, 97/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-098.cnf, 98/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-099.cnf, 99/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0100.cnf, 100/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0101.cnf, 101/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0102.cnf, 102/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0103.cnf, 103/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0104.cnf, 104/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0105.cnf, 105/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0106.cnf, 106/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0107.cnf, 107/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0108.cnf, 108/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0109.cnf, 109/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0110.cnf, 110/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0111.cnf, 111/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0112.cnf, 112/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0113.cnf, 113/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0114.cnf, 114/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 27
# Current Solvability: 0.00%
#
# file: uf100-0115.cnf, 115/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0116.cnf, 116/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0117.cnf, 117/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0118.cnf, 118/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0119.cnf, 119/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0120.cnf, 120/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0121.cnf, 121/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0122.cnf, 122/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-0123.cnf, 123/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0124.cnf, 124/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0125.cnf, 125/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 6
# Current Solvability: 0.00%
#
# file: uf100-0126.cnf, 126/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0127.cnf, 127/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0128.cnf, 128/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0129.cnf, 129/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0130.cnf, 130/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0131.cnf, 131/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0132.cnf, 132/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0133.cnf, 133/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0134.cnf, 134/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0135.cnf, 135/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0136.cnf, 136/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0137.cnf, 137/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0138.cnf, 138/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0139.cnf, 139/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0140.cnf, 140/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0141.cnf, 141/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0142.cnf, 142/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0143.cnf, 143/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0144.cnf, 144/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0145.cnf, 145/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0146.cnf, 146/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0147.cnf, 147/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0148.cnf, 148/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0149.cnf, 149/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0150.cnf, 150/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0151.cnf, 151/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0152.cnf, 152/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0153.cnf, 153/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0154.cnf, 154/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0155.cnf, 155/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0156.cnf, 156/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0157.cnf, 157/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0158.cnf, 158/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0159.cnf, 159/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0160.cnf, 160/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0161.cnf, 161/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 7
# Current Solvability: 0.00%
#
# file: uf100-0162.cnf, 162/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0163.cnf, 163/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0164.cnf, 164/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 7
# Current Solvability: 0.00%
#
# file: uf100-0165.cnf, 165/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0166.cnf, 166/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0167.cnf, 167/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0168.cnf, 168/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0169.cnf, 169/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0170.cnf, 170/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 22
# Current Solvability: 0.00%
#
# file: uf100-0171.cnf, 171/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0172.cnf, 172/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0173.cnf, 173/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0174.cnf, 174/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0175.cnf, 175/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0176.cnf, 176/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0177.cnf, 177/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0178.cnf, 178/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0179.cnf, 179/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0180.cnf, 180/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0181.cnf, 181/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0182.cnf, 182/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0183.cnf, 183/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0184.cnf, 184/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0185.cnf, 185/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0186.cnf, 186/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0187.cnf, 187/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0188.cnf, 188/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0189.cnf, 189/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0190.cnf, 190/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0191.cnf, 191/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0192.cnf, 192/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0193.cnf, 193/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0194.cnf, 194/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0195.cnf, 195/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0196.cnf, 196/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0197.cnf, 197/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0198.cnf, 198/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0199.cnf, 199/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0200.cnf, 200/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0201.cnf, 201/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0202.cnf, 202/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0203.cnf, 203/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0204.cnf, 204/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0205.cnf, 205/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0206.cnf, 206/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0207.cnf, 207/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0208.cnf, 208/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 7
# Current Solvability: 0.00%
#
# file: uf100-0209.cnf, 209/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0210.cnf, 210/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0211.cnf, 211/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0212.cnf, 212/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0213.cnf, 213/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0214.cnf, 214/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0215.cnf, 215/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0216.cnf, 216/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0217.cnf, 217/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0218.cnf, 218/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0219.cnf, 219/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0220.cnf, 220/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0221.cnf, 221/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0222.cnf, 222/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0223.cnf, 223/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0224.cnf, 224/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0225.cnf, 225/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0226.cnf, 226/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0227.cnf, 227/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0228.cnf, 228/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0229.cnf, 229/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0230.cnf, 230/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0231.cnf, 231/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0232.cnf, 232/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 23
# Current Solvability: 0.00%
#
# file: uf100-0233.cnf, 233/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0234.cnf, 234/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0235.cnf, 235/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0236.cnf, 236/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0237.cnf, 237/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0238.cnf, 238/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0239.cnf, 239/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0240.cnf, 240/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0241.cnf, 241/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0242.cnf, 242/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0243.cnf, 243/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0244.cnf, 244/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0245.cnf, 245/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0246.cnf, 246/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0247.cnf, 247/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0248.cnf, 248/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0249.cnf, 249/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0250.cnf, 250/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-0251.cnf, 251/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0252.cnf, 252/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0253.cnf, 253/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0254.cnf, 254/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0255.cnf, 255/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0256.cnf, 256/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0257.cnf, 257/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0258.cnf, 258/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0259.cnf, 259/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0260.cnf, 260/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0261.cnf, 261/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0262.cnf, 262/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0263.cnf, 263/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0264.cnf, 264/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0265.cnf, 265/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0266.cnf, 266/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0267.cnf, 267/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0268.cnf, 268/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0269.cnf, 269/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0270.cnf, 270/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0271.cnf, 271/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0272.cnf, 272/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0273.cnf, 273/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0274.cnf, 274/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0275.cnf, 275/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 5
# Current Solvability: 0.00%
#
# file: uf100-0276.cnf, 276/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0277.cnf, 277/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0278.cnf, 278/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0279.cnf, 279/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0280.cnf, 280/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0281.cnf, 281/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0282.cnf, 282/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0283.cnf, 283/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0284.cnf, 284/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 19
# Current Solvability: 0.00%
#
# file: uf100-0285.cnf, 285/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0286.cnf, 286/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0287.cnf, 287/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0288.cnf, 288/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0289.cnf, 289/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0290.cnf, 290/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0291.cnf, 291/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0292.cnf, 292/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0293.cnf, 293/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0294.cnf, 294/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0295.cnf, 295/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0296.cnf, 296/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0297.cnf, 297/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0298.cnf, 298/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0299.cnf, 299/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0300.cnf, 300/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0301.cnf, 301/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0302.cnf, 302/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0303.cnf, 303/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 24
# Current Solvability: 0.00%
#
# file: uf100-0304.cnf, 304/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0305.cnf, 305/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0306.cnf, 306/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0307.cnf, 307/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 7
# Current Solvability: 0.00%
#
# file: uf100-0308.cnf, 308/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 23
# Current Solvability: 0.00%
#
# file: uf100-0309.cnf, 309/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0310.cnf, 310/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0311.cnf, 311/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0312.cnf, 312/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0313.cnf, 313/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0314.cnf, 314/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0315.cnf, 315/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0316.cnf, 316/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0317.cnf, 317/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0318.cnf, 318/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0319.cnf, 319/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0320.cnf, 320/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0321.cnf, 321/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0322.cnf, 322/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0323.cnf, 323/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0324.cnf, 324/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0325.cnf, 325/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 21
# Current Solvability: 0.00%
#
# file: uf100-0326.cnf, 326/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0327.cnf, 327/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0328.cnf, 328/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0329.cnf, 329/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 22
# Current Solvability: 0.00%
#
# file: uf100-0330.cnf, 330/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0331.cnf, 331/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 9
# Current Solvability: 0.00%
#
# file: uf100-0332.cnf, 332/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0333.cnf, 333/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0334.cnf, 334/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0335.cnf, 335/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-0336.cnf, 336/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0337.cnf, 337/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0338.cnf, 338/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0339.cnf, 339/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0340.cnf, 340/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0341.cnf, 341/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 15
# Current Solvability: 0.00%
#
# file: uf100-0342.cnf, 342/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 11
# Current Solvability: 0.00%
#
# file: uf100-0343.cnf, 343/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0344.cnf, 344/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 14
# Current Solvability: 0.00%
#
# file: uf100-0345.cnf, 345/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 10
# Current Solvability: 0.00%
#
# file: uf100-0346.cnf, 346/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 13
# Current Solvability: 0.00%
#
# file: uf100-0347.cnf, 347/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 16
# Current Solvability: 0.00%
#
# file: uf100-0348.cnf, 348/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 17
# Current Solvability: 0.00%
#
# file: uf100-0349.cnf, 349/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 18
# Current Solvability: 0.00%
#
# file: uf100-0350.cnf, 350/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 12
# Current Solvability: 0.00%
#
# file: uf100-0351.cnf, 351/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-0352.cnf, 352/1000
# NOT SATISFIED! HYPER_MAX_ITER: 1,  last num_unsat_clause: 20
# Current Solvability: 0.00%
#
# file: uf100-0353.cnf, 353/1000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy
import os
import re
import json
import datetime

def plot_success_distribution_hyper(iter_save_path):

    # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
    config_path = iter_save_path + '.json'
    numpy_path = iter_save_path + '.npy'
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file not found: {config_path}")

    with open(config_path, 'r') as config_file:
        config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.


    # 저장된 NumPy 배열을 로드합니다.
    success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.
    print(config)
    # print(success_iter_array)

    # 숫자 50과 218을 추출하는 정규 표현식
    numbers = re.findall(r'\d+', numpy_path)
    # 추출된 숫자 확인
    if len(numbers) >= 2:
        variable_num, clause_num = numbers[0], numbers[1]
    else:
        assert False, "No matching numbers found."

    # 성공적인 반복 수를 추출합니다.
    success_counts = success_iter_array[:, 3]  # hyper_iter
    total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
    solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

    # 분포도 그리기
    fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

    # y축 방향의 grid를 가장 뒤에 배치
    ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

    # 히스토그램 생성
    z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
    counts, bins, patches = ax1.hist(
        
        success_counts, bins = np.arange(0, config["HYPER_MAX_ITER"] + 2) - z , 
        # success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
        edgecolor='black', alpha=0.7, label='Success Iteration', zorder=1
    )
    
    # 제목과 축 레이블 설정
    ax1.set_title(f'{variable_num}v-{clause_num}c Success Iteration | {total_problems} problems | {solved_files} solved | {config["num_rows"]} rows | lfsr_bit {config["LFSR_BIT"]}\nstochastic update {config["stochastic_mode_start_iter"]} | max iter {config["HYPER_MAX_ITER"]} | rotation {config["max_iter"]} | seed {config["hyper_seed"]} | sto_rot {config["STO_ROTATION"]} | total rot {config["total_rot"]}')  
    ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
    ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
    # ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
    ax1.set_xticks(np.arange(0, config["HYPER_MAX_ITER"] + 1, step=(config["HYPER_MAX_ITER"] // 10) + 1))  # x축 눈금 조정
    # ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

    # 막대 위에 빈도 수 표시
    for count, patch in zip(counts, patches):
        if count > 0:
            ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
        # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

    # 누적 비율을 계산하여 꺾은선 그래프 추가
    accumulated_count = 0
    cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
    for count in counts:  
        accumulated_count += count
        proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
        cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

    # 꺾은선 그래프의 2차 y축 생성
    ax2 = ax1.twinx()
    ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
    ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
    ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

    # 꺾은선 그래프 포인트 위에 비율 표시
    past_proportion = 0
    for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
        if proportion != past_proportion:
            ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
        past_proportion = proportion
        # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

    fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
    plt.show()  # 그래프를 화면에 표시합니다.

# 사용 예시
uf_name = BASE_PATH.split('/')[-2]
iter_save_path = f'iter_save_box/{uf_name}_iter_analysis_{current_time}_seed{hyper_seed}'  # 파일 경로를 지정합니다.
plot_success_distribution_hyper(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
# Out:
# {'HYPER_MAX_ITER': 1, 'hyper_seed': 50, 'num_rows': 10, 'num_cols': 12, 'BASE_PATH': '/data2/sat/uf100-430/', 'max_iter': 1, 'iter_verbose': False, 'max_problem': 1000, 'stochastic_mode_start_iter': 9999999, 'current_time': '20241217_144325', 'STO_ROTATION': 0, 'LFSR_BIT': 2, 'total_rot': 1000}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 98
#      96 uf_name = BASE_PATH.split('/')[-2]
#      97 iter_save_path = f'iter_save_box/{uf_name}_iter_analysis_{current_time}_seed{hyper_seed}'  # 파일 경로를 지정합니다.
# ---> 98 plot_success_distribution_hyper(iter_save_path)
#
# Cell In[12], line 37, in plot_success_distribution_hyper(iter_save_path)
#      34     assert False, "No matching numbers found."
#      36 # 성공적인 반복 수를 추출합니다.
# ---> 37 success_counts = success_iter_array[:, 3]  # hyper_iter
#      38 total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
#      39 solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import random
# import copy
# import os
# import re
# import json
# import datetime
# hyper_seed = 1

# def plot_success_distribution(iter_save_path):
#     # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
#     config_path = iter_save_path + '.json'
#     numpy_path = iter_save_path + '.npy'
#     if not os.path.exists(config_path):
#         raise FileNotFoundError(f"Configuration file not found: {config_path}")

#     with open(config_path, 'r') as config_file:
#         config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.

#     # 저장된 NumPy 배열을 로드합니다.
#     success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.

#     # 숫자 50과 218을 추출하는 정규 표현식
#     numbers = re.findall(r'\d+', numpy_path)
#     # 추출된 숫자 확인
#     if len(numbers) >= 2:
#         variable_num, clause_num = numbers[0], numbers[1]
#     else:
#         assert False, "No matching numbers found."

#     # 성공적인 반복 수를 추출합니다.
#     assert len(success_iter_array) > 0, "No successful iteration found."
#     success_counts = success_iter_array[:, 2]  # SUCCESS_OR_NOT가 저장된 열을 선택하여 성공적인 반복 수를 가져옵니다.
#     total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
#     solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

#     # 분포도 그리기
#     fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

#     # y축 방향의 grid를 가장 뒤에 배치
#     ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

#     # 히스토그램 생성
#     z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
#     counts, bins, patches = ax1.hist(
#         success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
#         edgecolor='black', alpha=0.7, label='Success Iteration', zorder=1
#     )
#     # 제목과 축 레이블 설정
#     ax1.set_title(f'{variable_num}v-{clause_num}c Success Iteration | {total_problems} problems | {solved_files} solved | sto {config["stochastic_mode_start_iter"]}\nmax hyper iter {config["HYPER_MAX_ITER"]} | max iter {config["max_iter"]} | hyper seed {config["hyper_seed"]}')  # 그래프 제목을 설정합니다.
#     ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
#     ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
#     ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
#     ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

#     # 막대 위에 빈도 수 표시
#     for count, patch in zip(counts, patches):
#         if count > 0:
#             ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
#         # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

#     # 누적 비율을 계산하여 꺾은선 그래프 추가
#     accumulated_count = 0
#     cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
#     for count in counts:  
#         accumulated_count += count
#         proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
#         cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

#     # 꺾은선 그래프의 2차 y축 생성
#     ax2 = ax1.twinx()
#     ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
#     ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
#     ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

#     # 꺾은선 그래프 포인트 위에 비율 표시
#     past_proportion = 0
#     for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
#         if proportion != past_proportion:
#             ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
#         past_proportion = proportion
#         # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

#     fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
#     plt.show()  # 그래프를 화면에 표시합니다.


# def plot_success_distribution_hyper(iter_save_path):

#     # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
#     config_path = iter_save_path + '.json'
#     numpy_path = iter_save_path + '.npy'
#     if not os.path.exists(config_path):
#         raise FileNotFoundError(f"Configuration file not found: {config_path}")

#     with open(config_path, 'r') as config_file:
#         config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.


#     # 저장된 NumPy 배열을 로드합니다.
#     success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.
#     print(config)
#     print(success_iter_array)

#     # 숫자 50과 218을 추출하는 정규 표현식
#     numbers = re.findall(r'\d+', numpy_path)
#     # 추출된 숫자 확인
#     if len(numbers) >= 2:
#         variable_num, clause_num = numbers[0], numbers[1]
#     else:
#         assert False, "No matching numbers found."

#     # 성공적인 반복 수를 추출합니다.
#     success_counts = success_iter_array[:, 3]  # hyper_iter
#     total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
#     solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

#     # 분포도 그리기
#     fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

#     # y축 방향의 grid를 가장 뒤에 배치
#     ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

#     # 히스토그램 생성
#     z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
#     counts, bins, patches = ax1.hist(
#         success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
#         edgecolor='black', alpha=0.7, label='Success Hyper Iteration', zorder=1
#     )
    
#     # 제목과 축 레이블 설정
#     ax1.set_title(f'{variable_num}v-{clause_num}c Success Hyper Iteration | {total_problems} problems | {solved_files} solved | sto {config["stochastic_mode_start_iter"]}\nmax hyper iter {config["HYPER_MAX_ITER"]} | max iter {config["max_iter"]} | hyper seed {config["hyper_seed"]}')  
#     ax1.set_xlabel('Hyper Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
#     ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
#     ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
#     ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

#     # 막대 위에 빈도 수 표시
#     for count, patch in zip(counts, patches):
#         if count > 0:
#             ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
#         # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

#     # 누적 비율을 계산하여 꺾은선 그래프 추가
#     accumulated_count = 0
#     cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
#     for count in counts:  
#         accumulated_count += count
#         proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
#         cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

#     # 꺾은선 그래프의 2차 y축 생성
#     ax2 = ax1.twinx()
#     ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
#     ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
#     ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

#     # 꺾은선 그래프 포인트 위에 비율 표시
#     past_proportion = 0
#     for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
#         if proportion != past_proportion:
#             ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
#         past_proportion = proportion
#         # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

#     fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
#     plt.show()  # 그래프를 화면에 표시합니다.


# # 사용 예시
# iter_save_path = f'iter_save_box/uf50-218_iter_analysis_{current_time}_seed{hyper_seed}'  # 파일 경로를 지정합니다.
# plot_success_distribution(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
# plot_success_distribution_hyper(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# 리스트 정의
n_bit = 2
L = list(range(1, 2**n_bit))  # 1부터 2^n_bit - 1까지 생성
A = [0, 1, 2, 3]
B = [0, 1, 2, 3]

# 시뮬레이션 반복 횟수
num_simulations = 1000000

# 조건 만족 횟수
go_down_count = 0
go_tog_count = 0
go_up_count = 0

# 저장용 리스트
results = []

# 시뮬레이션 시작
for _ in range(num_simulations):
    # 무작위 선택
    l = random.choice(L)
    a = random.choice(A)
    b = random.choice(B)
    
    # 조건 체크
    if l * (a + b) < (2**n_bit) * a:  # a가 0이면 나눗셈 불가능, 제외
        go_down_count += 1
    if l * (a + b) == (2**n_bit) * a:  # a가 0이면 나눗셈 불가능, 제외
        go_tog_count += 1
    if l * (a + b) > (2**n_bit) * a:  # a가 0이면 나눗셈 불가능, 제외
        go_up_count += 1

# 확률 계산
go_down_prob = go_down_count / num_simulations
go_tog_prob = go_tog_count / num_simulations
go_up_prob = go_up_count / num_simulations

# 결과 출력
print(f"Probability (go_down): {go_down_prob:.4f}")
print(f"Probability (go_tog): {go_tog_prob:.4f}")
print(f"Probability (go_up): {go_up_prob:.4f}")

# 막대그래프 생성
categories = ['go_down', 'go_tog', 'go_up']
probabilities = [go_down_prob, go_tog_prob, go_up_prob]

plt.bar(categories, probabilities, color=['blue', 'orange', 'green'])
plt.xlabel('Cases')
plt.ylabel('Probability')
plt.title(f'Probability Distribution (n_bit={n_bit})')
plt.ylim(0, 1)  # 확률은 0~1 사이

# 각 막대 위에 확률 표시
for i, prob in enumerate(probabilities):
    plt.text(i, prob + 0.02, f"{prob:.4f}", ha='center', fontsize=10, color='black')

plt.show()
# Out:
# Probability (go_down): 0.4162
# Probability (go_tog): 0.1664
# Probability (go_up): 0.4175
