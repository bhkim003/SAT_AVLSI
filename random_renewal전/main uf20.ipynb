# %%
# Simulation for SAT solving shardware
# reference: Shim, Chaeyun, Jooyoung Bae, and Bongjin Kim. "30.3 VIP-Sat: A Boolean Satisfiability Solver Featuring 5× 12 Variable In-Memory Processing Elements with 98% Solvability for 50-Variables 218-Clauses 3-SAT Problems." 2024 IEEE International Solid-State Circuits Conference (ISSCC). Vol. 67. IEEE, 2024.

# %%
# 데이터셋 위치  
# /data2/sat/uf50-218  
# /data2/sat/uf20-91 
# 출처: https://www.cs.ubc.ca/~hoos/SATLIB/benchm.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy 
import os
import re
import json
import datetime
from collections import defaultdict
import re

# %%
def count_files_in_directory(directory):
    try:
        # 폴더 내의 모든 파일 목록 가져오기
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        return files
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
        return None

# %%
def read_cnf_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    clauses = []

    clause_save_start = False
    clause_count = 0
    for line in lines:
        if clause_save_start == True:
            clause = list(map(int, line.strip().split()))
            assert clause[-1] == 0
            clause = clause[:-1]  # Remove the trailing 0
            clauses.append(clause)
            clause_count += 1
            if clause_count == num_clauses:
                break

        if line.startswith(('p')) and clause_save_start == False:
            clause_save_start = True
            _, _, num_vars, num_clauses = line.split()
            num_vars = int(num_vars)
            num_clauses = int(num_clauses)
    assert clause_save_start == True

    clauses = np.array(clauses)
    return clauses, num_vars, num_clauses

# %%
class VPE:
    def __init__(self, MY_VAR):
        """
        VPE 초기화 메서드
        :param MY_VAR: 이 VPE가 담당할 변수 (예: v1, v2 등)
        """
        self._MY_VAR = MY_VAR  # 이 VPE가 처리할 변수
        self.MY_STATE = 1       # 변수의 상태 

        self.clauses = []         # 변수가 속한 절들의 리스트
        self.neighbors = set()    # 상관관계 있는 이웃 변수들

    @property # MY_VAR 속성은 읽기 전용
    def MY_VAR(self):
        return self._MY_VAR
    
    def add_clause(self, all_clauses):
        """
        변수가 속한 절을 추가하는 메서드
        :param all_clauses: 전체 절들의 리스트
        """
        clauses_clone = copy.deepcopy(all_clauses)
        for clause in clauses_clone:
            clause_abs = [abs(x) for x in clause]

            if self.MY_VAR in clause_abs:
                self_index = clause_abs.index(self.MY_VAR)
                temp = clause[self_index]
                #주인공이 앞에 오게 저장
                clause = np.concatenate((clause[:self_index], clause[self_index + 1:]))  # self_index에서 요소 제거
                clause_abs = clause_abs[:self_index] + clause_abs[self_index+1:]
                temp2 = np.insert(clause, 0, temp) 
                self.clauses.append(temp2) 

                # 절 내에서 다른 변수들을 이웃으로 추가
                for var_abs in clause_abs:
                    self.neighbors.add(var_abs)

        # assert len(self.clauses) <= 32, f'{len(self.clauses)}'
        if len(self.clauses) > 32:
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print(f'32개 절 초과됨!!!! : Var{self._MY_VAR}에 {len(self.clauses)}개 추가됨.')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            
            # assert False
            
        # print('self._MY_VAR:', self._MY_VAR-1)
        # print('self.clauses:\n', np.abs(self.clauses)-1)
        # print('self.clauses unique:\n', len(np.unique(np.abs(self.clauses)-1)))
            
    def get_neighbors(self):
        """
        상관관계 있는 이웃 변수들을 반환하는 메서드
        """
        return list(self.neighbors)

    def process(self, var_state_array, stochastic_mode):
        """
        변수를 처리하는 메서드 (예: 값 업데이트 등)
        이 부분은 문제 해결 알고리즘에 따라 달라질 수 있음.
        """

        # Adder Tree
        tree_sum = 0

        non_trivial_clauses_count = 0.0 # VI가 중요한 절 개수
        up_count = 0.0
        down_count = 0.0

        # Clause Column
        # print(len(self.clauses),'개 연관 클로즈','v',self._MY_VAR-1)
        for clause in self.clauses:
            SI = 0 if clause[0] < 0 else 1 # 음수면 0, 양수면 1 
            SL = 0 if clause[1] < 0 else 1
            SR = 0 if clause[2] < 0 else 1

            VI = var_state_array[abs(clause[0])-1] # 현재 V값 가져오기
            VL = var_state_array[abs(clause[1])-1]
            VR = var_state_array[abs(clause[2])-1]

            assert VI == self.MY_STATE, f'{VI}, {self.MY_STATE}'

            # S와 V의 XOR값(같으면 0 다르면 1)이 3개가 나옴. (SIVI, SLVL, SRVR) 한개라도 XOR값이 0이어야 Clause satisfied.
            
            # Clause Logic
            if ((SL == 1 and VL == 0) or (SL == 0 and VL == 1)) and ((SR == 0 and VR == 1) or (SR == 1 and VR == 0)) == 1: 
                C0 = 1 # MY_VAR가 중요해졌다는 flag.
                C1 = 1 if SI == 0 else 0 # SI 토글
            else:
                C0 = 0
                C1 = 0

            # Adder Tree
            addi = 0
            if C0 == 1:
                non_trivial_clauses_count += 1.0
                if C1 == 1:
                    addi = -1
                    down_count += 1.0
                else: # C1 == 0
                    addi = 1
                    up_count += 1.0
            else: # C0 == 0
                addi = 0

            tree_sum = tree_sum + addi
            if self._MY_VAR-1 == 10:
                # print(f'clause[0]: {clause[0]}, clause[1]: {clause[1]}, clause[2]: {clause[2]}, C0: {C0}, C1: {C1}, SI: {SI}, SL: {SL}, VL: {VL}, SR: {SR}, VR: {VR}, VI: {VI}, addi: {addi}')
                pass
        # print('tree_sum',tree_sum,'\n')

        # Variable Update Logic
        if stochastic_mode == False:
            # DETERMINISTIC UPDATE MODE
            if tree_sum < 0:
                self.MY_STATE = 0
            elif tree_sum == 0:
                self.MY_STATE = 1 if self.MY_STATE == 0 else 0
                # pass
            elif tree_sum > 0:
                self.MY_STATE = 1
            else: 
                assert False
        else:
            # STOCHASTIC UPDATE MODE
            if tree_sum == 0:
                # self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
                p = 1/2
            else:
                p = down_count/non_trivial_clauses_count
                
            if random.random() < p:
                self.MY_STATE = 0
            else:
                self.MY_STATE = 1

        return self.MY_STATE

# %%
class VPE_ARRAY:
    def __init__(self, my_seed=42,  num_rows=5, num_cols=12, clauses=[[1,2,-3],[2,-1,57]], num_vars=50, num_clauses=218, what_file='uf50-03'):
        """
        VPE_ARRAY 초기화 메서드
        :param num_rows: VPE 배열의 행 개수 (기본값: 5)
        :param num_cols: VPE 배열의 열 개수 (기본값: 12)
        :param clauses: 3-SAT 문제의 절(clause) 리스트
        :param num_vars: 변수의 총 개수
        :param num_clauses: 절의 총 개수
        """
        self.my_seed = my_seed
        self.num_rows = num_rows  # 행 개수
        self.clauses = clauses
        self.num_cols = num_cols  # 열 개수
        self.num_vars = num_vars  # 변수의 총 개수
        self.var_init_seed = my_seed
        self.what_file = what_file

        # 랜덤 시드 초기화
        random.seed(self.my_seed)
        np.random.seed(self.my_seed)

        # 상관 관계 행렬 
        self.correlation_matrix = self.create_correlation_matrix()

        # VPE 배열 생성
        
        # self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_varaibles_to_vpe_with_file()
        self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_variables_to_vpe_shim()
        # self.VPE_index = np.load(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}_rows{self.num_rows}.npy', allow_pickle=True)

        # 딱 variable 개수만큼 배치 잘했는지 확인
        assert len(self.assigned_abs_vars) == self.num_vars, f'len(self.assigned_abs_vars): {len(self.assigned_abs_vars)}, self.num_vars: {self.num_vars}'
        assert sum(1 for i in range(self.num_rows) for j in range(self.num_cols) if self.VPES[i][j] is not None) == self.num_vars

        # 배치한 거 한번 보자
        # self.print_vpe_index()

        # uncorrelated columns check
        assert self.check_uncorrelated_columns(self.VPE_index, self.correlation_matrix)
        np.save(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}_rows{self.num_rows}.npy', self.VPE_index)

        # VPE 배열에 모든 절 삽입
        self.add_clause_to_vpe()
        
        # variable state initialize
        # self.var_state_array = self.variable_state_initialize()
        self.var_state_array = self.variable_state_initialize2()

        # deployment된 VPE들의 state값을 출력
        # self.print_var_state_array()
        
        # run
        # 외부에서 실행하세요.    


    def create_correlation_matrix(self):
        """
        상관 관계 행렬을 생성하는 메서드

        Args:
            clauses (list): 변수의 절(clause) 리스트
        """
        # 각 절(clause)에서 변수를 두 개씩 비교하며 상관 관계를 행렬에 기록
        correlation_matrix = np.zeros((self.num_vars, self.num_vars), dtype=int)
        for clause in self.clauses:
            for i, var1 in enumerate(clause):
                for var2 in clause[i + 1:]:
                    abs_var1, abs_var2 = abs(var1) - 1, abs(var2) - 1  # 변수 인덱스는 0부터 시작하므로 -1 처리
                    correlation_matrix[abs_var1, abs_var2] = 1  # 상관된 변수 간에는 1을 표시
                    correlation_matrix[abs_var2, abs_var1] = 1  # 상관 행렬은 대칭이므로 반대 방향도 동일하게 처리
        
        return correlation_matrix
    
    def assign_varaibles_to_vpe_with_file(self):
        # 사용한 변수를 추적하기 위한 리스트
        assigned_abs_vars = set()
        # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
        VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
        VPES_index = np.load(f'/home/bhkim003/SAT_AVLSI/mapping_box/vpe_index_for_{self.what_file}.npy', allow_pickle=True)
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if VPES_index[row][col] != None:
                    VPES[row][col] = VPE(VPES_index[row][col])
                    assigned_abs_vars.add(VPES_index[row][col])
        return VPES, VPES_index, assigned_abs_vars
    

        
    def assign_variables_to_vpe_shim(self):
        correlation_matrix_save = copy.deepcopy(self.correlation_matrix)
        assigned_abs_vars = set()
        deploy_search_iter = 0
        while True:
            # print('deploy_search_iter', deploy_search_iter)
            deploy_search_iter += 1
            self.correlation_matrix = copy.deepcopy(correlation_matrix_save)
            

            # 사용한 변수를 추적하기 위한 리스트
            assigned_abs_vars = set()

            # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
            VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
            VPES_index_past = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])

            # 변수 할당을 위한 작업
            current_row_at_column = [0 for _ in range(self.num_cols)]
            for whole_col_iter in range(1000): # 모든 컬럼 반복 # 근데 어차피 이전 iter와 변화가 없으면 걍 break된다.
                # print('whole_col_iter', whole_col_iter)
                

                # 같은 숫자는 섞기
                # shuffled_abs_vars_range1 = np.concatenate([np.random.shuffle(group) or group for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 if np.random.seed((self.my_seed+1)*(whole_col_iter+1)*(deploy_search_iter+1)) is None else None
                shuffled_abs_vars_range = np.concatenate([np.sort(group)[::-1] for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 
                
                if deploy_search_iter > 100:
                    shuffled_abs_vars_range = np.concatenate([np.random.shuffle(group) or group for group in [np.where(self.correlation_matrix.sum(axis=1) == total)[0] for total in sorted(set(self.correlation_matrix.sum(axis=1)), reverse=True)]], axis=0) + 1 if np.random.seed((self.my_seed+1)*(whole_col_iter+1)*(deploy_search_iter+1)) is None else None
                


                # combined_array = np.column_stack((shuffled_abs_vars_range-1, -np.sort(-self.correlation_matrix.sum(axis=1))))
                # for kkk in combined_array:
                #     print(kkk, end=' ')
                #     for lll in np.where(self.correlation_matrix[kkk[0]]==1)[0]:
                #         print(lll, end=' ')
                #     print()

                for col in range(self.num_cols):
                    if current_row_at_column[col] >= self.num_rows:  # 이 column에 모두 할당했으면 다음 column으로
                        continue
                    

                    # 상관 관계가 없는 변수들을 찾아서 같은 컬럼에 넣어!
                    col_chance = self.num_rows # 원하는 만큼 다 해 (한 컬럼에 한번에 몇개까지 넣을지)

                    for abs_var in shuffled_abs_vars_range:
                        if abs_var in assigned_abs_vars:
                            continue # next var  # 이미 할당된 변수는 건너뜀
                        

                        # 상관되지 않은 변수인지 확인
                        can_assign = True
                        for prev_row in range(current_row_at_column[col]):
                            prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                            if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                                can_assign = False
                                break # next var

                        if can_assign == True:
                            assert VPES[current_row_at_column[col]][col] == None
                            VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                            assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                            current_row_at_column[col] += 1
                            col_chance -= 1 

                        # stage1_cut_row = self.num_vars//self.num_cols - 1
                        if current_row_at_column[col] == self.num_rows or col_chance == 0:  # 이 column에 어느 정도 할당했으면 다음 column으로
                            break # next col;
                
                VPES_index_temp = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                if np.array_equal(VPES_index_past, VPES_index_temp) or len(assigned_abs_vars) == self.num_vars:
                    break
                else:
                    pass
                VPES_index_past = VPES_index_temp
            
            assert len(assigned_abs_vars) <= self.num_vars, f'ASSERT FALSE!! len(assigned_abs_vars): {len(assigned_abs_vars)}, self.num_vars: {self.num_vars}'
            if len(assigned_abs_vars) == self.num_vars:
                # print('deploy_search_iter', deploy_search_iter)
                VPES_index = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                break
        return VPES, VPES_index, assigned_abs_vars




    def check_uncorrelated_columns(self, VPE_index, correlation_matrix):
        num_rows = len(VPE_index)
        num_cols = len(VPE_index[0])
        for col in range(num_cols):
            col_values = [VPE_index[row][col] for row in range(num_rows) if VPE_index[row][col] is not None]
            for i in range(len(col_values)):
                for j in range(i + 1, len(col_values)):
                    var1 = col_values[i]
                    var2 = col_values[j]
                    if correlation_matrix[var1 - 1][var2 - 1] == 1:
                        return False
        return True

    def add_clause_to_vpe(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].add_clause(self.clauses)

    
    def variable_state_initialize(self):
        self.var_init_seed = self.my_seed
        random.seed(self.var_init_seed)
        var_state_array = [random.choice([0, 1]) for _ in range(self.num_vars)]

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].MY_STATE = var_state_array[self.VPES[row][col].MY_VAR - 1]
        return var_state_array
    
    def variable_state_initialize2(self):
        # np.random.seed(1)
        var_state_array = [None for _ in range(self.num_vars)]
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    draw = np.random.choice([0, 1], p=[0.5, 0.5])
                    self.VPES[row][col].MY_STATE = draw
                    var_state_array[self.VPES[row][col].MY_VAR - 1] = draw
        return var_state_array
    


    def satisfy_check(self, var_state_array, clauses):
        """
        절을 만족하는지 확인하는 메서드
        :param var_state_array: 변수들의 상태를 나타내는 배열 (0 또는 1로 구성된 리스트)
        :param clauses: 각 절을 표현하는 리스트의 리스트 (변수는 양수 또는 음수로 표현됨)
        :return: num_unsat_clause, unsat_clauses_list (만족되지 않은 절의 개수와 그 절들의 리스트)
        """
        unsat_clauses_list = []
        # 각 절에 대해 만족 여부를 확인
        for clause in clauses:
            satisfied = False  # 해당 절이 만족되는지 여부를 나타내는 변수

            for var in clause:
                abs_var = abs(var) - 1  # 변수의 절대값으로 인덱스를 맞춤 (0부터 시작)
                var_state = var_state_array[abs_var]  # 해당 변수의 상태

                if (var > 0 and var_state == 1) or (var < 0 and var_state == 0):
                    satisfied = True  
                    break # 하나라도 만족하는 변수가 있으면 절이 만족됨

            if satisfied == False:
                unsat_clauses_list.append(clause)  # 만족되지 않은 절을 리스트에 추가

        num_unsat_clause = len(unsat_clauses_list)  # 만족되지 않은 절의 개수

        return num_unsat_clause, unsat_clauses_list
    
    def print_var_state_array(self):
        # for row in range(self.num_rows):
        #     for col in range(self.num_cols):
        #         if self.VPE_index[row][col] != None:
        #             print(f'v{row * self.num_cols + col:<2} {self.VPE_index[row][col]:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
        #         else: 
        #             print(f'None    ', end=' | ')
        #     print()

        for col in range(self.num_cols):
            print(f'col{col:>2}', end='|||')
        print()

        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPE_index[row][col] != None:
                    print(f'v{self.VPE_index[row][col]-1:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
                else: 
                    print(f'None ', end=' | ')
            print()

        # f = open(f'sat_init_condition/{self.what_file}_init_condition.txt', 'w')  # 파일 열기
        # for row in range(self.num_rows):
        #     for col in range(self.num_cols):
        #         if self.VPE_index[row][col] != None:
        #             f.write(f'v{row * self.num_cols + col:<2} {self.VPE_index[row][col]:<2}={self.var_state_array[self.VPE_index[row][col]-1]} | ')
        #         else: 
        #             f.write(f'None     | ')
        #     f.write('\n')
        # f.close()
        
        # f_all = open(f'sat_init_condition/all_init_condition.txt', 'a')  # 파일 열기
        # problem_integer = int(re.search(r'-(\d+)', self.what_file).group(1))
        # f_all.write(f'\nmy %map{problem_integer} = (\n    ')
        # for row in range(self.num_rows):
        #     for col in range(self.num_cols):
        #         if self.VPE_index[row][col] != None:
        #             f_all.write(f'\'{self.VPE_index[row][col]:<2}\' => \'{row * self.num_cols + col}\', ')
        #         else:
        #             f_all.write(f'\'99\' => \'{row * self.num_cols + col}\', ')
        #     f_all.write('\n    ') if row != self.num_rows-1 else f.write('\n')
        # f_all.write(f'\n);\n\n')
        # f_all.close()
        
        # f_all_value = open(f'sat_init_condition/all_init_value.txt', 'a')  # 파일 열기
        # problem_integer = int(re.search(r'-(\d+)', self.what_file).group(1))
        # for row in range(self.num_rows):
        #     f_all_value.write(f'`define INIT_VAR{row}_PRO{problem_integer} \'{{')
        #     for col in range(self.num_cols):
        #         if self.VPE_index[row][col] != None:
        #             f_all_value.write(f'{self.var_state_array[self.VPE_index[row][col]-1]}')
        #         else:
        #             f_all_value.write(f'{0}')

        #         f_all_value.write(', ') if col != self.num_cols-1 else f_all_value.write('}')

                
        #     f_all_value.write('\n')
        # f_all_value.write(f'\n\n')
        # f_all_value.close()



    def run(self, max_iter, iter_verbose, stochastic_mode_start_iter):
        """
        VPE 배열을 실행하는 메서드
        :param max_iter: 최대 반복 횟수 (기본값: 100)
        """
        num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)

        if iter_verbose == True or True:
        # if iter_verbose == True :
            print('INITIAL VAR STATE ARRAY')
            print(f'iteration {0:>4} | num_unsat_clause: {num_unsat_clause}')
            self.print_var_state_array()
        for i in range(max_iter):
            # row-wise parellel processing
            for col in range(self.num_cols):
                state_temp_at_now_col = [None for _ in range(self.num_rows)]
                for row in range(self.num_rows):
                    if self.VPES[row][col] != None:

                        stochastic_mode = True if i+1 >= stochastic_mode_start_iter else False
                        state_temp_at_now_col[row] = self.VPES[row][col].process(self.var_state_array,stochastic_mode)

                # updated state update!!
                toggle_count = 0
                for row in range(self.num_rows):
                    if state_temp_at_now_col[row] != None:  
                        if self.var_state_array[self.VPES[row][col].MY_VAR - 1] != state_temp_at_now_col[row]:
                            toggle_count += 1
                        self.var_state_array[self.VPES[row][col].MY_VAR - 1] = state_temp_at_now_col[row]

                        
                if iter_verbose == True:
                    num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
                    print(f'\n\niter {i+1}- col {col} done, toggle_count: {toggle_count}' )
                    print(f'iteration {i+1:>4} | num_unsat_clause: {num_unsat_clause}')
                    self.print_var_state_array()

            num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)


            # 매번 검사해서 나가는 게 아니다.
            # if num_unsat_clause == 0:
            #     return i+1
            
            # iteration 마다 실패하면 다시 리셋하기 (근데 이러면 solvability 0)
            # self.var_state_array = self.variable_state_initialize()


        else:
            if num_unsat_clause == 0:
                return i+1
            else:
                if iter_verbose == True:
                    print(f"NOT SATISFIED! num_unsat_clause: {num_unsat_clause}, unsat_clauses_list: {unsat_clauses_list}, iteration: {i+1}")
                return -num_unsat_clause

# %%
def HYPER_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=18, file_path='/data2/sat/uf50-218/uf50-03.cnf', max_iter=100, iter_verbose=False, stochastic_mode_start_iter=9999999):
    clauses, num_vars, num_clauses = read_cnf_file(file_path)

    SUCCESS_OR_NOT = 0
    for hyper_iter in range(HYPER_MAX_ITER):
        # print(f'hyper_iter: {hyper_iter+1}', end = '  ')
        my_seed = hyper_seed * (hyper_iter+1)
        what_file = os.path.splitext(os.path.basename(file_path))[0]
        vpe_array = VPE_ARRAY(my_seed=my_seed, num_rows=num_rows, num_cols=num_cols, clauses=clauses, num_vars=num_vars, num_clauses=num_clauses, what_file=what_file)  # 5x12 VPE 배열 생성
        success_iter = vpe_array.run(max_iter, iter_verbose, stochastic_mode_start_iter)  # VPE processing 실행
        assert success_iter != 0, 'run메서드에서는 0이 나올 수는 없게 해놨다.'
        
        if success_iter > 0:
            print(f'SATISFIED!!!! hyper_iter: {hyper_iter+1}, success_iter: {success_iter}')
            SUCCESS_OR_NOT = success_iter # 양수면 성공임
            break
        # print(f'not satisfied. num_unsat_clause: {-success_iter}')
        # print()
    else:
        print(f'NOT SATISFIED! HYPER_MAX_ITER: {HYPER_MAX_ITER},  last num_unsat_clause: {-success_iter}')

    return SUCCESS_OR_NOT, hyper_iter+1

# %%
def FULL_FILE_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, BASE_PATH='/data2/sat/uf50-218/', max_iter=10, iter_verbose=False, max_problem = 1000, stochastic_mode_start_iter = 9999999, current_time="20241026_025657"):
    # 설정 값을 딕셔너리 형태로 저장
    config = {
        "HYPER_MAX_ITER": HYPER_MAX_ITER,
        "hyper_seed": hyper_seed,
        "num_rows": num_rows,
        "num_cols": num_cols,
        "BASE_PATH": BASE_PATH,
        "max_iter": max_iter,
        "iter_verbose": iter_verbose,
        "max_problem": max_problem,
        "stochastic_mode_start_iter": stochastic_mode_start_iter,
        "current_time": current_time
    }

    success_file_list = []
    fail_file_list = []
    
    # config.json 파일로 저장
    folder_name = os.path.basename(os.path.normpath(BASE_PATH))  # 마지막 폴더 이름을 추출합니다.
    iter_save_path = os.path.join(f'iter_save_box/{folder_name}_iter_analysis_{current_time}_seed{hyper_seed}')

    with open(iter_save_path + '.json', 'w') as config_file:
        json.dump(config, config_file, indent=4)  # JSON 형식으로 저장하며, 들여쓰기를 설정합니다.


    files = count_files_in_directory(BASE_PATH)
    assert files != None, '파일 못 불러오고 있따.'
    
    # 파일 이름에서 숫자만 추출하여 정렬
    def extract_number(file_name):
        numbers = re.findall(r'\d+', file_name) # 파일 이름에서 숫자를 추출
        # print(numbers)
        return int(numbers[-1]) if numbers else float('inf')  # 숫자가 없는 파일을 뒤로 정렬
    
    files.sort(key=extract_number)  # 파일 이름을 숫자 순으로 정렬
    
    total_file = len(files)
    num_success = 0
    current_file = 0

    success_iter_list = []
    for file in files:
        # if file != 'uf50-03.cnf':
        #     continue
        # if file != 'uf50-025.cnf':
        #     continue
        current_file += 1
        file_path = os.path.join(BASE_PATH, file)
        print(f'\nfile: {file}, {current_file}/{max_problem}   (real total: {total_file})')

        SUCCESS_OR_NOT, hyper_iter= HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose, stochastic_mode_start_iter=stochastic_mode_start_iter)
        # SUCCESS_OR_NOT가 양수면 성공(성공한 iter 수), 음수면 실패(불만족하는 clause 수)
        if SUCCESS_OR_NOT > 0:
            num_success += 1
            iter = SUCCESS_OR_NOT
            success_iter_list.append((min(total_file, max_problem), current_file, iter, hyper_iter))
            success_file_list.append(file)
        else:
            fail_file_list.append(file)
        print(f'Current Solvability: {100*num_success/current_file:.2f}%')
        
        if max_problem == current_file:
            break
    print(f'\n\nFinal Solvability: {100*num_success/current_file:.2f}%')
    print(f'')
    print(f'success_file_list: {success_file_list}')
    print(f'fail_file_list: {fail_file_list}')
    success_iter_array = np.array(success_iter_list, dtype=int)  # 정수형 배열로 변환
    np.save(iter_save_path , success_iter_array)  # NumPy 형식으로 저장

    # final solvability
    return num_success/current_file

# %%
HYPER_MAX_ITER = 7 #iteration

# BASE_PATH = '/data2/sat/uf50-218/'
BASE_PATH = '/data2/sat/uf20-91'
hyper_seed = 50
num_rows = 2
num_cols = 12
max_iter = 8 #rotation
iter_verbose = False # True # False
max_problem = 1000
stochastic_mode_start_iter = 9999999    #1    #9999999    #stochastic할 거면 1로 설정 
current_time = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
print(f'current_time: {current_time}')

solv_list = []
for for_loop_seed in range(hyper_seed,hyper_seed+1):
    print(f'\n\n\n\n\nfor_loop_seed: {for_loop_seed}\n\n\n\n\n')

    solvability = FULL_FILE_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, 
                    hyper_seed=for_loop_seed, 
                    num_rows=num_rows, 
                    num_cols=num_cols, 
                    BASE_PATH=BASE_PATH, 
                    max_iter=max_iter, 
                    iter_verbose=iter_verbose,
                    max_problem=max_problem,
                    stochastic_mode_start_iter=stochastic_mode_start_iter,
                    current_time=current_time)
    solv_list.append(solvability)
    print(f'solvability: {solvability*100:.2f}')

np.save(f'solv_list_save_box/solv_list_{current_time}.npy', solv_list) # NumPy로 저장
loaded_solv_list = np.load(f'solv_list_save_box/solv_list_{current_time}.npy') # NumPy로 로드
print(f"Mean: {np.mean(loaded_solv_list)}, Min: { np.min(loaded_solv_list)}, Max: {np.max(loaded_solv_list)}")
# Out:
# current_time: 20241214_163238
#
#
#
#
#
# for_loop_seed: 50
#
#
#
#
#
#
# file: uf20-01.cnf, 1/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v11=0 | v10=0 | v8 =0 | v4 =0 | v18=1 | v16=0 | v19=1 | v3 =1 | v7 =0 | v5 =0 | None  |
# None  | v0 =0 | v12=0 | v17=1 | v6 =1 | v15=1 | v13=0 | v9 =1 | v1 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v11=0 | v10=0 | v8 =1 | v4 =0 | v18=0 | v16=1 | v19=1 | v3 =0 | v7 =1 | v5 =1 | None  |
# None  | v0 =0 | v12=0 | v17=0 | v6 =0 | v15=1 | v13=1 | v9 =0 | v1 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v11=0 | v10=1 | v8 =1 | v4 =1 | v18=1 | v16=1 | v19=1 | v3 =0 | v7 =1 | v5 =0 | None  |
# None  | v0 =1 | v12=0 | v17=0 | v6 =0 | v15=0 | v13=1 | v9 =0 | v1 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v11=0 | v10=1 | v8 =0 | v4 =1 | v18=0 | v16=0 | v19=1 | v3 =0 | v7 =1 | v5 =1 | None  |
# None  | v0 =1 | v12=1 | v17=0 | v6 =1 | v15=0 | v13=1 | v9 =0 | v1 =0 | v2 =1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-02.cnf, 2/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v12=0 | v6 =0 | v0 =0 | v16=0 | v9 =1 | v17=0 | v11=1 | v4 =1 | v3 =0 | None  | None  |
# v13=0 | v7 =0 | v10=0 | v15=1 | v19=1 | v8 =1 | v5 =0 | v1 =1 | v2 =1 | v14=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-03.cnf, 3/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v9 =0 | v8 =0 | v6 =0 | v0 =0 | v19=1 | v13=0 | v15=1 | v2 =1 | v1 =0 | None  | None  |
# v18=0 | v7 =0 | v11=0 | v17=1 | v14=1 | v5 =1 | v10=0 | v4 =1 | v3 =1 | v16=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-04.cnf, 4/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v16=0 | v11=0 | v9 =0 | v8 =0 | v6 =0 | v2 =1 | v1 =0 | v0 =1 | v7 =1 | v15=0 | None  | None  |
# v19=0 | v3 =0 | v13=0 | v5 =1 | v12=1 | v10=1 | v18=0 | v4 =1 | v17=1 | v14=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v16=1 | v11=0 | v9 =0 | v8 =1 | v6 =0 | v2 =0 | v1 =1 | v0 =1 | v7 =0 | v15=1 | None  | None  |
# v19=1 | v3 =0 | v13=0 | v5 =0 | v12=0 | v10=1 | v18=1 | v4 =0 | v17=1 | v14=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v16=1 | v11=0 | v9 =1 | v8 =1 | v6 =1 | v2 =1 | v1 =1 | v0 =1 | v7 =0 | v15=1 | None  | None  |
# v19=0 | v3 =1 | v13=0 | v5 =0 | v12=0 | v10=0 | v18=1 | v4 =0 | v17=1 | v14=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-05.cnf, 5/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v17=0 | v8 =0 | v7 =0 | v18=0 | v4 =1 | v19=0 | v13=1 | v16=1 | v12=0 | v15=0 | None  |
# None  | v3 =0 | v10=0 | v2 =1 | v11=1 | v0 =1 | v14=0 | v5 =1 | v6 =1 | v9 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =1 | v17=0 | v8 =0 | v7 =1 | v18=0 | v4 =0 | v19=1 | v13=1 | v16=0 | v12=1 | v15=1 | None  |
# None  | v3 =0 | v10=0 | v2 =0 | v11=0 | v0 =1 | v14=1 | v5 =0 | v6 =1 | v9 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-06.cnf, 6/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v13=0 | v11=0 | v2 =0 | v15=0 | v9 =1 | v10=0 | v7 =1 | v4 =1 | v18=0 | v17=0 | None  |
# v12=0 | v16=0 | v0 =1 | v8 =1 | v19=1 | v5 =0 | v3 =1 | v1 =1 | v6 =0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 6
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v13=0 | v11=0 | v2 =1 | v15=0 | v9 =0 | v10=1 | v7 =1 | v4 =0 | v18=1 | v17=1 | None  |
# v12=0 | v16=0 | v0 =0 | v8 =0 | v19=1 | v5 =1 | v3 =0 | v1 =1 | v6 =0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v13=0 | v11=1 | v2 =1 | v15=1 | v9 =1 | v10=1 | v7 =1 | v4 =0 | v18=1 | v17=0 | None  |
# v12=1 | v16=0 | v0 =0 | v8 =0 | v19=0 | v5 =1 | v3 =0 | v1 =1 | v6 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-07.cnf, 7/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v14=0 | v16=0 | v9 =0 | v15=0 | v13=1 | v3 =0 | v2 =1 | v11=1 | v8 =0 | None  | None  |
# v10=0 | v12=0 | v0 =0 | v19=1 | v6 =1 | v5 =1 | v7 =0 | v17=1 | v4 =1 | v1 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-08.cnf, 8/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v19=0 | v17=0 | v11=0 | v4 =0 | v1 =1 | v14=0 | v13=1 | v9 =1 | v12=0 | None  | None  |
# v10=0 | v3 =0 | v6 =0 | v18=1 | v2 =1 | v0 =1 | v8 =0 | v5 =1 | v15=1 | v16=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-09.cnf, 9/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=0 | v19=0 | v10=0 | v18=0 | v14=0 | v12=1 | v8 =0 | v11=1 | v1 =1 | v7 =0 | None  | None  |
# v9 =0 | v15=0 | v2 =0 | v3 =1 | v4 =1 | v13=1 | v16=0 | v0 =1 | v6 =1 | v5 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 18
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v19=0 | v10=0 | v18=1 | v14=0 | v12=0 | v8 =1 | v11=1 | v1 =0 | v7 =1 | None  | None  |
# v9 =1 | v15=0 | v2 =0 | v3 =0 | v4 =0 | v13=1 | v16=1 | v0 =0 | v6 =1 | v5 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v19=0 | v10=1 | v18=1 | v14=1 | v12=1 | v8 =1 | v11=1 | v1 =0 | v7 =1 | None  | None  |
# v9 =0 | v15=1 | v2 =0 | v3 =0 | v4 =0 | v13=0 | v16=1 | v0 =0 | v6 =1 | v5 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v19=0 | v10=1 | v18=0 | v14=1 | v12=0 | v8 =0 | v11=1 | v1 =0 | v7 =1 | None  | None  |
# v9 =1 | v15=1 | v2 =1 | v3 =0 | v4 =1 | v13=0 | v16=1 | v0 =0 | v6 =0 | v5 =1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-010.cnf, 10/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v18=0 | v17=0 | v12=0 | v14=0 | v5 =1 | v8 =0 | v6 =1 | v2 =1 | v0 =0 | v15=0 | None  |
# None  | v10=0 | v7 =0 | v13=1 | v11=1 | v16=1 | v4 =0 | v19=1 | v3 =1 | v9 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-011.cnf, 11/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v16=0 | v7 =0 | v4 =0 | v17=0 | v8 =1 | v15=0 | v12=1 | v5 =1 | v14=0 | v0 =0 | None  |
# v11=0 | None  | v6 =0 | v1 =1 | v19=1 | v2 =1 | v10=0 | v13=1 | v3 =1 | v9 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-012.cnf, 12/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v4 =0 | v13=0 | v11=0 | v10=0 | v6 =0 | v18=1 | v9 =0 | v8 =1 | v1 =1 | v17=0 | None  | None  |
# v12=0 | v2 =0 | v5 =0 | v3 =1 | v16=1 | v15=1 | v14=0 | v7 =1 | v19=1 | v0 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-013.cnf, 13/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =0 | v2 =0 | v19=0 | v17=0 | v14=0 | v13=1 | v12=0 | v8 =1 | v15=1 | v11=0 | None  | None  |
# v4 =0 | v18=0 | v5 =0 | v16=1 | v10=1 | v6 =1 | v7 =0 | v9 =1 | v0 =1 | v1 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =1 | v2 =0 | v19=0 | v17=1 | v14=0 | v13=0 | v12=1 | v8 =1 | v15=0 | v11=1 | None  | None  |
# v4 =1 | v18=0 | v5 =0 | v16=0 | v10=0 | v6 =1 | v7 =1 | v9 =0 | v0 =1 | v1 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-014.cnf, 14/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=0 | v13=0 | v10=0 | v9 =0 | v6 =0 | v19=1 | v5 =0 | v8 =1 | v4 =1 | v12=0 | v14=0 | None  |
# v7 =0 | v18=0 | v1 =1 | v11=1 | v0 =1 | v16=0 | v3 =1 | v15=1 | v2 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-015.cnf, 15/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=0 | v16=0 | v6 =0 | v19=0 | v14=0 | v12=1 | v18=0 | v11=1 | v2 =1 | v8 =0 | v3 =0 | None  |
# v1 =0 | v15=0 | v0 =1 | v10=1 | v9 =1 | v5 =0 | v13=1 | v7 =1 | None  | v4 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-016.cnf, 16/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v15=0 | v9 =0 | v18=0 | v17=0 | v16=1 | v10=0 | v8 =1 | v6 =1 | v19=0 | None  | None  |
# v0 =0 | v11=0 | v4 =0 | v5 =1 | v13=1 | v14=1 | v7 =0 | v2 =1 | v12=1 | v3 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-017.cnf, 17/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 18
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v8 =0 | v19=0 | v0 =0 | v14=0 | v10=1 | v6 =0 | v13=1 | v9 =1 | v18=0 | v16=0 | None  |
# None  | v2 =0 | v12=0 | v5 =1 | v11=1 | v17=1 | v15=0 | v4 =1 | v3 =1 | v1 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-018.cnf, 18/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v18=0 | v4 =0 | v11=0 | v10=0 | v8 =1 | v16=0 | v9 =1 | v15=1 | v0 =0 | v1 =0 | None  |
# v2 =0 | v17=0 | v3 =1 | v12=1 | v5 =1 | v19=0 | v7 =1 | v14=1 | v6 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-019.cnf, 19/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v5 =0 | v16=0 | v10=0 | v8 =0 | v0 =1 | v4 =0 | v3 =1 | v2 =1 | v19=0 | None  | None  |
# v1 =0 | v6 =0 | v17=0 | v18=1 | v14=1 | v11=1 | v12=0 | v7 =1 | v15=1 | v9 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=1 | v5 =0 | v16=0 | v10=1 | v8 =0 | v0 =0 | v4 =1 | v3 =1 | v2 =0 | v19=1 | None  | None  |
# v1 =1 | v6 =0 | v17=0 | v18=0 | v14=0 | v11=1 | v12=1 | v7 =0 | v15=1 | v9 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-020.cnf, 20/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =0 | v4 =0 | v0 =0 | v16=0 | v11=0 | v9 =1 | v3 =0 | v5 =1 | v12=1 | v7 =0 | None  | None  |
# v18=0 | v17=0 | v13=0 | v6 =1 | v10=1 | v2 =1 | v14=0 | v19=1 | v1 =1 | v15=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =1 | v4 =0 | v0 =0 | v16=1 | v11=0 | v9 =0 | v3 =1 | v5 =1 | v12=0 | v7 =1 | None  | None  |
# v18=1 | v17=0 | v13=0 | v6 =0 | v10=0 | v2 =1 | v14=1 | v19=0 | v1 =1 | v15=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-021.cnf, 21/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =0 | v3 =0 | v17=0 | v9 =0 | v4 =0 | v1 =1 | v11=0 | v12=1 | v5 =1 | v19=0 | v14=0 | None  |
# v7 =0 | v2 =0 | v18=1 | v13=1 | v15=1 | v16=0 | v6 =1 | v0 =1 | v10=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-022.cnf, 22/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =0 | v14=0 | v13=0 | v11=0 | v10=0 | v0 =1 | v8 =0 | v7 =1 | v4 =1 | v6 =0 | v3 =0 | None  |
# v9 =0 | v1 =0 | v19=1 | v17=1 | v18=1 | v16=0 | v2 =1 | None  | v12=1 | v15=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =1 | v14=0 | v13=0 | v11=1 | v10=0 | v0 =0 | v8 =1 | v7 =1 | v4 =0 | v6 =1 | v3 =1 | None  |
# v9 =0 | v1 =0 | v19=0 | v17=0 | v18=1 | v16=1 | v2 =0 | None  | v12=1 | v15=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =1 | v14=0 | v13=1 | v11=1 | v10=1 | v0 =1 | v8 =1 | v7 =1 | v4 =0 | v6 =1 | v3 =0 | None  |
# v9 =1 | v1 =0 | v19=0 | v17=0 | v18=0 | v16=1 | v2 =0 | None  | v12=1 | v15=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =1 | v14=0 | v13=1 | v11=0 | v10=1 | v0 =0 | v8 =0 | v7 =1 | v4 =0 | v6 =1 | v3 =1 | None  |
# v9 =1 | v1 =1 | v19=0 | v17=1 | v18=0 | v16=1 | v2 =0 | None  | v12=0 | v15=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-023.cnf, 23/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =0 | v1 =0 | v16=0 | v14=0 | v10=0 | v6 =1 | v7 =0 | v5 =1 | v17=1 | v15=0 | None  | None  |
# v13=0 | v8 =0 | v3 =0 | v0 =1 | v19=1 | v4 =1 | v12=0 | v2 =1 | v18=1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =1 | v1 =0 | v16=0 | v14=1 | v10=0 | v6 =0 | v7 =1 | v5 =1 | v17=0 | v15=1 | None  | None  |
# v13=1 | v8 =0 | v3 =0 | v0 =0 | v19=0 | v4 =1 | v12=1 | v2 =0 | v18=1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =1 | v1 =0 | v16=1 | v14=1 | v10=1 | v6 =1 | v7 =1 | v5 =1 | v17=0 | v15=1 | None  | None  |
# v13=0 | v8 =1 | v3 =0 | v0 =0 | v19=0 | v4 =0 | v12=1 | v2 =0 | v18=1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v9 =1 | v1 =0 | v16=1 | v14=0 | v10=1 | v6 =0 | v7 =0 | v5 =1 | v17=0 | v15=1 | None  | None  |
# v13=1 | v8 =1 | v3 =1 | v0 =0 | v19=1 | v4 =0 | v12=1 | v2 =0 | v18=0 | v11=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-024.cnf, 24/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =0 | v8 =0 | v6 =0 | v13=0 | v11=0 | v0 =1 | v3 =0 | v1 =1 | v18=1 | v12=0 | v15=0 | None  |
# v2 =0 | v9 =0 | v7 =1 | v14=1 | v16=1 | v10=0 | v17=1 | v19=1 | v4 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-025.cnf, 25/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v5 =0 | v4 =0 | v19=0 | v17=0 | v12=1 | v0 =0 | v16=1 | v7 =1 | v6 =0 | v8 =0 | None  |
# v3 =0 | v18=0 | v2 =1 | v14=1 | v11=1 | v10=0 | v9 =1 | v15=1 | v13=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-026.cnf, 26/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v17=0 | v14=0 | v11=0 | v10=0 | v4 =1 | v3 =0 | v6 =1 | v0 =1 | v13=0 | v12=0 | None  |
# v9 =0 | v7 =0 | v15=1 | None  | v1 =1 | v2 =1 | v16=0 | v19=1 | v8 =1 | v5 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-027.cnf, 27/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v2 =0 | v14=0 | v4 =0 | v1 =0 | v13=1 | v8 =0 | v7 =1 | v18=1 | v3 =0 | v12=0 | v5 =0 |
# v15=0 | v9 =1 | v10=1 | v6 =1 | None  | v0 =0 | v16=1 | v17=1 | v11=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-028.cnf, 28/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v6 =0 | v4 =0 | v3 =0 | v16=0 | v12=0 | v0 =1 | v15=0 | v5 =1 | v19=1 | v11=0 | v8 =0 | None  |
# v10=0 | v9 =0 | v18=1 | v2 =1 | None  | v1 =1 | v17=0 | v14=1 | v13=1 | None  | v7 =0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v6 =1 | v4 =0 | v3 =0 | v16=1 | v12=0 | v0 =0 | v15=1 | v5 =1 | v19=0 | v11=1 | v8 =1 | None  |
# v10=0 | v9 =0 | v18=0 | v2 =0 | None  | v1 =1 | v17=1 | v14=0 | v13=1 | None  | v7 =0 | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-029.cnf, 29/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v17=0 | v19=0 | v15=0 | v13=0 | v12=1 | v7 =0 | v18=1 | v0 =1 | v1 =0 | None  | None  |
# v16=0 | v10=0 | v8 =0 | v3 =1 | v9 =1 | v4 =1 | v5 =0 | v11=1 | v6 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v17=0 | v19=0 | v15=1 | v13=0 | v12=0 | v7 =1 | v18=1 | v0 =0 | v1 =1 | None  | None  |
# v16=1 | v10=0 | v8 =0 | v3 =0 | v9 =0 | v4 =1 | v5 =1 | v11=0 | v6 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=1 | v17=0 | v19=1 | v15=1 | v13=1 | v12=1 | v7 =1 | v18=1 | v0 =0 | v1 =1 | None  | None  |
# v16=0 | v10=1 | v8 =0 | v3 =0 | v9 =0 | v4 =0 | v5 =1 | v11=0 | v6 =1 | v2 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-030.cnf, 30/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v9 =0 | v6 =0 | v18=0 | v17=0 | v5 =1 | v4 =0 | v2 =1 | v14=1 | v16=0 | v7 =0 | None  |
# v10=0 | v11=0 | v1 =1 | v0 =1 | v13=1 | v8 =0 | v12=1 | v3 =1 | v19=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-031.cnf, 31/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=0 | v6 =0 | v18=0 | v2 =0 | v5 =0 | v3 =1 | v0 =0 | v15=1 | v9 =1 | v13=0 | v7 =0 | None  |
# None  | v8 =0 | v19=0 | v11=1 | v14=1 | v10=1 | v16=0 | v12=1 | v4 =1 | None  | v1 =0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v6 =0 | v18=0 | v2 =1 | v5 =0 | v3 =0 | v0 =1 | v15=1 | v9 =0 | v13=1 | v7 =1 | None  |
# None  | v8 =0 | v19=0 | v11=0 | v14=0 | v10=1 | v16=1 | v12=0 | v4 =1 | None  | v1 =0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v6 =0 | v18=1 | v2 =1 | v5 =1 | v3 =1 | v0 =1 | v15=1 | v9 =0 | v13=1 | v7 =0 | None  |
# None  | v8 =1 | v19=0 | v11=0 | v14=0 | v10=0 | v16=1 | v12=0 | v4 =1 | None  | v1 =0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v6 =0 | v18=1 | v2 =0 | v5 =1 | v3 =0 | v0 =0 | v15=1 | v9 =0 | v13=1 | v7 =1 | None  |
# None  | v8 =1 | v19=1 | v11=0 | v14=1 | v10=0 | v16=1 | v12=0 | v4 =0 | None  | v1 =1 | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf20-032.cnf, 32/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v9 =0 | v12=0 | v3 =0 | v18=0 | v16=1 | v14=0 | v13=1 | v5 =1 | v0 =0 | None  | None  |
# v2 =0 | v15=0 | v11=0 | v1 =1 | v4 =1 | v7 =1 | v10=0 | v17=1 | v8 =1 | v6 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=1 | v9 =0 | v12=0 | v3 =1 | v18=0 | v16=0 | v14=1 | v13=1 | v5 =0 | v0 =1 | None  | None  |
# v2 =1 | v15=0 | v11=0 | v1 =0 | v4 =0 | v7 =1 | v10=1 | v17=0 | v8 =1 | v6 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 6
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=1 | v9 =0 | v12=1 | v3 =1 | v18=1 | v16=1 | v14=1 | v13=1 | v5 =0 | v0 =1 | None  | None  |
# v2 =0 | v15=1 | v11=0 | v1 =0 | v4 =0 | v7 =0 | v10=1 | v17=0 | v8 =1 | v6 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=1 | v9 =0 | v12=1 | v3 =0 | v18=1 | v16=0 | v14=0 | v13=1 | v5 =0 | v0 =1 | None  | None  |
# v2 =1 | v15=1 | v11=1 | v1 =0 | v4 =1 | v7 =0 | v10=1 | v17=0 | v8 =0 | v6 =1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v9 =0 | v12=0 | v3 =1 | v18=1 | v16=1 | v14=1 | v13=0 | v5 =1 | v0 =1 | None  | None  |
# v2 =1 | v15=0 | v11=0 | v1 =1 | v4 =0 | v7 =1 | v10=0 | v17=1 | v8 =0 | v6 =1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v9 =0 | v12=0 | v3 =0 | v18=0 | v16=1 | v14=1 | v13=0 | v5 =0 | v0 =1 | None  | None  |
# v2 =1 | v15=1 | v11=1 | v1 =1 | v4 =1 | v7 =0 | v10=1 | v17=0 | v8 =0 | v6 =1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v9 =1 | v12=1 | v3 =0 | v18=1 | v16=0 | v14=0 | v13=1 | v5 =0 | v0 =1 | None  | None  |
# v2 =1 | v15=1 | v11=0 | v1 =1 | v4 =1 | v7 =0 | v10=0 | v17=1 | v8 =1 | v6 =0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 7,  last num_unsat_clause: 1
# Current Solvability: 96.88%
#
# file: uf20-033.cnf, 33/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v6 =0 | v2 =0 | v18=0 | v13=0 | v12=1 | v5 =0 | v3 =1 | v7 =1 | v4 =0 | None  | None  |
# v9 =0 | v17=0 | v8 =0 | v16=1 | v0 =1 | v15=1 | v10=0 | v11=1 | v19=1 | v1 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.97%
#
# file: uf20-034.cnf, 34/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v7 =0 | v0 =0 | v1 =0 | v13=0 | v12=1 | v6 =0 | v9 =1 | v10=1 | v3 =0 | None  | None  |
# v5 =0 | v4 =0 | v18=0 | v11=1 | v8 =1 | v16=1 | v15=0 | v14=1 | v17=1 | v2 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 97.06%
#
# file: uf20-035.cnf, 35/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v6 =0 | v0 =0 | v17=0 | v16=0 | v13=0 | v3 =1 | v9 =0 | v7 =1 | v2 =1 | v18=0 | v12=0 | None  |
# None  | v15=0 | v11=0 | v19=1 | v14=1 | v10=1 | v5 =0 | v4 =1 | v8 =1 | None  | v1 =0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v6 =1 | v0 =0 | v17=0 | v16=1 | v13=0 | v3 =0 | v9 =1 | v7 =1 | v2 =0 | v18=1 | v12=1 | None  |
# None  | v15=0 | v11=0 | v19=0 | v14=0 | v10=1 | v5 =1 | v4 =0 | v8 =1 | None  | v1 =0 | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 97.14%
#
# file: uf20-036.cnf, 36/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v16=0 | v13=0 | v3 =0 | v17=0 | v12=0 | v11=1 | v10=0 | v14=1 | v2 =1 | v8 =0 | None  | None  |
# v15=0 | v19=0 | v5 =0 | v1 =1 | v4 =1 | v7 =1 | v18=0 | v6 =1 | v9 =1 | v0 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 97.22%
#
# file: uf20-037.cnf, 37/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v2 =0 | v13=0 | v10=0 | v4 =0 | v3 =0 | v17=1 | v5 =0 | v0 =1 | v9 =1 | v8 =0 | v12=0 | None  |
# None  | v7 =0 | v11=0 | v18=1 | v19=1 | v14=1 | v15=0 | v16=1 | v1 =1 | v6 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 17
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v2 =1 | v13=0 | v10=0 | v4 =1 | v3 =0 | v17=0 | v5 =1 | v0 =1 | v9 =0 | v8 =1 | v12=1 | None  |
# None  | v7 =0 | v11=0 | v18=0 | v19=0 | v14=1 | v15=1 | v16=0 | v1 =1 | v6 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v2 =1 | v13=0 | v10=1 | v4 =1 | v3 =1 | v17=1 | v5 =1 | v0 =1 | v9 =0 | v8 =1 | v12=0 | None  |
# None  | v7 =1 | v11=0 | v18=0 | v19=0 | v14=0 | v15=1 | v16=0 | v1 =1 | v6 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 97.30%
#
# file: uf20-038.cnf, 38/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v0 =0 | v13=0 | v1 =0 | v18=0 | v6 =0 | v3 =1 | v2 =0 | v12=1 | v11=1 | v8 =0 | v7 =0 | None  |
# None  | v14=0 | v15=0 | v9 =1 | v17=1 | v10=1 | v16=0 | v5 =1 | v19=1 | v4 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 97.37%
#
# file: uf20-039.cnf, 39/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =0 | v2 =0 | v18=0 | v10=0 | v19=0 | v13=1 | v15=0 | v11=1 | v7 =1 | v1 =0 | None  | None  |
# v17=0 | v6 =0 | v9 =0 | v0 =1 | v8 =1 | v12=1 | v16=0 | v14=1 | v4 =1 | v5 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =1 | v2 =0 | v18=0 | v10=1 | v19=0 | v13=0 | v15=1 | v11=1 | v7 =0 | v1 =1 | None  | None  |
# v17=1 | v6 =0 | v9 =0 | v0 =0 | v8 =0 | v12=1 | v16=1 | v14=0 | v4 =1 | v5 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =1 | v2 =0 | v18=1 | v10=1 | v19=1 | v13=1 | v15=1 | v11=1 | v7 =0 | v1 =1 | None  | None  |
# v17=0 | v6 =1 | v9 =0 | v0 =0 | v8 =0 | v12=0 | v16=1 | v14=0 | v4 =1 | v5 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 97.44%
#
# file: uf20-040.cnf, 40/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v14=0 | v12=0 | v1 =0 | v17=0 | v7 =1 | v6 =0 | v15=1 | v0 =1 | v13=0 | None  | None  |
# v16=0 | v3 =0 | v19=0 | v4 =1 | v10=1 | v8 =1 | v5 =0 | v2 =1 | v11=1 | v9 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v12=0 | v1 =1 | v17=0 | v7 =0 | v6 =1 | v15=1 | v0 =0 | v13=1 | None  | None  |
# v16=1 | v3 =0 | v19=0 | v4 =0 | v10=0 | v8 =1 | v5 =1 | v2 =0 | v11=1 | v9 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v12=1 | v1 =1 | v17=1 | v7 =1 | v6 =1 | v15=1 | v0 =0 | v13=1 | None  | None  |
# v16=0 | v3 =1 | v19=0 | v4 =0 | v10=0 | v8 =0 | v5 =1 | v2 =0 | v11=1 | v9 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v12=1 | v1 =0 | v17=1 | v7 =0 | v6 =0 | v15=1 | v0 =0 | v13=1 | None  | None  |
# v16=1 | v3 =1 | v19=1 | v4 =0 | v10=1 | v8 =0 | v5 =1 | v2 =0 | v11=0 | v9 =1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 97.50%
#
# file: uf20-041.cnf, 41/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v12=0 | v19=0 | v5 =0 | v15=0 | v9 =1 | v14=0 | v6 =1 | v17=1 | v2 =0 | v13=0 | None  |
# None  | None  | v11=0 | v10=0 | v7 =1 | v0 =1 | v16=1 | v4 =0 | v8 =1 | v3 =1 | v1 =0 | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 97.56%
#
# file: uf20-042.cnf, 42/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v14=0 | v1 =0 | v13=0 | v11=0 | v2 =1 | v16=0 | v4 =1 | v15=1 | v10=0 | None  | None  |
# v7 =0 | v3 =0 | v9 =0 | v0 =1 | v12=1 | v19=1 | v6 =0 | v5 =1 | v8 =1 | v17=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v1 =0 | v13=1 | v11=0 | v2 =0 | v16=1 | v4 =1 | v15=0 | v10=1 | None  | None  |
# v7 =1 | v3 =0 | v9 =0 | v0 =0 | v12=0 | v19=1 | v6 =1 | v5 =0 | v8 =1 | v17=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v1 =1 | v13=1 | v11=1 | v2 =1 | v16=1 | v4 =1 | v15=0 | v10=1 | None  | None  |
# v7 =0 | v3 =1 | v9 =0 | v0 =0 | v12=0 | v19=0 | v6 =1 | v5 =0 | v8 =1 | v17=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v14=0 | v1 =1 | v13=0 | v11=1 | v2 =0 | v16=0 | v4 =1 | v15=0 | v10=1 | None  | None  |
# v7 =1 | v3 =1 | v9 =1 | v0 =0 | v12=1 | v19=0 | v6 =1 | v5 =0 | v8 =0 | v17=1 | None  | None  |
# SATISFIED!!!! hyper_iter: 4, success_iter: 8
# Current Solvability: 97.62%
#
# file: uf20-043.cnf, 43/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v15=0 | v4 =0 | v19=0 | v12=0 | v9 =1 | v18=0 | v14=1 | v10=1 | v16=0 | v7 =0 | None  |
# None  | v5 =0 | v8 =0 | v2 =1 | v3 =1 | v1 =1 | v6 =0 | v17=1 | v0 =1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=1 | v15=0 | v4 =0 | v19=1 | v12=0 | v9 =0 | v18=1 | v14=1 | v10=0 | v16=1 | v7 =1 | None  |
# None  | v5 =0 | v8 =0 | v2 =0 | v3 =0 | v1 =1 | v6 =1 | v17=0 | v0 =1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=1 | v15=0 | v4 =1 | v19=1 | v12=1 | v9 =1 | v18=1 | v14=1 | v10=0 | v16=1 | v7 =0 | None  |
# None  | v5 =1 | v8 =0 | v2 =0 | v3 =0 | v1 =0 | v6 =1 | v17=0 | v0 =1 | v11=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 17
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=1 | v15=0 | v4 =1 | v19=0 | v12=1 | v9 =0 | v18=0 | v14=1 | v10=0 | v16=1 | v7 =1 | None  |
# None  | v5 =1 | v8 =1 | v2 =0 | v3 =1 | v1 =0 | v6 =1 | v17=0 | v0 =0 | v11=1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 7
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v15=0 | v4 =0 | v19=1 | v12=1 | v9 =1 | v18=1 | v14=0 | v10=1 | v16=1 | v7 =1 | None  |
# None  | v5 =0 | v8 =0 | v2 =1 | v3 =0 | v1 =1 | v6 =0 | v17=1 | v0 =0 | v11=1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v15=0 | v4 =0 | v19=0 | v12=0 | v9 =1 | v18=1 | v14=0 | v10=0 | v16=1 | v7 =1 | None  |
# None  | v5 =1 | v8 =1 | v2 =1 | v3 =1 | v1 =0 | v6 =1 | v17=0 | v0 =0 | v11=1 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v15=1 | v4 =1 | v19=0 | v12=1 | v9 =0 | v18=0 | v14=1 | v10=0 | v16=1 | v7 =1 | None  |
# None  | v5 =1 | v8 =0 | v2 =1 | v3 =1 | v1 =0 | v6 =0 | v17=1 | v0 =1 | v11=0 | None  | None  |
# NOT SATISFIED! HYPER_MAX_ITER: 7,  last num_unsat_clause: 1
# Current Solvability: 95.35%
#
# file: uf20-044.cnf, 44/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v6 =0 | v5 =0 | v17=0 | v7 =0 | v2 =1 | v15=0 | v13=1 | v4 =1 | v3 =0 | v11=0 | None  |
# v19=0 | v0 =0 | None  | v1 =1 | v8 =1 | v18=1 | v16=0 | v9 =1 | v10=1 | v12=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.45%
#
# file: uf20-045.cnf, 45/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v8 =0 | v18=0 | v11=0 | v7 =0 | v4 =1 | v2 =0 | v0 =1 | v12=1 | v9 =0 | v10=0 | None  |
# None  | None  | v15=0 | v17=0 | v19=1 | v13=1 | v1 =1 | v16=0 | v5 =1 | v6 =1 | v3 =0 | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.56%
#
# file: uf20-046.cnf, 46/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v17=0 | v9 =0 | v5 =0 | v2 =0 | v8 =1 | v3 =0 | v1 =1 | v11=1 | v10=0 | None  | None  |
# v13=0 | v4 =0 | v16=0 | v6 =1 | v14=1 | v19=1 | v12=0 | v15=1 | v0 =1 | v18=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.65%
#
# file: uf20-047.cnf, 47/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v14=0 | v0 =0 | v18=0 | v17=0 | v6 =1 | v11=0 | v10=1 | v7 =1 | v5 =0 | v8 =0 | None  |
# v13=0 | v9 =0 | v3 =1 | v16=1 | v1 =1 | v19=0 | v12=1 | v4 =1 | v2 =0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=1 | v14=0 | v0 =0 | v18=1 | v17=0 | v6 =0 | v11=1 | v10=1 | v7 =0 | v5 =1 | v8 =1 | None  |
# v13=0 | v9 =0 | v3 =0 | v16=0 | v1 =1 | v19=1 | v12=0 | v4 =1 | v2 =0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 17
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=1 | v14=0 | v0 =1 | v18=1 | v17=1 | v6 =1 | v11=1 | v10=1 | v7 =0 | v5 =1 | v8 =0 | None  |
# v13=1 | v9 =0 | v3 =0 | v16=0 | v1 =0 | v19=1 | v12=0 | v4 =1 | v2 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 95.74%
#
# file: uf20-048.cnf, 48/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v19=0 | v17=0 | v15=0 | v9 =0 | v8 =0 | v3 =1 | v16=0 | v11=1 | v4 =1 | v12=0 | v18=0 | None  |
# v14=0 | v2 =0 | v0 =1 | v6 =1 | v10=1 | v13=0 | v5 =1 | v7 =1 | v1 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.83%
#
# file: uf20-049.cnf, 49/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 4
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v12=0 | v11=0 | v17=0 | v2 =0 | v1 =1 | v16=0 | v9 =1 | v3 =1 | v19=0 | v6 =0 | None  |
# v14=0 | None  | v4 =0 | v5 =1 | v13=1 | v8 =1 | v15=0 | v0 =1 | v10=1 | v7 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v12=0 | v11=0 | v17=1 | v2 =0 | v1 =0 | v16=1 | v9 =1 | v3 =0 | v19=1 | v6 =1 | None  |
# v14=0 | None  | v4 =0 | v5 =0 | v13=0 | v8 =1 | v15=1 | v0 =0 | v10=1 | v7 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 95.92%
#
# file: uf20-050.cnf, 50/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v19=0 | v16=0 | v13=0 | v11=0 | v5 =1 | v7 =0 | v6 =1 | v4 =1 | v9 =0 | v18=0 | None  |
# v1 =0 | v8 =0 | v2 =1 | v14=1 | v10=1 | v0 =0 | v12=1 | v17=1 | None  | v3 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=1 | v19=0 | v16=0 | v13=1 | v11=0 | v5 =0 | v7 =1 | v6 =1 | v4 =0 | v9 =1 | v18=1 | None  |
# v1 =0 | v8 =0 | v2 =0 | v14=0 | v10=1 | v0 =1 | v12=0 | v17=1 | None  | v3 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 96.00%
#
# file: uf20-051.cnf, 51/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v10=0 | v7 =0 | v5 =0 | v14=0 | v13=0 | v2 =1 | v0 =0 | v6 =1 | v9 =1 | v17=0 | None  | None  |
# v8 =0 | v19=0 | v12=0 | v11=1 | v18=1 | v1 =1 | v3 =0 | v16=1 | v4 =1 | v15=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.08%
#
# file: uf20-052.cnf, 52/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v2 =0 | v6 =0 | v17=0 | v8 =0 | v4 =0 | v18=1 | v9 =0 | v0 =1 | v7 =1 | v1 =0 | None  | None  |
# v12=0 | v14=0 | v5 =0 | v19=1 | v13=1 | v15=1 | v3 =0 | v16=1 | v11=1 | v10=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.15%
#
# file: uf20-053.cnf, 53/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v16=0 | v12=0 | v10=0 | v0 =0 | v4 =1 | v2 =0 | v1 =1 | v18=1 | v3 =0 | None  | None  |
# v13=0 | v19=0 | v17=0 | v7 =1 | v11=1 | v14=1 | v6 =0 | v9 =1 | v8 =1 | v5 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.23%
#
# file: uf20-054.cnf, 54/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=0 | v19=0 | v6 =0 | v14=0 | v13=0 | v12=1 | v11=0 | v3 =1 | v8 =1 | v16=0 | None  | None  |
# v18=0 | v5 =0 | v4 =0 | v7 =1 | v15=1 | v9 =1 | v10=0 | v0 =1 | v1 =1 | v2 =0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v17=1 | v19=0 | v6 =0 | v14=1 | v13=0 | v12=0 | v11=1 | v3 =1 | v8 =0 | v16=1 | None  | None  |
# v18=1 | v5 =0 | v4 =0 | v7 =0 | v15=0 | v9 =1 | v10=1 | v0 =0 | v1 =1 | v2 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 96.30%
#
# file: uf20-055.cnf, 55/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v4 =0 | v19=0 | v17=0 | v16=0 | v2 =1 | v8 =0 | v7 =1 | v10=1 | v18=0 | v13=0 | None  |
# v11=0 | v3 =0 | v12=1 | v14=1 | v0 =1 | v6 =0 | v1 =1 | v5 =1 | v9 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.36%
#
# file: uf20-056.cnf, 56/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v12=0 | v1 =0 | v0 =0 | v6 =0 | v15=1 | v3 =0 | v2 =1 | v9 =1 | v19=0 | v8 =0 | None  |
# v13=0 | v5 =0 | v14=1 | v7 =1 | v4 =1 | v17=0 | v11=1 | v16=1 | v10=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.43%
#
# file: uf20-057.cnf, 57/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v14=0 | v0 =0 | v8 =0 | v6 =0 | v18=0 | v17=1 | v16=0 | v19=1 | v2 =1 | v13=0 | None  | None  |
# v11=0 | v5 =0 | v12=0 | v4 =1 | v9 =1 | v1 =1 | v3 =0 | v7 =1 | v10=1 | v15=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.49%
#
# file: uf20-058.cnf, 58/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v19=0 | v14=0 | v13=0 | v9 =0 | v4 =1 | v16=0 | v12=1 | v10=1 | v2 =0 | None  | None  |
# v7 =0 | v11=0 | v5 =0 | v3 =1 | v1 =1 | v6 =1 | v18=0 | v17=1 | v0 =1 | v8 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.55%
#
# file: uf20-059.cnf, 59/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v10=0 | v19=0 | v9 =0 | v6 =0 | v18=0 | v11=1 | v1 =0 | v5 =1 | v17=1 | v0 =0 | None  | None  |
# v7 =0 | v4 =0 | v15=0 | v16=1 | v8 =1 | v13=1 | v14=0 | v3 =1 | v2 =1 | v12=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.61%
#
# file: uf20-060.cnf, 60/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v6 =0 | v8 =0 | v3 =0 | v5 =0 | v19=0 | v10=1 | v9 =0 | v14=1 | v11=1 | v15=0 | v4 =0 | None  |
# None  | v1 =0 | v2 =0 | v13=1 | v18=1 | v12=1 | v0 =0 | v7 =1 | v17=1 | v16=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 96.67%
#
# file: uf20-061.cnf, 61/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v8 =0 | v19=0 | v11=0 | v10=0 | v4 =1 | v0 =0 | v12=1 | v7 =1 | v1 =0 | v14=0 | v16=0 |
# ...
# v18=1 | v19=0 | v2 =0 | v17=1 | v16=0 | v3 =0 | v13=1 | v5 =1 | v6 =0 | v14=1 | v8 =1 | None  |
# None  | v1 =0 | v10=0 | v11=0 | v4 =0 | v0 =1 | v9 =1 | v15=0 | v12=1 | v7 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 95.54%
#
# file: uf20-0988.cnf, 988/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v4 =0 | v16=0 | v14=0 | v10=0 | v17=0 | v2 =1 | v1 =0 | v9 =1 | v7 =1 | v6 =0 | None  | None  |
# v18=0 | v19=0 | v0 =0 | v12=1 | v11=1 | v15=1 | v13=0 | v8 =1 | v5 =1 | v3 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.55%
#
# file: uf20-0989.cnf, 989/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =0 | v0 =0 | v15=0 | v11=0 | v7 =0 | v13=1 | v8 =0 | v1 =1 | v14=1 | v6 =0 | v2 =0 | None  |
# None  | None  | v18=0 | v9 =0 | v10=1 | v4 =1 | v16=1 | v17=0 | v12=1 | v3 =1 | v19=0 | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v5 =1 | v0 =0 | v15=0 | v11=1 | v7 =0 | v13=0 | v8 =1 | v1 =1 | v14=0 | v6 =1 | v2 =1 | None  |
# None  | None  | v18=0 | v9 =0 | v10=0 | v4 =0 | v16=1 | v17=1 | v12=0 | v3 =1 | v19=0 | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 95.55%
#
# file: uf20-0990.cnf, 990/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 19
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v15=0 | v12=0 | v17=0 | v9 =0 | v3 =0 | v18=1 | v7 =0 | v1 =1 | v0 =1 | v16=0 | None  | None  |
# v2 =0 | v8 =0 | v10=0 | v13=1 | v6 =1 | v19=1 | v14=0 | v11=1 | v4 =1 | v5 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.56%
#
# file: uf20-0991.cnf, 991/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 3
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v17=0 | v9 =0 | v19=0 | v7 =0 | v2 =1 | v18=0 | v6 =1 | v11=1 | v13=0 | v0 =0 | None  |
# None  | v14=0 | v10=0 | v16=1 | v8 =1 | v5 =1 | v12=0 | v15=1 | v3 =1 | v4 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.56%
#
# file: uf20-0992.cnf, 992/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v13=0 | v15=0 | v14=0 | v17=0 | v7 =0 | v1 =1 | v0 =0 | v12=1 | v9 =1 | v4 =0 | v3 =0 | None  |
# v8 =0 | v10=0 | v19=1 | v18=1 | v2 =1 | v11=0 | v16=1 | v6 =1 | v5 =0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.56%
#
# file: uf20-0993.cnf, 993/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =0 | v4 =0 | v2 =0 | v19=0 | v7 =0 | v3 =1 | v8 =0 | v16=1 | v17=1 | v5 =0 | None  | None  |
# v10=0 | v0 =0 | v14=0 | v6 =1 | v18=1 | v11=1 | v12=0 | v15=1 | v9 =1 | v13=0 | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v1 =1 | v4 =0 | v2 =0 | v19=1 | v7 =0 | v3 =0 | v8 =1 | v16=1 | v17=0 | v5 =1 | None  | None  |
# v10=1 | v0 =0 | v14=0 | v6 =0 | v18=0 | v11=1 | v12=1 | v15=0 | v9 =1 | v13=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 2, success_iter: 8
# Current Solvability: 95.57%
#
# file: uf20-0994.cnf, 994/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v2 =0 | v1 =0 | v13=0 | v12=0 | v8 =0 | v9 =1 | v7 =0 | v4 =1 | v11=1 | v16=0 | None  | None  |
# v10=0 | v6 =0 | v5 =0 | v19=1 | v17=1 | v18=1 | v14=0 | v15=1 | v0 =1 | v3 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.57%
#
# file: uf20-0995.cnf, 995/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v17=0 | v14=0 | v13=0 | v12=0 | v9 =1 | v3 =0 | v11=1 | v2 =1 | v19=0 | v1 =0 | None  |
# v5 =0 | v8 =0 | v16=1 | v18=1 | v4 =1 | v0 =0 | v10=1 | v6 =1 | v15=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =1 | v17=0 | v14=0 | v13=1 | v12=0 | v9 =0 | v3 =1 | v11=1 | v2 =0 | v19=1 | v1 =1 | None  |
# v5 =0 | v8 =0 | v16=0 | v18=0 | v4 =1 | v0 =1 | v10=0 | v6 =1 | v15=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 6
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =1 | v17=0 | v14=1 | v13=1 | v12=1 | v9 =1 | v3 =1 | v11=1 | v2 =0 | v19=1 | v1 =0 | None  |
# v5 =1 | v8 =0 | v16=0 | v18=0 | v4 =0 | v0 =1 | v10=0 | v6 =1 | v15=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 15
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =1 | v17=0 | v14=1 | v13=0 | v12=1 | v9 =0 | v3 =0 | v11=1 | v2 =0 | v19=1 | v1 =1 | None  |
# v5 =1 | v8 =1 | v16=0 | v18=1 | v4 =0 | v0 =1 | v10=0 | v6 =0 | v15=1 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v17=0 | v14=0 | v13=1 | v12=1 | v9 =1 | v3 =1 | v11=0 | v2 =1 | v19=1 | v1 =1 | None  |
# v5 =0 | v8 =0 | v16=1 | v18=0 | v4 =1 | v0 =0 | v10=1 | v6 =0 | v15=1 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 10
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v7 =0 | v17=0 | v14=0 | v13=0 | v12=0 | v9 =1 | v3 =1 | v11=0 | v2 =0 | v19=1 | v1 =1 | None  |
# v5 =1 | v8 =1 | v16=1 | v18=1 | v4 =0 | v0 =1 | v10=0 | v6 =0 | v15=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 6, success_iter: 8
# Current Solvability: 95.58%
#
# file: uf20-0996.cnf, 996/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 16
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v9 =0 | v1 =0 | v15=0 | v14=0 | v11=1 | v5 =0 | v4 =1 | v3 =1 | v6 =0 | v7 =0 | None  |
# v16=0 | v18=0 | v2 =1 | v8 =1 | v19=1 | v0 =0 | v13=1 | v10=1 | v17=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 5
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=1 | v9 =0 | v1 =0 | v15=1 | v14=0 | v11=0 | v5 =1 | v4 =1 | v3 =0 | v6 =1 | v7 =1 | None  |
# v16=0 | v18=0 | v2 =0 | v8 =0 | v19=1 | v0 =1 | v13=0 | v10=1 | v17=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=1 | v9 =0 | v1 =1 | v15=1 | v14=1 | v11=1 | v5 =1 | v4 =1 | v3 =0 | v6 =1 | v7 =0 | None  |
# v16=1 | v18=0 | v2 =0 | v8 =0 | v19=0 | v0 =1 | v13=0 | v10=1 | v17=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=1 | v9 =0 | v1 =1 | v15=0 | v14=1 | v11=0 | v5 =0 | v4 =1 | v3 =0 | v6 =1 | v7 =1 | None  |
# v16=1 | v18=1 | v2 =0 | v8 =1 | v19=0 | v0 =1 | v13=0 | v10=0 | v17=1 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 14
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v12=0 | v9 =0 | v1 =0 | v15=1 | v14=1 | v11=1 | v5 =1 | v4 =0 | v3 =1 | v6 =1 | v7 =1 | None  |
# v16=0 | v18=0 | v2 =1 | v8 =0 | v19=1 | v0 =0 | v13=1 | v10=0 | v17=1 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 5, success_iter: 8
# Current Solvability: 95.58%
#
# file: uf20-0997.cnf, 997/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 13
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v3 =0 | v16=0 | v2 =0 | v8 =0 | v7 =0 | v6 =1 | v4 =0 | v11=1 | v19=1 | v9 =0 | None  | None  |
# v13=0 | v15=0 | v17=0 | v5 =1 | v14=1 | v12=1 | v10=0 | v0 =1 | v18=1 | v1 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.59%
#
# file: uf20-0998.cnf, 998/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 12
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v19=0 | v10=0 | v14=0 | v8 =0 | v5 =1 | v13=0 | v12=1 | v17=1 | v3 =0 | None  | None  |
# v1 =0 | v0 =0 | v2 =0 | v4 =1 | v7 =1 | v15=1 | v11=0 | v9 =1 | v6 =1 | v16=0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.59%
#
# file: uf20-0999.cnf, 999/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 9
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v8 =0 | v18=0 | v15=0 | v2 =0 | v14=0 | v11=1 | v0 =0 | v19=1 | v16=1 | v12=0 | v10=0 | None  |
# None  | v5 =0 | v4 =0 | v17=1 | v9 =1 | v3 =1 | v13=0 | v1 =1 | v7 =1 | v6 =0 | None  | None  |
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 95.60%
#
# file: uf20-01000.cnf, 1000/1000   (real total: 1000)
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=0 | v16=0 | v14=0 | v9 =0 | v1 =0 | v0 =1 | v15=0 | v8 =1 | v7 =1 | v6 =0 | v12=0 | None  |
# v19=0 | v4 =0 | v11=1 | v10=1 | v2 =1 | v5 =0 | v13=1 | v3 =1 | v17=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 8
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v16=0 | v14=0 | v9 =1 | v1 =0 | v0 =0 | v15=1 | v8 =1 | v7 =0 | v6 =1 | v12=1 | None  |
# v19=0 | v4 =0 | v11=0 | v10=0 | v2 =1 | v5 =1 | v13=0 | v3 =1 | v17=0 | None  | None  | None  |
# INITIAL VAR STATE ARRAY
# iteration    0 | num_unsat_clause: 11
# col 0|||col 1|||col 2|||col 3|||col 4|||col 5|||col 6|||col 7|||col 8|||col 9|||col10|||col11|||
# v18=1 | v16=0 | v14=1 | v9 =1 | v1 =1 | v0 =1 | v15=1 | v8 =1 | v7 =0 | v6 =1 | v12=0 | None  |
# v19=1 | v4 =0 | v11=0 | v10=0 | v2 =0 | v5 =1 | v13=0 | v3 =1 | v17=0 | None  | None  | None  |
# SATISFIED!!!! hyper_iter: 3, success_iter: 8
# Current Solvability: 95.60%
#
#
# Final Solvability: 95.60%
#
# success_file_list: ['uf20-01.cnf', 'uf20-02.cnf', 'uf20-03.cnf', 'uf20-04.cnf', 'uf20-05.cnf', 'uf20-06.cnf', 'uf20-07.cnf', 'uf20-08.cnf', 'uf20-09.cnf', 'uf20-010.cnf', 'uf20-011.cnf', 'uf20-012.cnf', 'uf20-013.cnf', 'uf20-014.cnf', 'uf20-015.cnf', 'uf20-016.cnf', 'uf20-017.cnf', 'uf20-018.cnf', 'uf20-019.cnf', 'uf20-020.cnf', 'uf20-021.cnf', 'uf20-022.cnf', 'uf20-023.cnf', 'uf20-024.cnf', 'uf20-025.cnf', 'uf20-026.cnf', 'uf20-027.cnf', 'uf20-028.cnf', 'uf20-029.cnf', 'uf20-030.cnf', 'uf20-031.cnf', 'uf20-033.cnf', 'uf20-034.cnf', 'uf20-035.cnf', 'uf20-036.cnf', 'uf20-037.cnf', 'uf20-038.cnf', 'uf20-039.cnf', 'uf20-040.cnf', 'uf20-041.cnf', 'uf20-042.cnf', 'uf20-044.cnf', 'uf20-045.cnf', 'uf20-046.cnf', 'uf20-047.cnf', 'uf20-048.cnf', 'uf20-049.cnf', 'uf20-050.cnf', 'uf20-051.cnf', 'uf20-052.cnf', 'uf20-053.cnf', 'uf20-054.cnf', 'uf20-055.cnf', 'uf20-056.cnf', 'uf20-057.cnf', 'uf20-058.cnf', 'uf20-059.cnf', 'uf20-060.cnf', 'uf20-061.cnf', 'uf20-062.cnf', 'uf20-063.cnf', 'uf20-064.cnf', 'uf20-065.cnf', 'uf20-066.cnf', 'uf20-067.cnf', 'uf20-068.cnf', 'uf20-069.cnf', 'uf20-070.cnf', 'uf20-071.cnf', 'uf20-072.cnf', 'uf20-073.cnf', 'uf20-074.cnf', 'uf20-075.cnf', 'uf20-076.cnf', 'uf20-077.cnf', 'uf20-078.cnf', 'uf20-079.cnf', 'uf20-080.cnf', 'uf20-081.cnf', 'uf20-082.cnf', 'uf20-083.cnf', 'uf20-084.cnf', 'uf20-085.cnf', 'uf20-086.cnf', 'uf20-087.cnf', 'uf20-088.cnf', 'uf20-089.cnf', 'uf20-090.cnf', 'uf20-091.cnf', 'uf20-092.cnf', 'uf20-093.cnf', 'uf20-094.cnf', 'uf20-095.cnf', 'uf20-096.cnf', 'uf20-097.cnf', 'uf20-098.cnf', 'uf20-099.cnf', 'uf20-0100.cnf', 'uf20-0101.cnf', 'uf20-0102.cnf', 'uf20-0103.cnf', 'uf20-0104.cnf', 'uf20-0105.cnf', 'uf20-0107.cnf', 'uf20-0108.cnf', 'uf20-0109.cnf', 'uf20-0110.cnf', 'uf20-0111.cnf', 'uf20-0112.cnf', 'uf20-0113.cnf', 'uf20-0114.cnf', 'uf20-0115.cnf', 'uf20-0116.cnf', 'uf20-0117.cnf', 'uf20-0118.cnf', 'uf20-0120.cnf', 'uf20-0121.cnf', 'uf20-0122.cnf', 'uf20-0123.cnf', 'uf20-0124.cnf', 'uf20-0125.cnf', 'uf20-0126.cnf', 'uf20-0127.cnf', 'uf20-0128.cnf', 'uf20-0129.cnf', 'uf20-0130.cnf', 'uf20-0131.cnf', 'uf20-0132.cnf', 'uf20-0133.cnf', 'uf20-0134.cnf', 'uf20-0135.cnf', 'uf20-0136.cnf', 'uf20-0137.cnf', 'uf20-0138.cnf', 'uf20-0139.cnf', 'uf20-0140.cnf', 'uf20-0141.cnf', 'uf20-0142.cnf', 'uf20-0143.cnf', 'uf20-0144.cnf', 'uf20-0145.cnf', 'uf20-0146.cnf', 'uf20-0147.cnf', 'uf20-0148.cnf', 'uf20-0149.cnf', 'uf20-0150.cnf', 'uf20-0151.cnf', 'uf20-0152.cnf', 'uf20-0153.cnf', 'uf20-0154.cnf', 'uf20-0155.cnf', 'uf20-0156.cnf', 'uf20-0157.cnf', 'uf20-0158.cnf', 'uf20-0159.cnf', 'uf20-0161.cnf', 'uf20-0162.cnf', 'uf20-0163.cnf', 'uf20-0164.cnf', 'uf20-0165.cnf', 'uf20-0166.cnf', 'uf20-0167.cnf', 'uf20-0168.cnf', 'uf20-0169.cnf', 'uf20-0170.cnf', 'uf20-0171.cnf', 'uf20-0172.cnf', 'uf20-0173.cnf', 'uf20-0174.cnf', 'uf20-0175.cnf', 'uf20-0176.cnf', 'uf20-0177.cnf', 'uf20-0178.cnf', 'uf20-0179.cnf', 'uf20-0181.cnf', 'uf20-0182.cnf', 'uf20-0184.cnf', 'uf20-0185.cnf', 'uf20-0186.cnf', 'uf20-0187.cnf', 'uf20-0188.cnf', 'uf20-0189.cnf', 'uf20-0190.cnf', 'uf20-0191.cnf', 'uf20-0192.cnf', 'uf20-0194.cnf', 'uf20-0195.cnf', 'uf20-0196.cnf', 'uf20-0197.cnf', 'uf20-0198.cnf', 'uf20-0199.cnf', 'uf20-0200.cnf', 'uf20-0201.cnf', 'uf20-0202.cnf', 'uf20-0203.cnf', 'uf20-0204.cnf', 'uf20-0205.cnf', 'uf20-0206.cnf', 'uf20-0207.cnf', 'uf20-0208.cnf', 'uf20-0209.cnf', 'uf20-0210.cnf', 'uf20-0211.cnf', 'uf20-0212.cnf', 'uf20-0213.cnf', 'uf20-0214.cnf', 'uf20-0215.cnf', 'uf20-0217.cnf', 'uf20-0218.cnf', 'uf20-0219.cnf', 'uf20-0220.cnf', 'uf20-0221.cnf', 'uf20-0222.cnf', 'uf20-0223.cnf', 'uf20-0224.cnf', 'uf20-0225.cnf', 'uf20-0226.cnf', 'uf20-0227.cnf', 'uf20-0228.cnf', 'uf20-0229.cnf', 'uf20-0230.cnf', 'uf20-0232.cnf', 'uf20-0233.cnf', 'uf20-0234.cnf', 'uf20-0237.cnf', 'uf20-0238.cnf', 'uf20-0239.cnf', 'uf20-0240.cnf', 'uf20-0241.cnf', 'uf20-0242.cnf', 'uf20-0243.cnf', 'uf20-0244.cnf', 'uf20-0245.cnf', 'uf20-0246.cnf', 'uf20-0247.cnf', 'uf20-0248.cnf', 'uf20-0249.cnf', 'uf20-0250.cnf', 'uf20-0251.cnf', 'uf20-0252.cnf', 'uf20- ...
# fail_file_list: ['uf20-032.cnf', 'uf20-043.cnf', 'uf20-0106.cnf', 'uf20-0119.cnf', 'uf20-0160.cnf', 'uf20-0180.cnf', 'uf20-0183.cnf', 'uf20-0193.cnf', 'uf20-0216.cnf', 'uf20-0231.cnf', 'uf20-0235.cnf', 'uf20-0236.cnf', 'uf20-0264.cnf', 'uf20-0316.cnf', 'uf20-0328.cnf', 'uf20-0384.cnf', 'uf20-0389.cnf', 'uf20-0408.cnf', 'uf20-0411.cnf', 'uf20-0442.cnf', 'uf20-0476.cnf', 'uf20-0495.cnf', 'uf20-0533.cnf', 'uf20-0552.cnf', 'uf20-0559.cnf', 'uf20-0670.cnf', 'uf20-0708.cnf', 'uf20-0715.cnf', 'uf20-0775.cnf', 'uf20-0777.cnf', 'uf20-0812.cnf', 'uf20-0825.cnf', 'uf20-0832.cnf', 'uf20-0842.cnf', 'uf20-0869.cnf', 'uf20-0880.cnf', 'uf20-0883.cnf', 'uf20-0887.cnf', 'uf20-0891.cnf', 'uf20-0927.cnf', 'uf20-0968.cnf', 'uf20-0971.cnf', 'uf20-0979.cnf', 'uf20-0981.cnf']
# solvability: 95.60
# Mean: 0.956, Min: 0.956, Max: 0.956

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy
import os
import re
import json
import datetime

def plot_success_distribution_hyper(iter_save_path):

    # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
    config_path = iter_save_path + '.json'
    numpy_path = iter_save_path + '.npy'
    if not os.path.exists(config_path):
        raise FileNotFoundError(f"Configuration file not found: {config_path}")

    with open(config_path, 'r') as config_file:
        config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.


    # 저장된 NumPy 배열을 로드합니다.
    success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.
    print(config)
    # print(success_iter_array)

    # 숫자 50과 218을 추출하는 정규 표현식
    numbers = re.findall(r'\d+', numpy_path)
    # 추출된 숫자 확인
    if len(numbers) >= 2:
        variable_num, clause_num = numbers[0], numbers[1]
    else:
        assert False, "No matching numbers found."

    # 성공적인 반복 수를 추출합니다.
    success_counts = success_iter_array[:, 3]  # hyper_iter
    total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
    solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

    # 분포도 그리기
    fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

    # y축 방향의 grid를 가장 뒤에 배치
    ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

    # 히스토그램 생성
    z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
    counts, bins, patches = ax1.hist(
        
        success_counts, bins = np.arange(0, config["HYPER_MAX_ITER"] + 2) - z , 
        # success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
        edgecolor='black', alpha=0.7, label='Success Iteration', zorder=1
    )
    
    # 제목과 축 레이블 설정
    ax1.set_title(f'{variable_num}v-{clause_num}c Success Iteration | {total_problems} problems | {solved_files} solved\nstochastic update {config["stochastic_mode_start_iter"]} | max iter {config["HYPER_MAX_ITER"]} | rotation {config["max_iter"]} | seed {config["hyper_seed"]}')  
    ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
    ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
    # ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
    ax1.set_xticks(np.arange(0, config["HYPER_MAX_ITER"] + 1, step=(config["HYPER_MAX_ITER"] // 10) + 1))  # x축 눈금 조정
    # ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

    # 막대 위에 빈도 수 표시
    for count, patch in zip(counts, patches):
        if count > 0:
            ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
        # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

    # 누적 비율을 계산하여 꺾은선 그래프 추가
    accumulated_count = 0
    cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
    for count in counts:  
        accumulated_count += count
        proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
        cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

    # 꺾은선 그래프의 2차 y축 생성
    ax2 = ax1.twinx()
    ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
    ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
    ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

    # 꺾은선 그래프 포인트 위에 비율 표시
    past_proportion = 0
    for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
        if proportion != past_proportion:
            ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
        past_proportion = proportion
        # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

    fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
    plt.show()  # 그래프를 화면에 표시합니다.

# 사용 예시
uf_name = BASE_PATH.split('/')[-1]
iter_save_path = f'iter_save_box/{uf_name}_iter_analysis_{current_time}_seed{hyper_seed}'  # 파일 경로를 지정합니다.
plot_success_distribution_hyper(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
# Out:
# {'HYPER_MAX_ITER': 7, 'hyper_seed': 50, 'num_rows': 2, 'num_cols': 12, 'BASE_PATH': '/data2/sat/uf20-91', 'max_iter': 8, 'iter_verbose': False, 'max_problem': 1000, 'stochastic_mode_start_iter': 9999999, 'current_time': '20241214_163238'}

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import random
# import copy
# import os
# import re
# import json
# import datetime
# hyper_seed = 1

# def plot_success_distribution(iter_save_path):
#     # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
#     config_path = iter_save_path + '.json'
#     numpy_path = iter_save_path + '.npy'
#     if not os.path.exists(config_path):
#         raise FileNotFoundError(f"Configuration file not found: {config_path}")

#     with open(config_path, 'r') as config_file:
#         config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.

#     # 저장된 NumPy 배열을 로드합니다.
#     success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.

#     # 숫자 50과 218을 추출하는 정규 표현식
#     numbers = re.findall(r'\d+', numpy_path)
#     # 추출된 숫자 확인
#     if len(numbers) >= 2:
#         variable_num, clause_num = numbers[0], numbers[1]
#     else:
#         assert False, "No matching numbers found."

#     # 성공적인 반복 수를 추출합니다.
#     assert len(success_iter_array) > 0, "No successful iteration found."
#     success_counts = success_iter_array[:, 2]  # SUCCESS_OR_NOT가 저장된 열을 선택하여 성공적인 반복 수를 가져옵니다.
#     total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
#     solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

#     # 분포도 그리기
#     fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

#     # y축 방향의 grid를 가장 뒤에 배치
#     ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

#     # 히스토그램 생성
#     z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
#     counts, bins, patches = ax1.hist(
#         success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
#         edgecolor='black', alpha=0.7, label='Success Iteration', zorder=1
#     )
#     # 제목과 축 레이블 설정
#     ax1.set_title(f'{variable_num}v-{clause_num}c Success Iteration | {total_problems} problems | {solved_files} solved | sto {config["stochastic_mode_start_iter"]}\nmax hyper iter {config["HYPER_MAX_ITER"]} | max iter {config["max_iter"]} | hyper seed {config["hyper_seed"]}')  # 그래프 제목을 설정합니다.
#     ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
#     ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
#     ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
#     ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

#     # 막대 위에 빈도 수 표시
#     for count, patch in zip(counts, patches):
#         if count > 0:
#             ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
#         # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

#     # 누적 비율을 계산하여 꺾은선 그래프 추가
#     accumulated_count = 0
#     cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
#     for count in counts:  
#         accumulated_count += count
#         proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
#         cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

#     # 꺾은선 그래프의 2차 y축 생성
#     ax2 = ax1.twinx()
#     ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
#     ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
#     ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

#     # 꺾은선 그래프 포인트 위에 비율 표시
#     past_proportion = 0
#     for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
#         if proportion != past_proportion:
#             ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
#         past_proportion = proportion
#         # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

#     fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
#     plt.show()  # 그래프를 화면에 표시합니다.


# def plot_success_distribution_hyper(iter_save_path):

#     # 설정 파일을 읽어 설정 값을 로드하는 함수입니다.
#     config_path = iter_save_path + '.json'
#     numpy_path = iter_save_path + '.npy'
#     if not os.path.exists(config_path):
#         raise FileNotFoundError(f"Configuration file not found: {config_path}")

#     with open(config_path, 'r') as config_file:
#         config = json.load(config_file)  # JSON 형식으로 저장된 설정 값을 불러옵니다.


#     # 저장된 NumPy 배열을 로드합니다.
#     success_iter_array = np.load(numpy_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.
#     print(config)
#     print(success_iter_array)

#     # 숫자 50과 218을 추출하는 정규 표현식
#     numbers = re.findall(r'\d+', numpy_path)
#     # 추출된 숫자 확인
#     if len(numbers) >= 2:
#         variable_num, clause_num = numbers[0], numbers[1]
#     else:
#         assert False, "No matching numbers found."

#     # 성공적인 반복 수를 추출합니다.
#     success_counts = success_iter_array[:, 3]  # hyper_iter
#     total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
#     solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

#     # 분포도 그리기
#     fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

#     # y축 방향의 grid를 가장 뒤에 배치
#     ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

#     # 히스토그램 생성
#     z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
#     counts, bins, patches = ax1.hist(
#         success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
#         edgecolor='black', alpha=0.7, label='Success Hyper Iteration', zorder=1
#     )
    
#     # 제목과 축 레이블 설정
#     ax1.set_title(f'{variable_num}v-{clause_num}c Success Hyper Iteration | {total_problems} problems | {solved_files} solved | sto {config["stochastic_mode_start_iter"]}\nmax hyper iter {config["HYPER_MAX_ITER"]} | max iter {config["max_iter"]} | hyper seed {config["hyper_seed"]}')  
#     ax1.set_xlabel('Hyper Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
#     ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
#     ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=bins.shape[0]//10+1))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
#     ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

#     # 막대 위에 빈도 수 표시
#     for count, patch in zip(counts, patches):
#         if count > 0:
#             ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
#         # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

#     # 누적 비율을 계산하여 꺾은선 그래프 추가
#     accumulated_count = 0
#     cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
#     for count in counts:  
#         accumulated_count += count
#         proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
#         cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

#     # 꺾은선 그래프의 2차 y축 생성
#     ax2 = ax1.twinx()
#     ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Solvability [%]', zorder=3)  
#     ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
#     ax2.set_ylabel('Solvability [%]')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

#     # 꺾은선 그래프 포인트 위에 비율 표시
#     past_proportion = 0
#     for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
#         if proportion != past_proportion:
#             ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='green', fontsize=15)  
#         past_proportion = proportion
#         # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

#     fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
#     plt.show()  # 그래프를 화면에 표시합니다.


# # 사용 예시
# iter_save_path = f'iter_save_box/uf50-218_iter_analysis_{current_time}_seed{hyper_seed}'  # 파일 경로를 지정합니다.
# plot_success_distribution(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
# plot_success_distribution_hyper(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
