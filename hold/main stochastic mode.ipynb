# %%
# Simulation for SAT solving shardware
# reference: Shim, Chaeyun, Jooyoung Bae, and Bongjin Kim. "30.3 VIP-Sat: A Boolean Satisfiability Solver Featuring 5× 12 Variable In-Memory Processing Elements with 98% Solvability for 50-Variables 218-Clauses 3-SAT Problems." 2024 IEEE International Solid-State Circuits Conference (ISSCC). Vol. 67. IEEE, 2024.

# %%
# 데이터셋 위치  
# /data2/sat/uf50-218  
# /data2/sat/uf20-91 
# 출처: https://www.cs.ubc.ca/~hoos/SATLIB/benchm.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy 
import os
import re

# %%
def count_files_in_directory(directory):
    try:
        # 폴더 내의 모든 파일 목록 가져오기
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        return files
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
        return None

# %%
def read_cnf_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    clauses = []

    clause_save_start = False
    clause_count = 0
    for line in lines:
        if clause_save_start == True:
            clause = list(map(int, line.strip().split()))
            assert clause[-1] == 0
            clause = clause[:-1]  # Remove the trailing 0
            clauses.append(clause)
            clause_count += 1
            if clause_count == num_clauses:
                break

        if line.startswith(('p')) and clause_save_start == False:
            clause_save_start = True
            _, _, num_vars, num_clauses = line.split()
            num_vars = int(num_vars)
            num_clauses = int(num_clauses)
    assert clause_save_start == True

    clauses = np.array(clauses)
    return clauses, num_vars, num_clauses

# %%
class VPE:
    def __init__(self, MY_VAR):
        """
        VPE 초기화 메서드
        :param MY_VAR: 이 VPE가 담당할 변수 (예: v1, v2 등)
        """
        self._MY_VAR = MY_VAR  # 이 VPE가 처리할 변수
        self.MY_STATE = 1       # 변수의 상태 

        self.clauses = []         # 변수가 속한 절들의 리스트
        self.neighbors = set()    # 상관관계 있는 이웃 변수들

    @property # MY_VAR 속성은 읽기 전용
    def MY_VAR(self):
        return self._MY_VAR
    
    def add_clause(self, all_clauses):
        """
        변수가 속한 절을 추가하는 메서드
        :param all_clauses: 전체 절들의 리스트
        """
        clauses_clone = copy.deepcopy(all_clauses)
        for clause in clauses_clone:
            clause_abs = [abs(x) for x in clause]

            if self.MY_VAR in clause_abs:
                self_index = clause_abs.index(self.MY_VAR)
                temp = clause[self_index]
                clause = np.concatenate((clause[:self_index], clause[self_index + 1:]))  # self_index에서 요소 제거
                clause_abs = clause_abs[:self_index] + clause_abs[self_index+1:]
                temp2 = np.insert(clause, 0, temp)
                self.clauses.append(temp2)

                # 절 내에서 다른 변수들을 이웃으로 추가
                for var_abs in clause_abs:
                    self.neighbors.add(var_abs)
        
        # assert len(self.clauses) <= 32, f'{len(self.clauses)}'
        if len(self.clauses) > 32:
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print(f'32개 절 초과됨!!!! : Var{self._MY_VAR}에 {len(self.clauses)}개 추가됨.')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            print('================================================================\n')
            
            # assert False
            
    def get_neighbors(self):
        """
        상관관계 있는 이웃 변수들을 반환하는 메서드
        """
        return list(self.neighbors)

    def process(self, var_state_array, stochastic_mode):
        """
        변수를 처리하는 메서드 (예: 값 업데이트 등)
        이 부분은 문제 해결 알고리즘에 따라 달라질 수 있음.
        """

        # Adder Tree
        tree_sum = 0

        non_trivial_clauses_count = 0.0 # VI가 중요한 절 개수
        up_count = 0.0
        down_count = 0.0

        # Clause Column
        for clause in self.clauses:
            SI = 0 if clause[0] < 0 else 1 # 음수면 0, 양수면 1 # sign bit 같은 거임.
            SL = 0 if clause[1] < 0 else 1
            SR = 0 if clause[2] < 0 else 1

            VI = var_state_array[abs(clause[0])-1] # 현재 V값 가져오기
            VL = var_state_array[abs(clause[1])-1]
            VR = var_state_array[abs(clause[2])-1]

            assert VI == self.MY_STATE, f'{VI}, {self.MY_STATE}'

            # S와 V의 XOR값(같으면 0 다르면 1)이 3개가 나옴. (SIVI, SLVL, SRVR) 한개라도 XOR값이 0이어야 Clause satisfied.
            
            # Clause Logic
            if (SL ^ VL) and (SR ^ VR) == 1: 
                C0 = 1 # MY_VAR가 중요해졌다는 flag.
                C1 = 1 if SI == 0 else 0 # SI 토글
            else:
                C0 = 0
                C1 = 0

            # Adder Tree
            if C0 == 1:
                non_trivial_clauses_count += 1.0
                if C1 == 1:
                    tree_sum += -1
                    down_count += 1.0
                else: # C1 == 0
                    tree_sum += 1
                    up_count += 1.0
            else: # C0 == 0
                tree_sum += 0

        if stochastic_mode == False:
            # Variable Update Logic
            if tree_sum < 0:
                self.MY_STATE = 0
            elif tree_sum == 0:
                self.MY_STATE = 1 if self.MY_STATE == 0 else 0
            elif tree_sum > 0:
                self.MY_STATE = 1
            else: 
                assert False
        else:
            # STOCHASTIC UPDATE
            if tree_sum == 0:
                # self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
                p = 1/2
            else:
                p = down_count/non_trivial_clauses_count
                
            if random.random() < p:
                self.MY_STATE = 0
            else:
                self.MY_STATE = 1

        return self.MY_STATE

# %%
class VPE_ARRAY:
    def __init__(self, my_seed=42,  num_rows=5, num_cols=12, clauses=[[1,2,-3],[2,-1,57]], num_vars=50, num_clauses=218):
        """
        VPE_ARRAY 초기화 메서드
        :param num_rows: VPE 배열의 행 개수 (기본값: 5)
        :param num_cols: VPE 배열의 열 개수 (기본값: 12)
        :param clauses: 3-SAT 문제의 절(clause) 리스트
        :param num_vars: 변수의 총 개수
        :param num_clauses: 절의 총 개수
        """
        self.my_seed = my_seed
        self.num_rows = num_rows  # 행 개수
        self.clauses = clauses
        self.num_cols = num_cols  # 열 개수
        self.num_vars = num_vars  # 변수의 총 개수

        # 랜덤 시드 초기화
        random.seed(self.my_seed)

        # 상관 관계 행렬 
        self.correlation_matrix = self.create_correlation_matrix()

        # VPE 배열 생성
        self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_variables_to_vpe()

        # uncorrelated columns check
        assert self.check_uncorrelated_columns(self.VPE_index, self.correlation_matrix)

        # VPE 배열에 모든 절 삽입
        self.add_clause_to_vpe()
        
        # variable state initialize
        self.var_state_array = self.variable_state_initialize()
        
        # run
        # 외부에서 실행하세요.    


    def create_correlation_matrix(self):
        """
        상관 관계 행렬을 생성하는 메서드

        Args:
            clauses (list): 변수의 절(clause) 리스트
        """
        # 각 절(clause)에서 변수를 두 개씩 비교하며 상관 관계를 행렬에 기록
        correlation_matrix = np.zeros((self.num_vars, self.num_vars), dtype=int)
        for clause in self.clauses:
            for i, var1 in enumerate(clause):
                for var2 in clause[i + 1:]:
                    abs_var1, abs_var2 = abs(var1) - 1, abs(var2) - 1  # 변수 인덱스는 0부터 시작하므로 -1 처리
                    correlation_matrix[abs_var1, abs_var2] = 1  # 상관된 변수 간에는 1을 표시
                    correlation_matrix[abs_var2, abs_var1] = 1  # 상관 행렬은 대칭이므로 반대 방향도 동일하게 처리
        
        return correlation_matrix
    
    def assign_variables_to_vpe(self):
        assigned_abs_vars = set()
        VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]

        deploy_search_iter = 0
        while True:
            deploy_search_iter += 1

            # 사용한 변수를 추적하기 위한 리스트
            assigned_abs_vars = set()

            # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
            VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
            
            # Stage 1 : numvars//numcols 만큼의 row까지만 할당
            # 변수 할당을 위한 작업
            current_row_at_column = [0 for _ in range(self.num_cols)]
            for col in range(self.num_cols):
                # 상관 관계가 없는 변수들을 찾음
                shuffled_abs_vars_range = list(range(1, self.num_vars + 1))
                random.shuffle(shuffled_abs_vars_range)
                for abs_var in shuffled_abs_vars_range:
                    if abs_var in assigned_abs_vars:
                        continue  # 이미 할당된 변수는 건너뜀

                    # 상관되지 않은 변수인지 확인
                    can_assign = True
                    for prev_row in range(current_row_at_column[col]):
                        prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                        if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                            can_assign = False
                            break

                    if can_assign == True:
                        assert VPES[current_row_at_column[col]][col] == None
                        VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                        assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                        current_row_at_column[col] += 1

                    if current_row_at_column[col] >= self.num_vars//self.num_cols:  # 이 column에 모두 할당했으면 다음 column으로
                        break

            # Stage 2: 나머지 row에 할당
            shuffled_col_list = list(range(self.num_cols))
            random.shuffle(shuffled_col_list)
            for col in shuffled_col_list:
                # 상관 관계가 없는 변수들을 찾음
                shuffled_abs_vars_range = list(range(1, self.num_vars + 1))
                random.shuffle(shuffled_abs_vars_range)
                for abs_var in shuffled_abs_vars_range:
                    if abs_var in assigned_abs_vars:
                        continue  # 이미 할당된 변수는 건너뜀

                    # 상관되지 않은 변수인지 확인
                    can_assign = True
                    for prev_row in range(current_row_at_column[col]):
                        prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                        if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                            can_assign = False
                            break

                    if can_assign == True:
                        VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                        assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                        current_row_at_column[col] += 1

                    if current_row_at_column[col] >= self.num_rows:  # 이 column에 모두 할당했으면 다음 column으로
                        break
            
            if len(assigned_abs_vars) == self.num_vars:
                # print('deploy_search_iter', deploy_search_iter)
                VPES_index = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                break
        return VPES, VPES_index, assigned_abs_vars

    def print_vpe_index(self):
        """
        VPE 배열을 2D 행렬로 출력하는 메서드
        """
        print('VPE Array:')
        for row_index, row in enumerate(self.VPE_index):
            formatted_row = '| '.join(f'v{row_index * len(row) + col_index:<2} {str(elem) if elem is not None else "No":>2}' 
                                        for col_index, elem in enumerate(row))
            print(formatted_row)
        print('\nnum of assigned_abs_vars:', len(self.assigned_abs_vars))
        

    def check_uncorrelated_columns(self, VPE_index, correlation_matrix):
        # VPE_index: VPE 배열의 인덱스를 나타냄. 각 값은 변수 번호를 의미함.
        # correlation_matrix: 변수들 간의 상관관계를 나타내는 행렬. (num_vars x num_vars 크기의 행렬)

        num_rows = len(VPE_index)
        # VPE_index의 행(row) 수를 얻음. 즉, VPE 배열에서 몇 개의 행이 있는지 확인.

        num_cols = len(VPE_index[0])
        # VPE_index의 열(column) 수를 얻음. 즉, 각 열에 몇 개의 변수가 배치되었는지 확인.

        for col in range(num_cols):
            # 각 열(column)을 순회함. 이때 col은 현재 처리 중인 열의 인덱스를 나타냄.

            col_values = [VPE_index[row][col] for row in range(num_rows) if VPE_index[row][col] is not None]
            # 현재 열에서 변수가 할당된 값을 모두 수집. None이 아닌 값만 선택하여 리스트로 만듦.
            # 즉, 해당 열에 배치된 변수 번호들을 수집하는 과정.

            for i in range(len(col_values)):
                # 수집한 변수 번호 리스트에서 첫 번째 변수부터 시작하여 다른 변수들과 비교하기 위해 반복문 시작.
                # i는 현재 비교하고자 하는 첫 번째 변수의 인덱스를 나타냄.

                for j in range(i + 1, len(col_values)):
                    # i 이후에 있는 변수들과 비교하기 위한 반복문.
                    # j는 두 번째로 비교할 변수의 인덱스를 나타냄.

                    var1 = col_values[i]
                    # 첫 번째 변수의 값(var1)을 col_values 리스트에서 가져옴.

                    var2 = col_values[j]
                    # 두 번째 변수의 값(var2)을 col_values 리스트에서 가져옴.

                    # 상관된 경우를 찾음
                    if correlation_matrix[var1 - 1][var2 - 1] == 1:
                        # correlation_matrix에서 var1과 var2가 상관된 경우를 확인.
                        # 변수 번호는 1부터 시작하므로, 0-based 인덱스에 맞추기 위해 -1 처리.
                        # 상관된 경우, correlation_matrix에서 해당 값이 1임을 이용하여 상관된 변수를 확인함.

                        # print(f"Error: Column {col+1} contains correlated variables {var1} and {var2}.")
                        # 상관된 변수를 발견한 경우, 그 변수가 어느 column에 있는지와 함께 에러 메시지를 출력.

                        return False
                        # 상관된 변수가 발견되면 더 이상 검사를 진행하지 않고 False를 반환하여 함수 종료.

        # 모든 열에 대해 상관된 변수가 없을 경우, 오류가 없음을 나타냄.
        # print("All columns are internally uncorrelated.\n")
        return True
        # 모든 열에서 상관된 변수가 없는 경우, True를 반환함.

    def add_clause_to_vpe(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].add_clause(self.clauses)

    
    def variable_state_initialize(self):
        var_state_array = [random.choice([0, 1]) for _ in range(self.num_vars)]
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].MY_STATE = var_state_array[self.VPES[row][col].MY_VAR - 1]
        return var_state_array
    


    def satisfy_check(self, var_state_array, clauses):
        """
        절을 만족하는지 확인하는 메서드
        :param var_state_array: 변수들의 상태를 나타내는 배열 (0 또는 1로 구성된 리스트)
        :param clauses: 각 절을 표현하는 리스트의 리스트 (변수는 양수 또는 음수로 표현됨)
        :return: num_unsat_clause, unsat_clauses_list (만족되지 않은 절의 개수와 그 절들의 리스트)
        """
        unsat_clauses_list = []

        # 각 절에 대해 만족 여부를 확인
        for clause in clauses:
            satisfied = False  # 해당 절이 만족되는지 여부를 나타내는 변수

            for var in clause:
                abs_var = abs(var) - 1  # 변수의 절대값으로 인덱스를 맞춤 (0부터 시작)
                var_state = var_state_array[abs_var]  # 해당 변수의 상태

                if (var > 0 and var_state == 1) or (var < 0 and var_state == 0):
                    satisfied = True  # 하나라도 만족하는 변수가 있으면 절이 만족됨
                    break

            if satisfied == False:
                unsat_clauses_list.append(clause)  # 만족되지 않은 절을 리스트에 추가

        num_unsat_clause = len(unsat_clauses_list)  # 만족되지 않은 절의 개수

        return num_unsat_clause, unsat_clauses_list
    
    def print_var_state_array(self):
        print('print self.var_state_array')
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPE_index[row][col] != None:
                    print(f'v{self.VPE_index[row][col]:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
                else: 
                    # print(f'vNo=None', end=' | ')
                    print(f'None ', end=' | ')
            print()
        print()

    def run(self, max_iter, iter_verbose):
        """
        VPE 배열을 실행하는 메서드
        :param max_iter: 최대 반복 횟수 (기본값: 100)
        """
        num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
        if iter_verbose == True:
            print(f'iteration {0:>4} | num_unsat_clause: {num_unsat_clause}')
        for i in range(max_iter):
            # self.print_var_state_array()

            # row-wise parellel processing
            for col in range(self.num_cols):
                # self.print_var_state_array()
                # num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
                # print(f'col {col}, num_unsat_clause: {num_unsat_clause}')
                state_temp_at_now_col = [None for _ in range(self.num_rows)]
                for row in range(self.num_rows):
                    if self.VPES[row][col] != None:
                        stochastic_mode = True
                        # stochastic_mode = False if i < 5 else True
                        state_temp_at_now_col[row] = self.VPES[row][col].process(self.var_state_array,stochastic_mode)

                    # updated state update!!
                for row in range(self.num_rows):
                    # print(state_temp_at_now_col)
                    if state_temp_at_now_col[row] != None:
                        self.var_state_array[self.VPES[row][col].MY_VAR - 1] = state_temp_at_now_col[row]

            num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
            if iter_verbose == True:
                print(f'iteration {i+1:>4} | num_unsat_clause: {num_unsat_clause}')


            if num_unsat_clause == 0:
                if iter_verbose == True:
                    print(f'SATISFIED!!!! iter{i+1}')
                return i+1
            
            # # iteration 마다 실패하면 다시 리셋하기
            # self.var_state_array = self.variable_state_initialize()


        else:
            if iter_verbose == True:
                print(f"NOT SATISFIED! num_unsat_clause: {num_unsat_clause}, unsat_clauses_list: {unsat_clauses_list}, iteration: {i+1}")
            return -num_unsat_clause

# %%
def HYPER_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=18, file_path='/data2/sat/uf50-218/uf50-03.cnf', max_iter=100, iter_verbose=False):
    clauses, num_vars, num_clauses = read_cnf_file(file_path)

    SUCCESS_OR_NOT = 0
    for hyper_iter in range(HYPER_MAX_ITER):
        # print(f'hyper_iter: {hyper_iter+1}', end = '  ')
        my_seed = hyper_seed * (hyper_iter+1)
        vpe_array = VPE_ARRAY(my_seed=my_seed, num_rows=num_rows, num_cols=num_cols, clauses=clauses, num_vars=num_vars, num_clauses=num_clauses)  # 5x12 VPE 배열 생성
        success_iter = vpe_array.run(max_iter, iter_verbose)  # VPE processing 실행
        assert success_iter != 0, 'run메서드에서는 0이 나올 수는 없게 해놨다.'
        
        if success_iter > 0:
            print(f'SATISFIED!!!! hyper_iter: {hyper_iter+1}, success_iter: {success_iter}')
            SUCCESS_OR_NOT = success_iter # 양수면 성공임
            break
        # print(f'not satisfied. num_unsat_clause: {-success_iter}')
        # print()
    else:
        print(f'HYPER_MAX_ITER: {HYPER_MAX_ITER}, NOT SATISFIED!  last num_unsat_clause: {-success_iter}')

    return SUCCESS_OR_NOT, hyper_iter

    # vpe_array.print_vpe_index()  # VPE 배열 출력

# %%
# HYPER_MAX_ITER = 1

# # file_path = 'example_uf50-03.cnf'
# file_path = '/data2/sat/uf50-218/uf50-02.cnf'
# hyper_seed = 42
# num_rows = 5
# num_cols = 12
# max_iter = 100
# iter_verbose = False

# # HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose)

# %%
def FULL_FILE_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, BASE_PATH='/data2/sat/uf50-218/', max_iter=10, iter_verbose=False, max_problem = 1000):
    
    files = count_files_in_directory(BASE_PATH)
    assert files != None, '파일 못 불러오고 있따.'
    
    # 파일 이름에서 숫자만 추출하여 정렬
    def extract_number(file_name):
        numbers = re.findall(r'\d+', file_name) # 파일 이름에서 숫자를 추출
        # print(numbers)
        return int(numbers[-1]) if numbers else float('inf')  # 숫자가 없는 파일을 뒤로 정렬
    
    files.sort(key=extract_number)  # 파일 이름을 숫자 순으로 정렬
    
    total_file = len(files)
    num_success = 0
    current_file = 0
    folder_name = os.path.basename(os.path.normpath(BASE_PATH))  # 마지막 폴더 이름을 추출합니다.
    iter_save_path = os.path.join(f'iter_save_box/{folder_name}_iter_analysis')
    success_iter_list = []
    for file in files:
        current_file += 1
        file_path = os.path.join(BASE_PATH, file)
        print(f'\nfile: {file}, {current_file}/{total_file}')

        SUCCESS_OR_NOT, hyper_iter= HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose)
        if SUCCESS_OR_NOT > 0:
            num_success += 1
            success_iter_list.append((min(total_file, max_problem), current_file, SUCCESS_OR_NOT, hyper_iter))
        print(f'Current Solvability: {100*num_success/current_file:.2f}%')
        
        if max_problem == current_file:
            break
    print(f'\n\nFinal Solvability: {100*num_success/current_file:.2f}%')

    success_iter_array = np.array(success_iter_list, dtype=int)  # 정수형 배열로 변환
    np.save(iter_save_path, success_iter_array)  # NumPy 형식으로 저장

# %%
HYPER_MAX_ITER = 1000

# BASE_PATH = '/data2/sat/uf50-218/uf50-02.cnf'
BASE_PATH = '/data2/sat/uf50-218/'
# BASE_PATH = '/data2/sat/uf20-91'
hyper_seed = 42
num_rows = 5
num_cols = 12
max_iter = 1000
iter_verbose = False
max_problem = 1000

FULL_FILE_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, 
                hyper_seed=hyper_seed, 
                num_rows=num_rows, 
                num_cols=num_cols, 
                BASE_PATH=BASE_PATH, 
                max_iter=max_iter, 
                iter_verbose=iter_verbose,
                max_problem=max_problem)
# Out:
# file: uf50-01.cnf, 1/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 40
# Current Solvability: 100.00%
#
# file: uf50-02.cnf, 2/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 708
# Current Solvability: 100.00%
#
# file: uf50-03.cnf, 3/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 4
# Current Solvability: 100.00%
#
# file: uf50-04.cnf, 4/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 34
# Current Solvability: 100.00%
#
# file: uf50-05.cnf, 5/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 100.00%
#
# file: uf50-06.cnf, 6/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 51
# Current Solvability: 100.00%
#
# file: uf50-07.cnf, 7/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 54
# Current Solvability: 100.00%
#
# file: uf50-08.cnf, 8/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 29
# Current Solvability: 100.00%
#
# file: uf50-09.cnf, 9/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 350
# Current Solvability: 100.00%
#
# file: uf50-010.cnf, 10/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 48
# Current Solvability: 100.00%
#
# file: uf50-011.cnf, 11/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 136
# Current Solvability: 100.00%
#
# file: uf50-012.cnf, 12/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 23
# Current Solvability: 100.00%
#
# file: uf50-013.cnf, 13/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 49
# Current Solvability: 100.00%
#
# file: uf50-014.cnf, 14/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 80
# Current Solvability: 100.00%
#
# file: uf50-015.cnf, 15/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 49
# Current Solvability: 100.00%
#
# file: uf50-016.cnf, 16/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 47
# Current Solvability: 100.00%
#
# file: uf50-017.cnf, 17/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 211
# Current Solvability: 100.00%
#
# file: uf50-018.cnf, 18/1000
# SATISFIED!!!! hyper_iter: 1, success_iter:
1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 80
# Current Solvability: 100.00%
#
# file: uf50-0343.cnf, 343/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 105
# Current Solvability: 100.00%
#
# file: uf50-0344.cnf, 344/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 817
# Current Solvability: 100.00%
#
# file: uf50-0345.cnf, 345/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 314
# Current Solvability: 100.00%
#
# file: uf50-0346.cnf, 346/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 342
# Current Solvability: 100.00%
#
# file: uf50-0347.cnf, 347/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 523
# Current Solvability: 100.00%
#
# file: uf50-0348.cnf, 348/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 57
# Current Solvability: 100.00%
#
# file: uf50-0349.cnf, 349/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 525
# Current Solvability: 100.00%
#
# file: uf50-0350.cnf, 350/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 786
# Current Solvability: 100.00%
#
# file: uf50-0351.cnf, 351/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 256
# Current Solvability: 100.00%
#
# file: uf50-0352.cnf, 352/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 61
# Current Solvability: 100.00%
#
# file: uf50-0353.cnf, 353/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 16
# Current Solvability: 100.00%
#
# file: uf50-0354.cnf, 354/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 89
# Current Solvability: 100.00%
#
# file: uf50-0355.cnf, 355/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 540
# Current Solvability: 100.00%
#
# file: uf50-0356.cnf, 356/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 307
# Current Solvability: 100.00%
#
# file: uf50-0357.cnf, 357/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 46
# Current Solvability: 100.00%
#
# file: uf50-0358.cnf, 358/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 675
# Current Solvability: 100.00%
#
# file: uf50-0359.cnf, 359/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 4
# Current Solvability: 100.00%
#
# file: uf50-0360.cnf, 360/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 37
# Current Solvability: 100.00%
#
# file: uf50-0361.cnf, 361/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 14
# Current Solvability: 100.00%
#
# file: uf50-0362.cnf, 362/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 12
# Current Solvability: 100.00%
#
# file: uf50-0363.cnf, 363/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 15
# Current Solvability: 100.00%
#
# file: uf50-0364.cnf, 364/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 116
# Current Solvability: 100.00%
#
# file: uf50-0365.cnf, 365/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 38
# Current Solvability: 100.00%
#
# file: uf50-0366.cnf, 366/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 45
# Current Solvability: 100.00%
#
# file: uf50-0367.cnf, 367/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 904
# Current Solvability: 100.00%
#
# file: uf50-0368.cnf, 368/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 78
# Current Solvability: 100.00%
#
# file: uf50-0369.cnf, 369/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 67
# Current Solvability: 100.00%
#
# file: uf50-0370.cnf, 370/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 45
# Current Solvability: 100.00%
#
# file: uf50-0371.cnf, 371/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 42
# Current Solvability: 100.00%
#
# file: uf50-0372.cnf, 372/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 58
# Current Solvability: 100.00%
#
# file: uf50-0373.cnf, 373/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 51
# Current Solvability: 100.00%
#
# file: uf50-0374.cnf, 374/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 24
# Current Solvability: 100.00%
#
# file: uf50-0375.cnf, 375/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 83
# Current Solvability: 100.00%
#
# file: uf50-0376.cnf, 376/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 197
# Current Solvability: 100.00%
#
# file: uf50-0377.cnf, 377/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf50-0378.cnf, 378/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 22
# Current Solvability: 100.00%
#
# file: uf50-0379.cnf, 379/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 72
# Current Solvability: 100.00%
#
# file: uf50-0380.cnf, 380/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 360
# Current Solvability: 100.00%
#
# file: uf50-0381.cnf, 381/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 219
# Current Solvability: 100.00%
#
# file: uf50-0382.cnf, 382/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 544
# Current Solvability: 100.00%
#
# file: uf50-0383.cnf, 383/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 37
# Current Solvability: 100.00%
#
# file: uf50-0384.cnf, 384/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 33
# Current Solvability: 100.00%
#
# file: uf50-0385.cnf, 385/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 100.00%
#
# file: uf50-0386.cnf, 386/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 29
# Current Solvability: 100.00%
#
# file: uf50-0387.cnf, 387/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 11
# Current Solvability: 100.00%
#
# file: uf50-0388.cnf, 388/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 145
# Current Solvability: 100.00%
#
# file: uf50-0389.cnf, 389/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 118
# Current Solvability: 100.00%
#
# file: uf50-0390.cnf, 390/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 36
# Current Solvability: 100.00%
#
# file: uf50-0391.cnf, 391/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 154
# Current Solvability: 100.00%
#
# file: uf50-0392.cnf, 392/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 56
# Current Solvability: 100.00%
#
# file: uf50-0393.cnf, 393/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 302
# Current Solvability: 100.00%
#
# file: uf50-0394.cnf, 394/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 18
# Current Solvability: 100.00%
#
# file: uf50-0395.cnf, 395/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 469
# Current Solvability: 100.00%
#
# file: uf50-0396.cnf, 396/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 19
# Current Solvability: 100.00%
#
# file: uf50-0397.cnf, 397/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 61
# Current Solvability: 100.00%
#
# file: uf50-0398.cnf, 398/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 23
# Current Solvability: 100.00%
#
# file: uf50-0399.cnf, 399/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 162
# Current Solvability: 100.00%
#
# file: uf50-0400.cnf, 400/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 20
# Current Solvability: 100.00%
#
# file: uf50-0401.cnf, 401/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 46
# Current Solvability: 100.00%
#
# file: uf50-0402.cnf, 402/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 619
# Current Solvability: 100.00%
#
# file: uf50-0403.cnf, 403/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 265
# Current Solvability: 100.00%
#
# file: uf50-0404.cnf, 404/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 5
# Current Solvability: 100.00%
#
# file: uf50-0405.cnf, 405/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 134
# Current Solvability: 100.00%
#
# file: uf50-0406.cnf, 406/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 100.00%
#
# file: uf50-0407.cnf, 407/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 15
# Current Solvability: 100.00%
#
# file: uf50-0408.cnf, 408/1000
# SATISFIED!!!! hyper_iter: 4, success_iter: 67
# Current Solvability: 100.00%
#
# file: uf50-0409.cnf, 409/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 116
# Current Solvability: 100.00%
#
# file: uf50-0410.cnf, 410/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 162
# Current Solvability: 100.00%
#
# file: uf50-0411.cnf, 411/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 289
# Current Solvability: 100.00%
#
# file: uf50-0412.cnf, 412/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 85
# Current Solvability: 100.00%
#
# file: uf50-0413.cnf, 413/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 95
# Current Solvability: 100.00%
#
# file: uf50-0414.cnf, 414/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 17
# Current Solvability: 100.00%
#
# file: uf50-0415.cnf, 415/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 109
# Current Solvability: 100.00%
#
# file: uf50-0416.cnf, 416/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 27
# Current Solvability: 100.00%
#
# file: uf50-0417.cnf, 417/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 10
# Current Solvability: 100.00%
#
# file: uf50-0418.cnf, 418/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 183
# Current Solvability: 100.00%
#
# file: uf50-0419.cnf, 419/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 429
# Current Solvability: 100.00%
#
# file: uf50-0420.cnf, 420/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 515
# Current Solvability: 100.00%
#
# file: uf50-0421.cnf, 421/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 39
# Current Solvability: 100.00%
#
# file: uf50-0422.cnf, 422/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 275
# Current Solvability: 100.00%
#
# file: uf50-0423.cnf, 423/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 17
# Current Solvability: 100.00%
#
# file: uf50-0424.cnf, 424/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 64
# Current Solvability: 100.00%
#
# file: uf50-0425.cnf, 425/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 72
# Current Solvability: 100.00%
#
# file: uf50-0426.cnf, 426/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 29
# Current Solvability: 100.00%
#
# file: uf50-0427.cnf, 427/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 66
# Current Solvability: 100.00%
#
# file: uf50-0428.cnf, 428/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 116
# Current Solvability: 100.00%
#
# file: uf50-0429.cnf, 429/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 556
# Current Solvability: 100.00%
#
# file: uf50-0430.cnf, 430/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 496
# Current Solvability: 100.00%
#
# file: uf50-0431.cnf, 431/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 59
# Current Solvability: 100.00%
#
# file: uf50-0432.cnf, 432/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 12
# Current Solvability: 100.00%
#
# file: uf50-0433.cnf, 433/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 259
# Current Solvability: 100.00%
#
# file: uf50-0434.cnf, 434/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 70
# Current Solvability: 100.00%
#
# file: uf50-0435.cnf, 435/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 387
# Current Solvability: 100.00%
#
# file: uf50-0436.cnf, 436/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 311
# Current Solvability: 100.00%
#
# file: uf50-0437.cnf, 437/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 37
# Current Solvability: 100.00%
#
# file: uf50-0438.cnf, 438/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 383
# Current Solvability: 100.00%
#
# file: uf50-0439.cnf, 439/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 43
# Current Solvability: 100.00%
#
# file: uf50-0440.cnf, 440/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 332
# Current Solvability: 100.00%
#
# file: uf50-0441.cnf, 441/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 665
# Current Solvability: 100.00%
#
# file: uf50-0442.cnf, 442/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 261
# Current Solvability: 100.00%
#
# file: uf50-0443.cnf, 443/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 100.00%
#
# file: uf50-0444.cnf, 444/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 58
# Current Solvability: 100.00%
#
# file: uf50-0445.cnf, 445/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 5
# Current Solvability: 100.00%
#
# file: uf50-0446.cnf, 446/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 57
# Current Solvability: 100.00%
#
# file: uf50-0447.cnf, 447/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 296
# Current Solvability: 100.00%
#
# file: uf50-0448.cnf, 448/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 197
# Current Solvability: 100.00%
#
# file: uf50-0449.cnf, 449/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 14
# Current Solvability: 100.00%
#
# file: uf50-0450.cnf, 450/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 162
# Current Solvability: 100.00%
#
# file: uf50-0451.cnf, 451/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 21
# Current Solvability: 100.00%
#
# file: uf50-0452.cnf, 452/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 62
# Current Solvability: 100.00%
#
# file: uf50-0453.cnf, 453/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 444
# Current Solvability: 100.00%
#
# file: uf50-0454.cnf, 454/1000
# ...
# SATISFIED!!!! hyper_iter: 1, success_iter: 147
# Current Solvability: 100.00%
#
# file: uf50-0852.cnf, 852/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 218
# Current Solvability: 100.00%
#
# file: uf50-0853.cnf, 853/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 230
# Current Solvability: 100.00%
#
# file: uf50-0854.cnf, 854/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 382
# Current Solvability: 100.00%
#
# file: uf50-0855.cnf, 855/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 418
# Current Solvability: 100.00%
#
# file: uf50-0856.cnf, 856/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 584
# Current Solvability: 100.00%
#
# file: uf50-0857.cnf, 857/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 22
# Current Solvability: 100.00%
#
# file: uf50-0858.cnf, 858/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 28
# Current Solvability: 100.00%
#
# file: uf50-0859.cnf, 859/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 251
# Current Solvability: 100.00%
#
# file: uf50-0860.cnf, 860/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 42
# Current Solvability: 100.00%
#
# file: uf50-0861.cnf, 861/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 671
# Current Solvability: 100.00%
#
# file: uf50-0862.cnf, 862/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 232
# Current Solvability: 100.00%
#
# file: uf50-0863.cnf, 863/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 145
# Current Solvability: 100.00%
#
# file: uf50-0864.cnf, 864/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 697
# Current Solvability: 100.00%
#
# file: uf50-0865.cnf, 865/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 277
# Current Solvability: 100.00%
#
# file: uf50-0866.cnf, 866/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 243
# Current Solvability: 100.00%
#
# file: uf50-0867.cnf, 867/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 123
# Current Solvability: 100.00%
#
# file: uf50-0868.cnf, 868/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 349
# Current Solvability: 100.00%
#
# file: uf50-0869.cnf, 869/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 332
# Current Solvability: 100.00%
#
# file: uf50-0870.cnf, 870/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 91
# Current Solvability: 100.00%
#
# file: uf50-0871.cnf, 871/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 36
# Current Solvability: 100.00%
#
# file: uf50-0872.cnf, 872/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 15
# Current Solvability: 100.00%
#
# file: uf50-0873.cnf, 873/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 549
# Current Solvability: 100.00%
#
# file: uf50-0874.cnf, 874/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 62
# Current Solvability: 100.00%
#
# file: uf50-0875.cnf, 875/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 20
# Current Solvability: 100.00%
#
# file: uf50-0876.cnf, 876/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 95
# Current Solvability: 100.00%
#
# file: uf50-0877.cnf, 877/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 370
# Current Solvability: 100.00%
#
# file: uf50-0878.cnf, 878/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 16
# Current Solvability: 100.00%
#
# file: uf50-0879.cnf, 879/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 385
# Current Solvability: 100.00%
#
# file: uf50-0880.cnf, 880/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 178
# Current Solvability: 100.00%
#
# file: uf50-0881.cnf, 881/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 101
# Current Solvability: 100.00%
#
# file: uf50-0882.cnf, 882/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 309
# Current Solvability: 100.00%
#
# file: uf50-0883.cnf, 883/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 12
# Current Solvability: 100.00%
#
# file: uf50-0884.cnf, 884/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 109
# Current Solvability: 100.00%
#
# file: uf50-0885.cnf, 885/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 577
# Current Solvability: 100.00%
#
# file: uf50-0886.cnf, 886/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 51
# Current Solvability: 100.00%
#
# file: uf50-0887.cnf, 887/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 11
# Current Solvability: 100.00%
#
# file: uf50-0888.cnf, 888/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 13
# Current Solvability: 100.00%
#
# file: uf50-0889.cnf, 889/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 642
# Current Solvability: 100.00%
#
# file: uf50-0890.cnf, 890/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 9
# Current Solvability: 100.00%
#
# file: uf50-0891.cnf, 891/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 41
# Current Solvability: 100.00%
#
# file: uf50-0892.cnf, 892/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 483
# Current Solvability: 100.00%
#
# file: uf50-0893.cnf, 893/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 202
# Current Solvability: 100.00%
#
# file: uf50-0894.cnf, 894/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 96
# Current Solvability: 100.00%
#
# file: uf50-0895.cnf, 895/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 151
# Current Solvability: 100.00%
#
# file: uf50-0896.cnf, 896/1000
# SATISFIED!!!! hyper_iter: 3, success_iter: 24
# Current Solvability: 100.00%
#
# file: uf50-0897.cnf, 897/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 14
# Current Solvability: 100.00%
#
# file: uf50-0898.cnf, 898/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 136
# Current Solvability: 100.00%
#
# file: uf50-0899.cnf, 899/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 410
# Current Solvability: 100.00%
#
# file: uf50-0900.cnf, 900/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 106
# Current Solvability: 100.00%
#
# file: uf50-0901.cnf, 901/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 32
# Current Solvability: 100.00%
#
# file: uf50-0902.cnf, 902/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 831
# Current Solvability: 100.00%
#
# file: uf50-0903.cnf, 903/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 161
# Current Solvability: 100.00%
#
# file: uf50-0904.cnf, 904/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 26
# Current Solvability: 100.00%
#
# file: uf50-0905.cnf, 905/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 88
# Current Solvability: 100.00%
#
# file: uf50-0906.cnf, 906/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 44
# Current Solvability: 100.00%
#
# file: uf50-0907.cnf, 907/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 22
# Current Solvability: 100.00%
#
# file: uf50-0908.cnf, 908/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 33
# Current Solvability: 100.00%
#
# file: uf50-0909.cnf, 909/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 13
# Current Solvability: 100.00%
#
# file: uf50-0910.cnf, 910/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 769
# Current Solvability: 100.00%
#
# file: uf50-0911.cnf, 911/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 578
# Current Solvability: 100.00%
#
# file: uf50-0912.cnf, 912/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 29
# Current Solvability: 100.00%
#
# file: uf50-0913.cnf, 913/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 360
# Current Solvability: 100.00%
#
# file: uf50-0914.cnf, 914/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 30
# Current Solvability: 100.00%
#
# file: uf50-0915.cnf, 915/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 33
# Current Solvability: 100.00%
#
# file: uf50-0916.cnf, 916/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 128
# Current Solvability: 100.00%
#
# file: uf50-0917.cnf, 917/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 83
# Current Solvability: 100.00%
#
# file: uf50-0918.cnf, 918/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 30
# Current Solvability: 100.00%
#
# file: uf50-0919.cnf, 919/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 348
# Current Solvability: 100.00%
#
# file: uf50-0920.cnf, 920/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 95
# Current Solvability: 100.00%
#
# file: uf50-0921.cnf, 921/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 5
# Current Solvability: 100.00%
#
# file: uf50-0922.cnf, 922/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 33
# Current Solvability: 100.00%
#
# file: uf50-0923.cnf, 923/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 281
# Current Solvability: 100.00%
#
# file: uf50-0924.cnf, 924/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 169
# Current Solvability: 100.00%
#
# file: uf50-0925.cnf, 925/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 28
# Current Solvability: 100.00%
#
# file: uf50-0926.cnf, 926/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 21
# Current Solvability: 100.00%
#
# file: uf50-0927.cnf, 927/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 77
# Current Solvability: 100.00%
#
# file: uf50-0928.cnf, 928/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 276
# Current Solvability: 100.00%
#
# file: uf50-0929.cnf, 929/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 123
# Current Solvability: 100.00%
#
# file: uf50-0930.cnf, 930/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 245
# Current Solvability: 100.00%
#
# file: uf50-0931.cnf, 931/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 102
# Current Solvability: 100.00%
#
# file: uf50-0932.cnf, 932/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 24
# Current Solvability: 100.00%
#
# file: uf50-0933.cnf, 933/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 6
# Current Solvability: 100.00%
#
# file: uf50-0934.cnf, 934/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 184
# Current Solvability: 100.00%
#
# file: uf50-0935.cnf, 935/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 32
# Current Solvability: 100.00%
#
# file: uf50-0936.cnf, 936/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 7
# Current Solvability: 100.00%
#
# file: uf50-0937.cnf, 937/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 35
# Current Solvability: 100.00%
#
# file: uf50-0938.cnf, 938/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 32
# Current Solvability: 100.00%
#
# file: uf50-0939.cnf, 939/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 808
# Current Solvability: 100.00%
#
# file: uf50-0940.cnf, 940/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 52
# Current Solvability: 100.00%
#
# file: uf50-0941.cnf, 941/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 337
# Current Solvability: 100.00%
#
# file: uf50-0942.cnf, 942/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 243
# Current Solvability: 100.00%
#
# file: uf50-0943.cnf, 943/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 432
# Current Solvability: 100.00%
#
# file: uf50-0944.cnf, 944/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 238
# Current Solvability: 100.00%
#
# file: uf50-0945.cnf, 945/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 285
# Current Solvability: 100.00%
#
# file: uf50-0946.cnf, 946/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 197
# Current Solvability: 100.00%
#
# file: uf50-0947.cnf, 947/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 148
# Current Solvability: 100.00%
#
# file: uf50-0948.cnf, 948/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 454
# Current Solvability: 100.00%
#
# file: uf50-0949.cnf, 949/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 68
# Current Solvability: 100.00%
#
# file: uf50-0950.cnf, 950/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 977
# Current Solvability: 100.00%
#
# file: uf50-0951.cnf, 951/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 58
# Current Solvability: 100.00%
#
# file: uf50-0952.cnf, 952/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 108
# Current Solvability: 100.00%
#
# file: uf50-0953.cnf, 953/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 51
# Current Solvability: 100.00%
#
# file: uf50-0954.cnf, 954/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 53
# Current Solvability: 100.00%
#
# file: uf50-0955.cnf, 955/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 31
# Current Solvability: 100.00%
#
# file: uf50-0956.cnf, 956/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 12
# Current Solvability: 100.00%
#
# file: uf50-0957.cnf, 957/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 131
# Current Solvability: 100.00%
#
# file: uf50-0958.cnf, 958/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 476
# Current Solvability: 100.00%
#
# file: uf50-0959.cnf, 959/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 44
# Current Solvability: 100.00%
#
# file: uf50-0960.cnf, 960/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 156
# Current Solvability: 100.00%
#
# file: uf50-0961.cnf, 961/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 677
# Current Solvability: 100.00%
#
# file: uf50-0962.cnf, 962/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 109
# Current Solvability: 100.00%
#
# file: uf50-0963.cnf, 963/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 37
# Current Solvability: 100.00%
#
# file: uf50-0964.cnf, 964/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 100
# Current Solvability: 100.00%
#
# file: uf50-0965.cnf, 965/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 23
# Current Solvability: 100.00%
#
# file: uf50-0966.cnf, 966/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 132
# Current Solvability: 100.00%
#
# file: uf50-0967.cnf, 967/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 20
# Current Solvability: 100.00%
#
# file: uf50-0968.cnf, 968/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 35
# Current Solvability: 100.00%
#
# file: uf50-0969.cnf, 969/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 313
# Current Solvability: 100.00%
#
# file: uf50-0970.cnf, 970/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 51
# Current Solvability: 100.00%
#
# file: uf50-0971.cnf, 971/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 29
# Current Solvability: 100.00%
#
# file: uf50-0972.cnf, 972/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 405
# Current Solvability: 100.00%
#
# file: uf50-0973.cnf, 973/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 33
# Current Solvability: 100.00%
#
# file: uf50-0974.cnf, 974/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 128
# Current Solvability: 100.00%
#
# file: uf50-0975.cnf, 975/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 89
# Current Solvability: 100.00%
#
# file: uf50-0976.cnf, 976/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 260
# Current Solvability: 100.00%
#
# file: uf50-0977.cnf, 977/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 18
# Current Solvability: 100.00%
#
# file: uf50-0978.cnf, 978/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 449
# Current Solvability: 100.00%
#
# file: uf50-0979.cnf, 979/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 71
# Current Solvability: 100.00%
#
# file: uf50-0980.cnf, 980/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 8
# Current Solvability: 100.00%
#
# file: uf50-0981.cnf, 981/1000
# SATISFIED!!!! hyper_iter: 2, success_iter: 474
# Current Solvability: 100.00%
#
# file: uf50-0982.cnf, 982/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 448
# Current Solvability: 100.00%
#
# file: uf50-0983.cnf, 983/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 76
# Current Solvability: 100.00%
#
# file: uf50-0984.cnf, 984/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 72
# Current Solvability: 100.00%
#
# file: uf50-0985.cnf, 985/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 15
# Current Solvability: 100.00%
#
# file: uf50-0986.cnf, 986/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 37
# Current Solvability: 100.00%
#
# file: uf50-0987.cnf, 987/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 68
# Current Solvability: 100.00%
#
# file: uf50-0988.cnf, 988/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 47
# Current Solvability: 100.00%
#
# file: uf50-0989.cnf, 989/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 187
# Current Solvability: 100.00%
#
# file: uf50-0990.cnf, 990/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 162
# Current Solvability: 100.00%
#
# file: uf50-0991.cnf, 991/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 75
# Current Solvability: 100.00%
#
# file: uf50-0992.cnf, 992/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 44
# Current Solvability: 100.00%
#
# file: uf50-0993.cnf, 993/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 310
# Current Solvability: 100.00%
#
# file: uf50-0994.cnf, 994/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 380
# Current Solvability: 100.00%
#
# file: uf50-0995.cnf, 995/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 52
# Current Solvability: 100.00%
#
# file: uf50-0996.cnf, 996/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 181
# Current Solvability: 100.00%
#
# file: uf50-0997.cnf, 997/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 71
# Current Solvability: 100.00%
#
# file: uf50-0998.cnf, 998/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 151
# Current Solvability: 100.00%
#
# file: uf50-0999.cnf, 999/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 83
# Current Solvability: 100.00%
#
# file: uf50-01000.cnf, 1000/1000
# SATISFIED!!!! hyper_iter: 1, success_iter: 97
# Current Solvability: 100.00%
#
#
# Final Solvability: 100.00%

# %%
import numpy as np  # NumPy 라이브러리를 임포트하여 수치 계산 기능을 사용합니다.
import matplotlib.pyplot as plt  # matplotlib.pyplot을 임포트하여 그래프를 그리는 기능을 사용합니다.
import re

def plot_success_distribution(iter_save_path):
    # 저장된 NumPy 배열을 로드합니다.
    success_iter_array = np.load(iter_save_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.

    # 숫자 50과 218을 추출하는 정규 표현식
    numbers = re.findall(r'\d+', iter_save_path)
    # 추출된 숫자 확인
    if len(numbers) >= 2:
        variable_num, clause_num = numbers[0], numbers[1]
    else:
        assert False, "No matching numbers found."

    # 성공적인 반복 수를 추출합니다.
    success_counts = success_iter_array[:, 2]  # SUCCESS_OR_NOT가 저장된 열을 선택하여 성공적인 반복 수를 가져옵니다.
    total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
    solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

    # 분포도 그리기
    fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

    # y축 방향의 grid를 가장 뒤에 배치
    ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

    # 히스토그램 생성
    z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
    counts, bins, patches = ax1.hist(
        success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
        edgecolor='black', alpha=0.7, label='Histogram of Success Iterations', zorder=1
    )
    
    # 제목과 축 레이블 설정
    ax1.set_title(f'{variable_num}-{clause_num} Distribution of Success Iterations | {total_problems} problems | {solved_files} solved | max iter {np.max(success_counts)}')  
    ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
    ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
    ax1.set_xticks(range(0, int(np.max(success_counts)) + 2))  # x축 눈금을 성공 수의 범위에 맞춰 설정합니다.

    # 막대 위에 빈도 수 표시
    for count, patch in zip(counts, patches):
        ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
        # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

    # 누적 비율을 계산하여 꺾은선 그래프 추가
    accumulated_count = 0
    cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
    for count in counts:  
        accumulated_count += count
        proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
        cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

    # 꺾은선 그래프의 2차 y축 생성
    ax2 = ax1.twinx()
    ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Cumulative Proportion', zorder=3)  
    ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
    ax2.set_ylabel('Cumulative Proportion')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

    # 꺾은선 그래프 포인트 위에 비율 표시
    for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
        ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='red')  
        # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

    fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
    plt.show()  # 그래프를 화면에 표시합니다.

# 사용 예시
iter_save_path = 'iter_save_box/uf50-218_iter_analysis.npy'  # 파일 경로를 지정합니다.
plot_success_distribution(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.

# %%
import numpy as np  # NumPy 라이브러리를 임포트하여 수치 계산 기능을 사용합니다.
import matplotlib.pyplot as plt  # matplotlib.pyplot을 임포트하여 그래프를 그리는 기능을 사용합니다.
import re

def plot_success_distribution_hyper(iter_save_path):
    # 저장된 NumPy 배열을 로드합니다.
    success_iter_array = np.load(iter_save_path)  # 지정된 경로에서 NumPy 배열을 불러옵니다.

    # 숫자 50과 218을 추출하는 정규 표현식
    numbers = re.findall(r'\d+', iter_save_path)
    # 추출된 숫자 확인
    if len(numbers) >= 2:
        variable_num, clause_num = numbers[0], numbers[1]
    else:
        assert False, "No matching numbers found."

    # 성공적인 반복 수를 추출합니다.
    success_counts = success_iter_array[:, 3]  # hyper_iter
    total_problems = success_iter_array[0][0]  # 전체 문제 수를 가져옵니다.
    solved_files = success_iter_array.shape[0]  # 전체 파일 수를 계산합니다.

    # 분포도 그리기
    fig, ax1 = plt.subplots(figsize=(10, 6))  # 그래프의 크기를 10x6 인치로 설정합니다.

    # y축 방향의 grid를 가장 뒤에 배치
    ax1.grid(axis='y', alpha=0.25, zorder=0)  # y축 방향으로 그리드를 추가하고 가장 뒤로 설정합니다.

    # 히스토그램 생성
    z = 0.5  # 막대의 중앙을 맞추기 위한 오프셋
    counts, bins, patches = ax1.hist(
        success_counts, bins=np.arange(0, np.max(success_counts) + 2) - z, 
        edgecolor='black', alpha=0.7, label='Histogram of Success Hyper Iterations', zorder=1
    )
    
    # 제목과 축 레이블 설정
    ax1.set_title(f'{variable_num}-{clause_num} Distribution of Success Iterations | {total_problems} problems | {solved_files} solved | max h-iter {np.max(success_counts)}')  
    ax1.set_xlabel('Iterations')  # x축 레이블을 'Iterations'로 설정합니다.
    ax1.set_ylabel('Count of Solved Problems')  # y축 레이블을 'Count of Solved Problems'로 설정합니다.
    ax1.set_xticks(np.arange(0, np.max(success_counts) + 2, step=5))  # 예시로 step=5로 설정하였으므로 필요에 따라 변경 가능
    ax1.yaxis.get_major_locator().set_params(integer=True) # y축 눈금을 정수만 표시

    # 막대 위에 빈도 수 표시
    for count, patch in zip(counts, patches):
        ax1.text(patch.get_x() + patch.get_width() / 2, count, str(int(count)), ha='center', va='bottom', color='blue')
        # 각 막대의 상단 중앙에 빈도 수를 표시합니다.

    # 누적 비율을 계산하여 꺾은선 그래프 추가
    accumulated_count = 0
    cumulative_proportions = []  # 누적 비율을 저장할 리스트를 초기화합니다.
    for count in counts:  
        accumulated_count += count
        proportion = accumulated_count / total_problems  # 전체 문제 수에 대한 푼 문제 수의 비율을 계산합니다.
        cumulative_proportions.append(proportion*100)  # 계산된 비율을 리스트에 추가합니다.

    # 꺾은선 그래프의 2차 y축 생성
    ax2 = ax1.twinx()
    ax2.plot(bins[:-1] + z, cumulative_proportions, color='red', marker='o', linestyle='-', label='Cumulative Proportion', zorder=3)  
    ax2.set_ylim(0, 100)  # y축 범위를 0에서 1로 설정하여 누적 비율 그래프의 범위를 조정합니다.
    ax2.set_ylabel('Cumulative Proportion')  # 꺾은선 그래프의 y축 레이블을 설정합니다.

    # 꺾은선 그래프 포인트 위에 비율 표시
    for x, proportion in zip(bins[:-1] + z, cumulative_proportions):
        ax2.text(x, proportion-4, f"{proportion:.0f}%", ha='center', va='bottom', color='red')  
        # 각 꺾은선 그래프 포인트 위에 비율을 표시하며, 비율은 소수점 둘째 자리까지 나타냅니다.

    fig.legend(loc="upper left", bbox_to_anchor=(0,1), bbox_transform=ax1.transAxes)
    plt.show()  # 그래프를 화면에 표시합니다.

# 사용 예시
iter_save_path = 'iter_save_box/uf50-218_iter_analysis.npy'  # 파일 경로를 지정합니다.
plot_success_distribution_hyper(iter_save_path)  # 지정된 경로의 파일을 사용하여 분포도를 그립니다.
