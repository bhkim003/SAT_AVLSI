# %%
# Simulation for SAT solving shardware
# reference: Shim, Chaeyun, Jooyoung Bae, and Bongjin Kim. "30.3 VIP-Sat: A Boolean Satisfiability Solver Featuring 5× 12 Variable In-Memory Processing Elements with 98% Solvability for 50-Variables 218-Clauses 3-SAT Problems." 2024 IEEE International Solid-State Circuits Conference (ISSCC). Vol. 67. IEEE, 2024.

# %%
# 데이터셋 위치  
# /data2/sat/uf50-218  
# /data2/sat/uf20-91 
# 출처: https://www.cs.ubc.ca/~hoos/SATLIB/benchm.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import copy 
import os

# %%
def count_files_in_directory(directory):
    try:
        # 폴더 내의 모든 파일 목록 가져오기
        files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
        return files
    except FileNotFoundError:
        print(f"Error: The directory '{directory}' does not exist.")
        return None

# %%
def read_cnf_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    clauses = []

    clause_save_start = False
    clause_count = 0
    for line in lines:
        if clause_save_start == True:
            clause = list(map(int, line.strip().split()))
            assert clause[-1] == 0
            clause = clause[:-1]  # Remove the trailing 0
            clauses.append(clause)
            clause_count += 1
            if clause_count == num_clauses:
                break

        if line.startswith(('p')) and clause_save_start == False:
            clause_save_start = True
            _, _, num_vars, num_clauses = line.split()
            num_vars = int(num_vars)
            num_clauses = int(num_clauses)
    assert clause_save_start == True

    clauses = np.array(clauses)
    return clauses, num_vars, num_clauses

# %%
class VPE:
    def __init__(self, MY_VAR):
        """
        VPE 초기화 메서드
        :param MY_VAR: 이 VPE가 담당할 변수 (예: v1, v2 등)
        """
        self._MY_VAR = MY_VAR  # 이 VPE가 처리할 변수
        self.MY_STATE = 1       # 변수의 상태 

        self.clauses = []         # 변수가 속한 절들의 리스트
        self.neighbors = set()    # 상관관계 있는 이웃 변수들

    @property # MY_VAR 속성은 읽기 전용
    def MY_VAR(self):
        return self._MY_VAR
    
    def add_clause(self, all_clauses):
        """
        변수가 속한 절을 추가하는 메서드
        :param all_clauses: 전체 절들의 리스트
        """
        clauses_clone = copy.deepcopy(all_clauses)
        for clause in clauses_clone:
            clause_abs = [abs(x) for x in clause]

            if self.MY_VAR in clause_abs:
                self_index = clause_abs.index(self.MY_VAR)
                temp = clause[self_index]
                clause = np.concatenate((clause[:self_index], clause[self_index + 1:]))  # self_index에서 요소 제거
                clause_abs = clause_abs[:self_index] + clause_abs[self_index+1:]
                temp2 = np.insert(clause, 0, temp)
                self.clauses.append(temp2)

                # 절 내에서 다른 변수들을 이웃으로 추가
                for var_abs in clause_abs:
                    self.neighbors.add(var_abs)
        
    def get_neighbors(self):
        """
        상관관계 있는 이웃 변수들을 반환하는 메서드
        """
        return list(self.neighbors)

    def process(self, var_state_array, stocastic_mode):
        """
        변수를 처리하는 메서드 (예: 값 업데이트 등)
        이 부분은 문제 해결 알고리즘에 따라 달라질 수 있음.
        """

        # Adder Tree
        tree_sum = 0

        non_trivial_clauses_count = 0.0 # VI가 중요한 절 개수
        up_count = 0.0
        down_count = 0.0

        # Clause Column
        for clause in self.clauses:
            SI = 0 if clause[0] < 0 else 1 # 음수면 0, 양수면 1 # sign bit 같은 거임.
            SL = 0 if clause[1] < 0 else 1
            SR = 0 if clause[2] < 0 else 1

            VI = var_state_array[abs(clause[0])-1] # 현재 V값 가져오기
            VL = var_state_array[abs(clause[1])-1]
            VR = var_state_array[abs(clause[2])-1]

            assert VI == self.MY_STATE, f'{VI}, {self.MY_STATE}'

            # S와 V의 XOR값(같으면 0 다르면 1)이 3개가 나옴. (SIVI, SLVL, SRVR) 한개라도 XOR값이 0이어야 Clause satisfied.
            
            # Clause Logic
            if (SL ^ VL) and (SR ^ VR) == 1: 
                C0 = 1 # MY_VAR가 중요해졌다는 flag.
                C1 = 1 if SI == 0 else 0 # SI 토글
            else:
                C0 = 0
                C1 = 0

            # Adder Tree
            if C0 == 1:
                non_trivial_clauses_count += 1.0
                if C1 == 1:
                    tree_sum += -1
                    down_count += 1.0
                else: # C1 == 0
                    tree_sum += 1
                    up_count += 1.0
            else: # C0 == 0
                tree_sum += 0

        if stocastic_mode == False:
            # Variable Update Logic
            if tree_sum < 0:
                self.MY_STATE = 0
            elif tree_sum == 0:
                self.MY_STATE = 1 if self.MY_STATE == 0 else 0
            elif tree_sum > 0:
                self.MY_STATE = 1
            else: 
                assert False
        else:
            # STOCASTIC UPDATE
            if tree_sum == 0:
                # self.MY_STATE = 1 if self.MY_STATE == 0 else 0 
                p = 1/2
            else:
                p = down_count/non_trivial_clauses_count
                
            if random.random() < p:
                self.MY_STATE = 0
            else:
                self.MY_STATE = 1

        return self.MY_STATE

# %%
class VPE_ARRAY:
    def __init__(self, my_seed=42,  num_rows=5, num_cols=12, clauses=[[1,2,-3],[2,-1,57]], num_vars=50, num_clauses=218):
        """
        VPE_ARRAY 초기화 메서드
        :param num_rows: VPE 배열의 행 개수 (기본값: 5)
        :param num_cols: VPE 배열의 열 개수 (기본값: 12)
        :param clauses: 3-SAT 문제의 절(clause) 리스트
        :param num_vars: 변수의 총 개수
        :param num_clauses: 절의 총 개수
        """
        self.my_seed = my_seed
        self.num_rows = num_rows  # 행 개수
        self.clauses = clauses
        self.num_cols = num_cols  # 열 개수
        self.num_vars = num_vars  # 변수의 총 개수

        # 랜덤 시드 초기화
        random.seed(self.my_seed)

        # 상관 관계 행렬 
        self.correlation_matrix = self.create_correlation_matrix()

        # VPE 배열 생성
        self.VPES, self.VPE_index, self.assigned_abs_vars = self.assign_variables_to_vpe()

        # uncorrelated columns check
        assert self.check_uncorrelated_columns(self.VPE_index, self.correlation_matrix)

        # VPE 배열에 모든 절 삽입
        self.add_clause_to_vpe()
        
        # variable state initialize
        self.var_state_array = self.variable_state_initialize()
        
        # run
        # 외부에서 실행하세요.    


    def create_correlation_matrix(self):
        """
        상관 관계 행렬을 생성하는 메서드

        Args:
            clauses (list): 변수의 절(clause) 리스트
        """
        # 각 절(clause)에서 변수를 두 개씩 비교하며 상관 관계를 행렬에 기록
        correlation_matrix = np.zeros((self.num_vars, self.num_vars), dtype=int)
        for clause in self.clauses:
            for i, var1 in enumerate(clause):
                for var2 in clause[i + 1:]:
                    abs_var1, abs_var2 = abs(var1) - 1, abs(var2) - 1  # 변수 인덱스는 0부터 시작하므로 -1 처리
                    correlation_matrix[abs_var1, abs_var2] = 1  # 상관된 변수 간에는 1을 표시
                    correlation_matrix[abs_var2, abs_var1] = 1  # 상관 행렬은 대칭이므로 반대 방향도 동일하게 처리
        
        return correlation_matrix
    
    def assign_variables_to_vpe(self):
        assigned_abs_vars = set()
        VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]

        deploy_search_iter = 0
        while True:
            deploy_search_iter += 1

            # 사용한 변수를 추적하기 위한 리스트
            assigned_abs_vars = set()

            # 2D 어레이(행렬)로 VPE 배열 생성 (각 column에는 상관 관계가 없는 변수들 할당)
            VPES = [[None for col in range(self.num_cols)] for row in range(self.num_rows)]
            
            # Stage 1 : numvars//numcols 만큼의 row까지만 할당
            # 변수 할당을 위한 작업
            current_row_at_column = [0 for _ in range(self.num_cols)]
            for col in range(self.num_cols):
                # 상관 관계가 없는 변수들을 찾음
                shuffled_abs_vars_range = list(range(1, self.num_vars + 1))
                random.shuffle(shuffled_abs_vars_range)
                for abs_var in shuffled_abs_vars_range:
                    if abs_var in assigned_abs_vars:
                        continue  # 이미 할당된 변수는 건너뜀

                    # 상관되지 않은 변수인지 확인
                    can_assign = True
                    for prev_row in range(current_row_at_column[col]):
                        prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                        if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                            can_assign = False
                            break

                    if can_assign == True:
                        assert VPES[current_row_at_column[col]][col] == None
                        VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                        assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                        current_row_at_column[col] += 1

                    if current_row_at_column[col] >= self.num_vars//self.num_cols:  # 이 column에 모두 할당했으면 다음 column으로
                        break

            # Stage 2: 나머지 row에 할당
            shuffled_col_list = list(range(self.num_cols))
            random.shuffle(shuffled_col_list)
            for col in shuffled_col_list:
                # 상관 관계가 없는 변수들을 찾음
                shuffled_abs_vars_range = list(range(1, self.num_vars + 1))
                random.shuffle(shuffled_abs_vars_range)
                for abs_var in shuffled_abs_vars_range:
                    if abs_var in assigned_abs_vars:
                        continue  # 이미 할당된 변수는 건너뜀

                    # 상관되지 않은 변수인지 확인
                    can_assign = True
                    for prev_row in range(current_row_at_column[col]):
                        prev_abs_var = VPES[prev_row][col].MY_VAR  # 이전에 같은 column에 배치된 변수
                        if self.correlation_matrix[abs_var - 1][prev_abs_var - 1] == 1:  # 상관된 변수면 할당 불가
                            can_assign = False
                            break

                    if can_assign == True:
                        VPES[current_row_at_column[col]][col] = VPE(abs_var)  # 변수 할당
                        assigned_abs_vars.add(abs_var)  # 할당된 변수로 등록
                        current_row_at_column[col] += 1

                    if current_row_at_column[col] >= self.num_rows:  # 이 column에 모두 할당했으면 다음 column으로
                        break
            
            if len(assigned_abs_vars) == self.num_vars:
                # print('deploy_search_iter', deploy_search_iter)
                VPES_index = np.array([[vpe.MY_VAR if vpe else None for vpe in row] for row in VPES])
                break
        return VPES, VPES_index, assigned_abs_vars

    def print_vpe_index(self):
        """
        VPE 배열을 2D 행렬로 출력하는 메서드
        """
        print('VPE Array:')
        for row_index, row in enumerate(self.VPE_index):
            formatted_row = '| '.join(f'v{row_index * len(row) + col_index:<2} {str(elem) if elem is not None else "No":>2}' 
                                        for col_index, elem in enumerate(row))
            print(formatted_row)
        print('\nnum of assigned_abs_vars:', len(self.assigned_abs_vars))
        

    def check_uncorrelated_columns(self, VPE_index, correlation_matrix):
        # VPE_index: VPE 배열의 인덱스를 나타냄. 각 값은 변수 번호를 의미함.
        # correlation_matrix: 변수들 간의 상관관계를 나타내는 행렬. (num_vars x num_vars 크기의 행렬)

        num_rows = len(VPE_index)
        # VPE_index의 행(row) 수를 얻음. 즉, VPE 배열에서 몇 개의 행이 있는지 확인.

        num_cols = len(VPE_index[0])
        # VPE_index의 열(column) 수를 얻음. 즉, 각 열에 몇 개의 변수가 배치되었는지 확인.

        for col in range(num_cols):
            # 각 열(column)을 순회함. 이때 col은 현재 처리 중인 열의 인덱스를 나타냄.

            col_values = [VPE_index[row][col] for row in range(num_rows) if VPE_index[row][col] is not None]
            # 현재 열에서 변수가 할당된 값을 모두 수집. None이 아닌 값만 선택하여 리스트로 만듦.
            # 즉, 해당 열에 배치된 변수 번호들을 수집하는 과정.

            for i in range(len(col_values)):
                # 수집한 변수 번호 리스트에서 첫 번째 변수부터 시작하여 다른 변수들과 비교하기 위해 반복문 시작.
                # i는 현재 비교하고자 하는 첫 번째 변수의 인덱스를 나타냄.

                for j in range(i + 1, len(col_values)):
                    # i 이후에 있는 변수들과 비교하기 위한 반복문.
                    # j는 두 번째로 비교할 변수의 인덱스를 나타냄.

                    var1 = col_values[i]
                    # 첫 번째 변수의 값(var1)을 col_values 리스트에서 가져옴.

                    var2 = col_values[j]
                    # 두 번째 변수의 값(var2)을 col_values 리스트에서 가져옴.

                    # 상관된 경우를 찾음
                    if correlation_matrix[var1 - 1][var2 - 1] == 1:
                        # correlation_matrix에서 var1과 var2가 상관된 경우를 확인.
                        # 변수 번호는 1부터 시작하므로, 0-based 인덱스에 맞추기 위해 -1 처리.
                        # 상관된 경우, correlation_matrix에서 해당 값이 1임을 이용하여 상관된 변수를 확인함.

                        # print(f"Error: Column {col+1} contains correlated variables {var1} and {var2}.")
                        # 상관된 변수를 발견한 경우, 그 변수가 어느 column에 있는지와 함께 에러 메시지를 출력.

                        return False
                        # 상관된 변수가 발견되면 더 이상 검사를 진행하지 않고 False를 반환하여 함수 종료.

        # 모든 열에 대해 상관된 변수가 없을 경우, 오류가 없음을 나타냄.
        # print("All columns are internally uncorrelated.\n")
        return True
        # 모든 열에서 상관된 변수가 없는 경우, True를 반환함.

    def add_clause_to_vpe(self):
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].add_clause(self.clauses)

    
    def variable_state_initialize(self):
        var_state_array = [random.choice([0, 1]) for _ in range(self.num_vars)]
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPES[row][col] != None:
                    self.VPES[row][col].MY_STATE = var_state_array[self.VPES[row][col].MY_VAR - 1]
        return var_state_array
    


    def satisfy_check(self, var_state_array, clauses):
        """
        절을 만족하는지 확인하는 메서드
        :param var_state_array: 변수들의 상태를 나타내는 배열 (0 또는 1로 구성된 리스트)
        :param clauses: 각 절을 표현하는 리스트의 리스트 (변수는 양수 또는 음수로 표현됨)
        :return: num_unsat_clause, unsat_clauses_list (만족되지 않은 절의 개수와 그 절들의 리스트)
        """
        unsat_clauses_list = []

        # 각 절에 대해 만족 여부를 확인
        for clause in clauses:
            satisfied = False  # 해당 절이 만족되는지 여부를 나타내는 변수

            for var in clause:
                abs_var = abs(var) - 1  # 변수의 절대값으로 인덱스를 맞춤 (0부터 시작)
                var_state = var_state_array[abs_var]  # 해당 변수의 상태

                if (var > 0 and var_state == 1) or (var < 0 and var_state == 0):
                    satisfied = True  # 하나라도 만족하는 변수가 있으면 절이 만족됨
                    break

            if satisfied == False:
                unsat_clauses_list.append(clause)  # 만족되지 않은 절을 리스트에 추가

        num_unsat_clause = len(unsat_clauses_list)  # 만족되지 않은 절의 개수

        return num_unsat_clause, unsat_clauses_list
    
    def print_var_state_array(self):
        print('print self.var_state_array')
        for row in range(self.num_rows):
            for col in range(self.num_cols):
                if self.VPE_index[row][col] != None:
                    print(f'v{self.VPE_index[row][col]:<2}={self.var_state_array[self.VPE_index[row][col]-1]}', end=' | ')
                else: 
                    # print(f'vNo=None', end=' | ')
                    print(f'None ', end=' | ')
            print()
        print()

    def run(self, max_iter, iter_verbose):
        """
        VPE 배열을 실행하는 메서드
        :param max_iter: 최대 반복 횟수 (기본값: 100)
        """
        num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
        if iter_verbose == True:
            print(f'iteration {0:>4} | num_unsat_clause: {num_unsat_clause}')
        for i in range(max_iter):
            # self.print_var_state_array()

            # row-wise parellel processing
            for col in range(self.num_cols):
                # self.print_var_state_array()
                # num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
                # print(f'col {col}, num_unsat_clause: {num_unsat_clause}')
                state_temp_at_now_col = [None for _ in range(self.num_rows)]
                for row in range(self.num_rows):
                    if self.VPES[row][col] != None:
                        stocastic_mode = False
                        # stocastic_mode = False if i < 5 else True
                        state_temp_at_now_col[row] = self.VPES[row][col].process(self.var_state_array,stocastic_mode)

                    # updated state update!!
                for row in range(self.num_rows):
                    # print(state_temp_at_now_col)
                    if state_temp_at_now_col[row] != None:
                        self.var_state_array[self.VPES[row][col].MY_VAR - 1] = state_temp_at_now_col[row]

            num_unsat_clause, unsat_clauses_list = self.satisfy_check(self.var_state_array, self.clauses)
            if iter_verbose == True:
                print(f'iteration {i+1:>4} | num_unsat_clause: {num_unsat_clause}')


            if num_unsat_clause == 0:
                if iter_verbose == True:
                    print(f'SATISFIED!!!! iter{i+1}')
                return i+1
            
            # # iteration 마다 실패하면 다시 리셋하기
            # self.var_state_array = self.variable_state_initialize()


        else:
            if iter_verbose == True:
                print(f"NOT SATISFIED! num_unsat_clause: {num_unsat_clause}, unsat_clauses_list: {unsat_clauses_list}, iteration: {i+1}")
            return -num_unsat_clause

# %%
def HYPER_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=18, file_path='/data2/sat/uf50-218/uf50-03.cnf', max_iter=100, iter_verbose=False):
    clauses, num_vars, num_clauses = read_cnf_file(file_path)

    SUCCESS_OR_NOT = 0
    for hyper_iter in range(HYPER_MAX_ITER):
        # print(f'hyper_iter: {hyper_iter+1}', end = '  ')
        my_seed = hyper_seed * (hyper_iter+1)
        vpe_array = VPE_ARRAY(my_seed=my_seed, num_rows=num_rows, num_cols=num_cols, clauses=clauses, num_vars=num_vars, num_clauses=num_clauses)  # 5x12 VPE 배열 생성
        success_iter = vpe_array.run(max_iter, iter_verbose)  # VPE processing 실행
        if success_iter > 0:
            print(f'SATISFIED!!!! hyper_iter: {hyper_iter}, success_iter: {success_iter}')
            SUCCESS_OR_NOT = 1
            break
        # print(f'not satisfied. num_unsat_clause: {-success_iter}')
        # print()
    else:
        print(f'HYPER_MAX_ITER: {HYPER_MAX_ITER}, NOT SATISFIED!  last num_unsat_clause: {-success_iter}')

    return SUCCESS_OR_NOT

    # vpe_array.print_vpe_index()  # VPE 배열 출력

# %%
HYPER_MAX_ITER = 1

# file_path = 'example_uf50-03.cnf'
file_path = '/data2/sat/uf50-218/uf50-02.cnf'
hyper_seed = 42
num_rows = 5
num_cols = 12
max_iter = 100
iter_verbose = False

# HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose)

# %%
def FULL_FILE_RUN(HYPER_MAX_ITER=1, hyper_seed=42, num_rows=5, num_cols=12, BASE_PATH='/data2/sat/uf50-218/', max_iter=10, iter_verbose=False):
    
    files = count_files_in_directory(BASE_PATH)
    assert files != None, '파일 못 불러오고 있따.'

    total_file = len(files)
    num_success = 0
    current_file = 0
    for file in files:
        file_path = os.path.join(BASE_PATH, file)
        print(f'\nfile: {file}, {current_file+1}/{total_file}')
        SUCCESS_OR_NOT = HYPER_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, hyper_seed=hyper_seed, num_rows=num_rows, num_cols=num_cols, file_path=file_path, max_iter=max_iter, iter_verbose=iter_verbose)
        num_success += SUCCESS_OR_NOT
        current_file += 1
        print(f'Current Solvability: {100*num_success/current_file:.2f}%')
    assert current_file == total_file
    print(f'\n\nFinal Solvability: {100*num_success/total_file:.2f}%')

# %%
    
HYPER_MAX_ITER = 1

# BASE_PATH = '/data2/sat/uf50-218/uf50-02.cnf'
BASE_PATH = '/data2/sat/uf50-218/'
# BASE_PATH = '/data2/sat/uf20-91'
hyper_seed = 42
num_rows = 5
num_cols = 12
max_iter = 10000
iter_verbose = False

FULL_FILE_RUN(HYPER_MAX_ITER=HYPER_MAX_ITER, 
                hyper_seed=hyper_seed, 
                num_rows=num_rows, 
                num_cols=num_cols, 
                BASE_PATH=BASE_PATH, 
                max_iter=max_iter, 
                iter_verbose=iter_verbose)
# Out:
# file: uf50-0643.cnf, 1/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 0.00%
#
# file: uf50-065.cnf, 2/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 0.00%
#
# file: uf50-0509.cnf, 3/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 33.33%
#
# file: uf50-0923.cnf, 4/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 25.00%
#
# file: uf50-0448.cnf, 5/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 20.00%
#
# file: uf50-04.cnf, 6/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 16.67%
#
# file: uf50-0484.cnf, 7/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 14.29%
#
# file: uf50-0616.cnf, 8/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 4
# Current Solvability: 12.50%
#
# file: uf50-0386.cnf, 9/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 11.11%
#
# file: uf50-0357.cnf, 10/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 10.00%
#
# file: uf50-0216.cnf, 11/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 9.09%
#
# file: uf50-026.cnf, 12/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 8.33%
#
# file: uf50-0319.cnf, 13/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 7.69%
#
# file: uf50-0246.cnf, 14/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 32
# Current Solvability: 14.29%
#
# file: uf50-0820.cnf, 15/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 13.33%
#
# file: uf50-046.cnf, 16/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 12.50%
#
# file: uf50-0902.cnf, 17/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 11.76%
#
# file: uf50-0469.cnf, 18/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 16.67%
#
# file: uf50-0848.cnf, 19/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 21.05%
#
# file: uf50-0825.cnf, 20/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 20.00%
#
# file: uf50-0805.cnf, 21/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 19.05%
#
# file: uf50-0996.cnf, 22/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 3
# Current Solvability: 22.73%
#
# file: uf50-0477.cnf, 23/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 21.74%
#
# file: uf50-0204.cnf, 24/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 20.83%
#
# file: uf50-0408.cnf, 25/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 20.00%
#
# file: uf50-0604.cnf, 26/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 23.08%
#
# file: uf50-0756.cnf, 27/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 25.93%
#
# file: uf50-0465.cnf, 28/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 28.57%
#
# file: uf50-0240.cnf, 29/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 27.59%
#
# file: uf50-0163.cnf, 30/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 30.00%
#
# file: uf50-0795.cnf, 31/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 15
# Current Solvability: 32.26%
#
# file: uf50-0978.cnf, 32/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 22
# Current Solvability: 34.38%
#
# file: uf50-0488.cnf, 33/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 36.36%
#
# file: uf50-0562.cnf, 34/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 23
# Current Solvability: 38.24%
#
# file: uf50-0666.cnf, 35/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 37.14%
#
# file: uf50-0107.cnf, 36/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 36.11%
#
# file: uf50-0928.cnf, 37/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 35.14%
#
# file: uf50-0507.cnf, 38/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 34.21%
#
# file: uf50-0459.cnf, 39/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 35.90%
#
# file: uf50-0397.cnf, 40/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 10
# Current Solvability: 37.50%
#
# file: uf50-0716.cnf, 41/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 14
# Current Solvability: 39.02%
#
# file: uf50-0454.cnf, 42/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 40.48%
#
# file: uf50-0938.cnf, 43/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 26
# Current Solvability: 41.86%
#
# file: uf50-0758.cnf, 44/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 43.18%
#
# file: uf50-051.cnf, 45/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 42.22%
#
# file: uf50-031.cnf, 46/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 45
# Current Solvability: 43.48%
#
# file: uf50-0763.cnf, 47/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 42.55%
#
# file: uf50-0947.cnf, 48/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 86
# Current Solvability: 43.75%
#
# file: uf50-0961.cnf, 49/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 42.86%
#
# file: uf50-0968.cnf, 50/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 20
# Current Solvability: 44.00%
#
# file: uf50-0154.cnf, 51/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 43.14%
#
# file: uf50-0478.cnf, 52/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 42.31%
#
# file: uf50-0985.cnf, 53/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 41.51%
#
# file: uf50-0132.cnf, 54/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 42.59%
#
# file: uf50-0976.cnf, 55/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 41.82%
#
# file: uf50-0268.cnf, 56/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 42.86%
#
# file: uf50-0995.cnf, 57/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 42.11%
#
# file: uf50-0658.cnf, 58/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 41.38%
#
# file: uf50-071.cnf, 59/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 40.68%
#
# file: uf50-0789.cnf, 60/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 40.00%
#
# file: uf50-0217.cnf, 61/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.34%
#
# file: uf50-039.cnf, 62/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 40.32%
#
# file: uf50-0572.cnf, 63/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 39.68%
#
# file: uf50-018.cnf, 64/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.06%
#
# file: uf50-0868.cnf, 65/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 110
# Current Solvability: 40.00%
#
# file: uf50-0415.cnf, 66/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 40.91%
#
# file: uf50-0530.cnf, 67/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 41.79%
#
# file: uf50-0887.cnf, 68/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 42.65%
#
# file: uf50-014.cnf, 69/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 42.03%
#
# file: uf50-0569.cnf, 70/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 41.43%
#
# file: uf50-0363.cnf, 71/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 40.85%
#
# file: uf50-0543.cnf, 72/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 40.28%
#
# file: uf50-0157.cnf, 73/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.73%
#
# file: uf50-0433.cnf, 74/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 39.19%
#
# file: uf50-0857.cnf, 75/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 40.00%
#
# file: uf50-0924.cnf, 76/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 39.47%
#
# file: uf50-0853.cnf, 77/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.96%
#
# file: uf50-0243.cnf, 78/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.46%
#
# file: uf50-0361.cnf, 79/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 39.24%
#
# file: uf50-0585.cnf, 80/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.75%
#
# file: uf50-0627.cnf, 81/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 3
# Current Solvability: 39.51%
#
# file: uf50-0731.cnf, 82/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.02%
#
# file: uf50-0431.cnf, 83/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 39.76%
#
# file: uf50-0535.cnf, 84/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.29%
#
# file: uf50-0870.cnf, 85/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.82%
#
# file: uf50-0531.cnf, 86/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.37%
#
# file: uf50-0965.cnf, 87/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 11
# Current Solvability: 39.08%
#
# file: uf50-0630.cnf, 88/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.64%
#
# file: uf50-019.cnf, 89/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.20%
#
# file: uf50-0467.cnf, 90/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 37.78%
#
# file: uf50-0335.cnf, 91/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 38.46%
#
# file: uf50-0303.cnf, 92/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.04%
#
# file: uf50-0438.cnf, 93/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 16
# Current Solvability: 38.71%
#
# file: uf50-034.cnf, 94/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 39.36%
#
# file: uf50-0485.cnf, 95/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.95%
#
# file: uf50-0145.cnf, 96/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.54%
#
# file: uf50-0362.cnf, 97/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 39.18%
#
# file: uf50-0434.cnf, 98/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 39.80%
#
# file: uf50-0307.cnf, 99/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 39.39%
#
# file: uf50-0193.cnf, 100/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 39.00%
#
# file: uf50-0267.cnf, 101/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.61%
#
# file: uf50-0177.cnf, 102/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.24%
#
# file: uf50-0473.cnf, 103/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 37.86%
#
# file: uf50-0755.cnf, 104/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 38.46%
#
# file: uf50-0208.cnf, 105/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.10%
#
# file: uf50-0609.cnf, 106/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 10
# Current Solvability: 38.68%
#
# file: uf50-0524.cnf, 107/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 39.25%
#
# file: uf50-0305.cnf, 108/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.89%
#
# file: uf50-0879.cnf, 109/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 38.53%
#
# file: uf50-08.cnf, 110/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 38.18%
#
# file: uf50-0439.cnf, 111/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 38.74%
#
# file: uf50-0955.cnf, 112/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 3
# Current Solvability: 39.29%
#
# file: uf50-0542.cnf, 113/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 129
# Current Solvability: 39.82%
#
# file: uf50-0419.cnf, 114/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 40.35%
#
# file: uf50-0774.cnf, 115/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 45
# Current Solvability: 40.87%
#
# file: uf50-0831.cnf, 116/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 40.52%
#
# file: uf50-0840.cnf, 117/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 41.03%
#
# file: uf50-0426.cnf, 118/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 40.68%
#
# file: uf50-093.cnf, 119/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 41.18%
#
# file: uf50-0685.cnf, 120/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 41.67%
#
# file: uf50-0713.cnf, 121/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 42.15%
#
# file: uf50-0587.cnf, 122/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 41.80%
#
# file: uf50-0854.cnf, 123/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 41.46%
#
# file: uf50-0635.cnf, 124/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 41.94%
#
# file: uf50-0460.cnf, 125/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 41.60%
#
# file: uf50-0250.cnf, 126/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 42.06%
#
# file: uf50-0325.cnf, 127/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 42.52%
#
# file: uf50-0421.cnf, 128/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 10
# Current Solvability: 42.97%
#
# file: uf50-0450.cnf, 129/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 42.64%
#
# file: uf50-0791.cnf, 130/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 42.31%
#
# file: uf50-097.cnf, 131/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 41.98%
#
# file: uf50-0506.cnf, 132/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 42.42%
#
# file: uf50-057.cnf, 133/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 42.11%
#
# file: uf50-0289.cnf, 134/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 4
# Current Solvability: 42.54%
#
# file: uf50-0573.cnf, 135/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 14
# Current Solvability: 42.96%
#
# file: uf50-050.cnf, 136/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 42.65%
#
# file: uf50-0925.cnf, 137/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 43.07%
#
# file: uf50-0458.cnf, 138/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 43.48%
#
# file: uf50-0365.cnf, 139/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 10
# Current Solvability: 43.88%
#
# file: uf50-0316.cnf, 140/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 22
# Current Solvability: 44.29%
#
# file: uf50-0618.cnf, 141/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 27
# Current Solvability: 44.68%
#
# file: uf50-0464.cnf, 142/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 45.07%
#
# file: uf50-0915.cnf, 143/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 3
# Current Solvability: 45.45%
#
# file: uf50-0747.cnf, 144/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 15
# Current Solvability: 45.83%
#
# file: uf50-0753.cnf, 145/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 15
# Current Solvability: 46.21%
#
# file: uf50-0557.cnf, 146/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 15
# Current Solvability: 46.58%
#
# file: uf50-0705.cnf, 147/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 46.26%
#
# file: uf50-0234.cnf, 148/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.95%
#
# file: uf50-078.cnf, 149/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 45.64%
#
# file: uf50-056.cnf, 150/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 46.00%
#
# file: uf50-024.cnf, 151/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 45.70%
#
# file: uf50-080.cnf, 152/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.39%
#
# file: uf50-0544.cnf, 153/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.10%
#
# file: uf50-0843.cnf, 154/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 45.45%
#
# file: uf50-0517.cnf, 155/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.16%
#
# file: uf50-0377.cnf, 156/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 31
# Current Solvability: 45.51%
#
# file: uf50-0958.cnf, 157/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.22%
#
# file: uf50-0686.cnf, 158/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 8
# Current Solvability: 45.57%
#
# file: uf50-041.cnf, 159/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 45.28%
#
# file: uf50-0704.cnf, 160/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.00%
#
# file: uf50-0547.cnf, 161/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.72%
#
# file: uf50-0127.cnf, 162/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.44%
#
# file: uf50-0687.cnf, 163/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 44.79%
#
# file: uf50-0584.cnf, 164/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 45.12%
#
# file: uf50-0239.cnf, 165/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 3
# Current Solvability: 45.45%
#
# file: uf50-0475.cnf, 166/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 36
# Current Solvability: 45.78%
#
# file: uf50-0521.cnf, 167/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 46.11%
#
# file: uf50-0904.cnf, 168/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 14
# Current Solvability: 46.43%
#
# file: uf50-0952.cnf, 169/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 46.15%
#
# file: uf50-0398.cnf, 170/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.88%
#
# file: uf50-0343.cnf, 171/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 46.20%
#
# file: uf50-035.cnf, 172/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 12
# Current Solvability: 46.51%
#
# file: uf50-0414.cnf, 173/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 46.24%
#
# file: uf50-0519.cnf, 174/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 1858
# Current Solvability: 46.55%
#
# file: uf50-0194.cnf, 175/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 46.29%
#
# file: uf50-0236.cnf, 176/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 46.59%
#
# file: uf50-0809.cnf, 177/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 46.33%
#
# file: uf50-0650.cnf, 178/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 46.07%
#
# file: uf50-0494.cnf, 179/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.81%
#
# file: uf50-044.cnf, 180/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 45.56%
#
# file: uf50-0168.cnf, 181/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 45.86%
#
# file: uf50-048.cnf, 182/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.60%
#
# file: uf50-0167.cnf, 183/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 45.36%
#
# file: uf50-0248.cnf, 184/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 45.11%
#
# file: uf50-0160.cnf, 185/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.86%
#
# file: uf50-0898.cnf, 186/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 44.62%
#
# file: uf50-0559.cnf, 187/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 44.39%
#
# file: uf50-0313.cnf, 188/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.15%
#
# file: uf50-0389.cnf, 189/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.92%
#
# file: uf50-0260.cnf, 190/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 44.21%
#
# file: uf50-0907.cnf, 191/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 6
# Current Solvability: 44.50%
#
# file: uf50-0746.cnf, 192/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 39
# Current Solvability: 44.79%
#
# file: uf50-0844.cnf, 193/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.56%
#
# file: uf50-0701.cnf, 194/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 44.85%
#
# file: uf50-0395.cnf, 195/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 45.13%
#
# file: uf50-0856.cnf, 196/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.90%
#
# file: uf50-0741.cnf, 197/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.67%
#
# file: uf50-0552.cnf, 198/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 7
# Current Solvability: 44.95%
#
# file: uf50-0545.cnf, 199/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 44.72%
#
# file: uf50-0518.cnf, 200/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 44.50%
#
# file: uf50-0903.cnf, 201/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.28%
#
# file: uf50-0759.cnf, 202/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 44.06%
#
# file: uf50-054.cnf, 203/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 43.84%
#
# file: uf50-0462.cnf, 204/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.63%
#
# file: uf50-060.cnf, 205/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 43.41%
#
# file: uf50-0483.cnf, 206/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.20%
#
# file: uf50-0418.cnf, 207/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.00%
#
# file: uf50-0935.cnf, 208/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 13
# Current Solvability: 43.27%
#
# file: uf50-0594.cnf, 209/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 193
# Current Solvability: 43.54%
#
# file: uf50-0425.cnf, 210/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 2
# Current Solvability: 43.33%
#
# file: uf50-0797.cnf, 211/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 5
# Current Solvability: 43.60%
#
# file: uf50-0614.cnf, 212/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.40%
#
# file: uf50-0529.cnf, 213/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 74
# Current Solvability: 43.66%
#
# file: uf50-0430.cnf, 214/1000
# SATISFIED!!!! hyper_iter: 0, success_iter: 9
# Current Solvability: 43.93%
#
# file: uf50-0605.cnf, 215/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 3
# Current Solvability: 43.72%
#
# file: uf50-0215.cnf, 216/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.52%
#
# file: uf50-0263.cnf, 217/1000
# HYPER_MAX_ITER: 1, NOT SATISFIED!  last num_unsat_clause: 1
# Current Solvability: 43.32%
#
# file: uf50-0539.cnf, 218/1000
